# %%
import os
import json

import torch

from xstnn import SaptioTemporalNN
from utils import rmse
from datasets import dataset_factory

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Data

# %%
datadir = 'data'
dataset = 'heat'
_, (train_data, test_data), _ , _ = dataset_factory(datadir, dataset)

plt.figure('Heat Difusion Dataset')
plt.imshow(torch.cat((train_data, test_data)).squeeze().numpy().T, aspect='auto', cmap='jet')
plt.title('Heat Difusion Dataset')
plt.xlabel('timestep')
plt.colorbar()

# %% [markdown]
# ## Training

# %%
run train_xstnn.py --dataset heat --outputdir output_heat --manualSeed 2021 --xp stnn
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
#
#
#
#
#
#
#   0%|          | 0/10000 [00:00<?, ?it/s, loss=0.143, rmse_test=0.294]
#
#
#
#
#
#
#   0%|          | 0/10000 [00:00<?, ?it/s, loss=0.141, rmse_test=0.288]
#
#
#
#
#
#
#   0%|          | 0/10000 [00:00<?, ?it/s, loss=0.139, rmse_test=0.284]
#
#
#
#
#
#
#   0%|          | 3/10000 [00:00<05:53, 28.26it/s, loss=0.139, rmse_test=0.284]
#
#
#
#
#
#
#   0%|          | 3/10000 [00:00<05:53, 28.26it/s, loss=0.137, rmse_test=0.282]
#
#
#
#
#
#
#   0%|          | 3/10000 [00:00<05:53, 28.26it/s, loss=0.134, rmse_test=0.28]
#
#
#
#
#
#
#   0%|          | 3/10000 [00:00<05:53, 28.26it/s, loss=0.132, rmse_test=0.278]
#
#
#
#
#
#
#   0%|          | 3/10000 [00:00<05:53, 28.26it/s, loss=0.128, rmse_test=0.275]
#
#
#
#
#
#
#   0%|          | 7/10000 [00:00<05:54, 28.18it/s, loss=0.128, rmse_test=0.275]
#
#
#
#
#
#
#   0%|          | 7/10000 [00:00<05:54, 28.18it/s, loss=0.125, rmse_test=0.272]
#
#
#
#
#
#
#   0%|          | 7/10000 [00:00<05:54, 28.18it/s, loss=0.121, rmse_test=0.268]
#
#
#
#
#
#
#   0%|          | 7/10000 [00:00<05:54, 28.18it/s, loss=0.117, rmse_test=0.262]
#
#
#
#
#
#
#   0%|          | 7/10000 [00:00<05:54, 28.18it/s, loss=0.113, rmse_test=0.256]
#
#
#
#
#
#
#   0%|          | 11/10000 [00:00<05:31, 30.11it/s, loss=0.113, rmse_test=0.256]
#
#
#
#
#
#
#   0%|          | 11/10000 [00:00<05:31, 30.11it/s, loss=0.108, rmse_test=0.249]
#
#
#
#
#
#
#   0%|          | 11/10000 [00:00<05:31, 30.11it/s, loss=0.104, rmse_test=0.241]
#
#
#
#
#
#
#   0%|          | 11/10000 [00:00<05:31, 30.11it/s, loss=0.099, rmse_test=0.232]
#
#
#
#
#
#
#   0%|          | 11/10000 [00:00<05:31, 30.11it/s, loss=0.0942, rmse_test=0.223]
#
#
#
#
#
#
#   0%|          | 11/10000 [00:00<05:31, 30.11it/s, loss=0.0896, rmse_test=0.215]
#
#
#
#
#
#
#   0%|          | 16/10000 [00:00<05:06, 32.60it/s, loss=0.0896, rmse_test=0.215]
#
#
#
#
#
#
#   0%|          | 16/10000 [00:00<05:06, 32.60it/s, loss=0.0849, rmse_test=0.206]
#
#
#
#
#
#
#   0%|          | 16/10000 [00:00<05:06, 32.60it/s, loss=0.0801, rmse_test=0.198]
#
#
#
#
#
#
#   0%|          | 16/10000 [00:00<05:06, 32.60it/s, loss=0.0756, rmse_test=0.191]
#
#
#
#
#
#
#   0%|          | 16/10000 [00:00<05:06, 32.60it/s, loss=0.071, rmse_test=0.183]
#
#
#
#
#
#
#   0%|          | 16/10000 [00:00<05:06, 32.60it/s, loss=0.0666, rmse_test=0.177]
#
#
#
#
#
#
#   0%|          | 21/10000 [00:00<04:43, 35.17it/s, loss=0.0666, rmse_test=0.177]
#
#
#
#
#
#
#   0%|          | 21/10000 [00:00<04:43, 35.17it/s, loss=0.0623, rmse_test=0.172]
#
#
#
#
#
#
#   0%|          | 21/10000 [00:00<04:43, 35.17it/s, loss=0.0583, rmse_test=0.166]
#
#
#
#
#
#
#   0%|          | 21/10000 [00:00<04:43, 35.17it/s, loss=0.0544, rmse_test=0.162]
#
#
#
#
#
#
#   0%|          | 21/10000 [00:00<04:43, 35.17it/s, loss=0.0506, rmse_test=0.159]
#
#
#
#
#
#
#   0%|          | 25/10000 [00:00<04:36, 36.02it/s, loss=0.0506, rmse_test=0.159]
#
#
#
#
#
#
#   0%|          | 25/10000 [00:00<04:36, 36.02it/s, loss=0.0471, rmse_test=0.156]
#
#
#
#
#
#
#   0%|          | 25/10000 [00:00<04:36, 36.02it/s, loss=0.0438, rmse_test=0.153]
#
#
#
#
#
#
#   0%|          | 25/10000 [00:00<04:36, 36.02it/s, loss=0.0406, rmse_test=0.151]
#
#
#
#
#
#
#   0%|          | 25/10000 [00:00<04:36, 36.02it/s, loss=0.0375, rmse_test=0.15]
#
#
#
#
#
#
#   0%|          | 29/10000 [00:00<04:31, 36.71it/s, loss=0.0375, rmse_test=0.15]
#
#
#
#
#
#
#   0%|          | 29/10000 [00:00<04:31, 36.71it/s, loss=0.0346, rmse_test=0.148]
#
#
#
#
#
#
#   0%|          | 29/10000 [00:00<04:31, 36.71it/s, loss=0.0319, rmse_test=0.147]
#
#
#
#
#
#
#   0%|          | 29/10000 [00:00<04:31, 36.71it/s, loss=0.0295, rmse_test=0.145]
#
#
#
#
#
#
#   0%|          | 29/10000 [00:00<04:31, 36.71it/s, loss=0.0272, rmse_test=0.145]
#
#
#
#
#
#
#   0%|          | 33/10000 [00:00<04:31, 36.74it/s, loss=0.0272, rmse_test=0.145]
#
#
#
#
#
#
#   0%|          | 33/10000 [00:00<04:31, 36.74it/s, loss=0.0251, rmse_test=0.144]
#
#
#
#
#
#
#   0%|          | 33/10000 [00:00<04:31, 36.74it/s, loss=0.023, rmse_test=0.144]
#
#
#
#
#
#
#   0%|          | 33/10000 [00:01<04:31, 36.74it/s, loss=0.0212, rmse_test=0.143]
#
#
#
#
#
#
#   0%|          | 33/10000 [00:01<04:31, 36.74it/s, loss=0.0195, rmse_test=0.143]
#
#
#
#
#
#
#   0%|          | 37/10000 [00:01<04:41, 35.34it/s, loss=0.0195, rmse_test=0.143]
#
#
#
#
#
#
#   0%|          | 37/10000 [00:01<04:41, 35.34it/s, loss=0.0179, rmse_test=0.142]
#
#
#
#
#
#
#   0%|          | 37/10000 [00:01<04:41, 35.34it/s, loss=0.0164, rmse_test=0.143]
#
#
#
#
#
#
#   0%|          | 37/10000 [00:01<04:41, 35.34it/s, loss=0.015, rmse_test=0.143]
#
#
#
#
#
#
#   0%|          | 37/10000 [00:01<04:41, 35.34it/s, loss=0.0138, rmse_test=0.145]
#
#
#
#
#
#
#   0%|          | 41/10000 [00:01<04:50, 34.34it/s, loss=0.0138, rmse_test=0.145]
#
#
#
#
#
#
#   0%|          | 41/10000 [00:01<04:50, 34.34it/s, loss=0.0127, rmse_test=0.14]
#
#
#
#
#
#
#   0%|          | 41/10000 [00:01<04:50, 34.34it/s, loss=0.0116, rmse_test=0.141]
#
#
#
#
#
#
#   0%|          | 41/10000 [00:01<04:50, 34.34it/s, loss=0.0106, rmse_test=0.138]
#
#
#
#
#
#
#   0%|          | 41/10000 [00:01<04:50, 34.34it/s, loss=0.00976, rmse_test=0.136]
#
#
#
#
#
#
#   0%|          | 45/10000 [00:01<04:54, 33.82it/s, loss=0.00976, rmse_test=0.136]
#
#
#
#
#
#
#   0%|          | 45/10000 [00:01<04:54, 33.82it/s, loss=0.00894, rmse_test=0.134]
#
#
#
#
#
#
#   0%|          | 45/10000 [00:01<04:54, 33.82it/s, loss=0.00813, rmse_test=0.134]
#
#
#
#
#
#
#   0%|          | 45/10000 [00:01<04:54, 33.82it/s, loss=0.00743, rmse_test=0.136]
#
#
#
#
#
#
#   0%|          | 45/10000 [00:01<04:54, 33.82it/s, loss=0.00678, rmse_test=0.146]
#
#
#
#
#
#
#   0%|          | 49/10000 [00:01<04:46, 34.75it/s, loss=0.00678, rmse_test=0.146]
#
#
#
#
#
#
#   0%|          | 49/10000 [00:01<04:46, 34.75it/s, loss=0.00622, rmse_test=0.151]
#
#
#
#
#
#
#   0%|          | 49/10000 [00:01<04:46, 34.75it/s, loss=0.0057, rmse_test=0.13]
#
#
#
#
#
#
#   0%|          | 49/10000 [00:01<04:46, 34.75it/s, loss=0.00524, rmse_test=0.122]
#
#
#
#
#
#
#   0%|          | 49/10000 [00:01<04:46, 34.75it/s, loss=0.00482, rmse_test=0.119]
#
#
#
#
#
#
#   1%|          | 53/10000 [00:01<04:45, 34.90it/s, loss=0.00482, rmse_test=0.119]
#
#
#
#
#
#
#   1%|          | 53/10000 [00:01<04:45, 34.90it/s, loss=0.00444, rmse_test=0.124]
#
#
#
#
#
#
#   1%|          | 53/10000 [00:01<04:45, 34.90it/s, loss=0.00408, rmse_test=0.128]
#
#
#
#
#
#
#   1%|          | 53/10000 [00:01<04:45, 34.90it/s, loss=0.00373, rmse_test=0.11]
#
#
#
#
#
#
#   1%|          | 53/10000 [00:01<04:45, 34.90it/s, loss=0.00343, rmse_test=0.113]
#
#
#
#
#
#
#   1%|          | 57/10000 [00:01<04:35, 36.05it/s, loss=0.00343, rmse_test=0.113]
#
#
#
#
#
#
#   1%|          | 57/10000 [00:01<04:35, 36.05it/s, loss=0.00317, rmse_test=0.102]
#
#
#
#
#
#
#   1%|          | 57/10000 [00:01<04:35, 36.05it/s, loss=0.0029, rmse_test=0.0999]
#
#
#
#
#
#
#   1%|          | 57/10000 [00:01<04:35, 36.05it/s, loss=0.00268, rmse_test=0.0991]
#
#
#
#
#
#
#   1%|          | 57/10000 [00:01<04:35, 36.05it/s, loss=0.00249, rmse_test=0.101]
#   1%|          | 57/10000 [00:01<04:35, 36.05it/s, loss=0.00229, rmse_test=0.0957]
#
#
#
#
#
#
#   1%|          | 62/10000 [00:01<04:21, 38.02it/s, loss=0.00229, rmse_test=0.0957]
#
#
#
#
#
#
#   1%|          | 62/10000 [00:01<04:21, 38.02it/s, loss=0.00211, rmse_test=0.0766]
#
#
#
#
#
#
#   1%|          | 62/10000 [00:01<04:21, 38.02it/s, loss=0.00196, rmse_test=0.075]
#
#
#
#
#
#
#   1%|          | 62/10000 [00:01<04:21, 38.02it/s, loss=0.00182, rmse_test=0.069]
#
#
#
#
#
#
#   1%|          | 62/10000 [00:01<04:21, 38.02it/s, loss=0.00167, rmse_test=0.0667]
#
#
#
#
#
#
#   1%|          | 62/10000 [00:01<04:21, 38.02it/s, loss=0.00155, rmse_test=0.0677]
#
#
#
#
#
#
#   1%|          | 67/10000 [00:01<04:15, 38.95it/s, loss=0.00155, rmse_test=0.0677]
#
#
#
#
#
#
#   1%|          | 67/10000 [00:01<04:15, 38.95it/s, loss=0.00145, rmse_test=0.0741]
#
#
#
#
#
#
#   1%|          | 67/10000 [00:01<04:15, 38.95it/s, loss=0.00135, rmse_test=0.0635]
#
#
#
#
#
#
#   1%|          | 67/10000 [00:01<04:15, 38.95it/s, loss=0.00125, rmse_test=0.0523]
#
#
#
#
#
#
#   1%|          | 67/10000 [00:01<04:15, 38.95it/s, loss=0.00117, rmse_test=0.0997]
#
#
#
#
#
#
#   1%|          | 67/10000 [00:01<04:15, 38.95it/s, loss=0.00109, rmse_test=0.053]
#
#
#
#
#
#
#   1%|          | 72/10000 [00:01<04:03, 40.80it/s, loss=0.00109, rmse_test=0.053]
#
#
#
#
#
#
#   1%|          | 72/10000 [00:01<04:03, 40.80it/s, loss=0.000993, rmse_test=0.0429]
#
#
#
#
#
#
#   1%|          | 72/10000 [00:02<04:03, 40.80it/s, loss=0.000939, rmse_test=0.0409]
#
#
#
#
#
#
#   1%|          | 72/10000 [00:02<04:03, 40.80it/s, loss=0.000852, rmse_test=0.0827]
#
#
#
#
#
#
#   1%|          | 72/10000 [00:02<04:03, 40.80it/s, loss=0.000794, rmse_test=0.0543]
#
#
#
#
#
#
#   1%|          | 72/10000 [00:02<04:03, 40.80it/s, loss=0.000761, rmse_test=0.0307]
#
#
#
#
#
#
#   1%|          | 77/10000 [00:02<04:00, 41.30it/s, loss=0.000761, rmse_test=0.0307]
#
#
#
#
#
#
#   1%|          | 77/10000 [00:02<04:00, 41.30it/s, loss=0.000719, rmse_test=0.0331]
#
#
#
#
#
#
#   1%|          | 77/10000 [00:02<04:00, 41.30it/s, loss=0.000674, rmse_test=0.0308]
#
#
#
#
#
#
#   1%|          | 77/10000 [00:02<04:00, 41.30it/s, loss=0.000608, rmse_test=0.062]
#
#
#
#
#
#
#   1%|          | 77/10000 [00:02<04:00, 41.30it/s, loss=0.000564, rmse_test=0.0335]
#
#
#
#
#
#
#   1%|          | 77/10000 [00:02<04:00, 41.30it/s, loss=0.000543, rmse_test=0.0508]
#
#
#
#
#
#
#   1%|          | 82/10000 [00:02<03:55, 42.17it/s, loss=0.000543, rmse_test=0.0508]
#
#
#
#
#
#
#   1%|          | 82/10000 [00:02<03:55, 42.17it/s, loss=0.000495, rmse_test=0.0422]
#
#
#
#
#
#
#   1%|          | 82/10000 [00:02<03:55, 42.17it/s, loss=0.00047, rmse_test=0.0783]
#
#
#
#
#
#
#   1%|          | 82/10000 [00:02<03:55, 42.17it/s, loss=0.000427, rmse_test=0.0511]
#
#
#
#
#
#
#   1%|          | 82/10000 [00:02<03:55, 42.17it/s, loss=0.000389, rmse_test=0.0291]
#
#
#
#
#
#
#   1%|          | 82/10000 [00:02<03:55, 42.17it/s, loss=0.000377, rmse_test=0.0304]
#
#
#
#
#
#
#   1%|          | 87/10000 [00:02<03:59, 41.33it/s, loss=0.000377, rmse_test=0.0304]
#
#
#
#
#
#
#   1%|          | 87/10000 [00:02<03:59, 41.33it/s, loss=0.000351, rmse_test=0.0254]
#
#
#
#
#
#
#   1%|          | 87/10000 [00:02<03:59, 41.33it/s, loss=0.000337, rmse_test=0.0412]
#
#
#
#
#
#
#   1%|          | 87/10000 [00:02<03:59, 41.33it/s, loss=0.000312, rmse_test=0.0413]
#
#
#
#
#
#
#   1%|          | 87/10000 [00:02<03:59, 41.33it/s, loss=0.000309, rmse_test=0.0223]
#
#
#
#
#
#
#   1%|          | 87/10000 [00:02<03:59, 41.33it/s, loss=0.000264, rmse_test=0.0545]
#
#
#
#
#
#
#   1%|          | 92/10000 [00:02<03:58, 41.51it/s, loss=0.000264, rmse_test=0.0545]
#
#
#
#
#
#
#   1%|          | 92/10000 [00:02<03:58, 41.51it/s, loss=0.000245, rmse_test=0.0223]
#
#
#
#
#
#
#   1%|          | 92/10000 [00:02<03:58, 41.51it/s, loss=0.000233, rmse_test=0.0171]
#
#
#
#
#
#
#   1%|          | 92/10000 [00:02<03:58, 41.51it/s, loss=0.000215, rmse_test=0.0489]
#
#
#
#
#
#
#   1%|          | 92/10000 [00:02<03:58, 41.51it/s, loss=0.00021, rmse_test=0.019]
#
#
#
#
#
#
#   1%|          | 92/10000 [00:02<03:58, 41.51it/s, loss=0.000193, rmse_test=0.0335]
#
#
#
#
#
#
#   1%|          | 97/10000 [00:02<04:11, 39.37it/s, loss=0.000193, rmse_test=0.0335]
#
#
#
#
#
#
#   1%|          | 97/10000 [00:02<04:11, 39.37it/s, loss=0.000188, rmse_test=0.0277]
#
#
#
#
#
#
#   1%|          | 97/10000 [00:02<04:11, 39.37it/s, loss=0.000185, rmse_test=0.0494]
#
#
#
#
#
#
#   1%|          | 97/10000 [00:02<04:11, 39.37it/s, loss=0.000174, rmse_test=0.0206]
#
#
#
#
#
#
#   1%|          | 97/10000 [00:02<04:11, 39.37it/s, loss=0.000155, rmse_test=0.0264]
#
#
#
#
#
#
#   1%|          | 101/10000 [00:02<04:24, 37.43it/s, loss=0.000155, rmse_test=0.0264]
#
#
#
#
#
#
#   1%|          | 101/10000 [00:02<04:24, 37.43it/s, loss=0.000156, rmse_test=0.013]
#
#
#
#
#
#
#   1%|          | 101/10000 [00:02<04:24, 37.43it/s, loss=0.000151, rmse_test=0.0184]
#
#
#
#
#
#
#   1%|          | 101/10000 [00:02<04:24, 37.43it/s, loss=0.00014, rmse_test=0.014]
#
#
#
#
#
#
#   1%|          | 101/10000 [00:02<04:24, 37.43it/s, loss=0.000142, rmse_test=0.0123]
#
#
#
#
#
#
#   1%|          | 101/10000 [00:02<04:24, 37.43it/s, loss=0.000131, rmse_test=0.0136]
#
#
#
#
#
#
#   1%|          | 106/10000 [00:02<04:07, 39.99it/s, loss=0.000131, rmse_test=0.0136]
#
#
#
#
#
#
#   1%|          | 106/10000 [00:02<04:07, 39.99it/s, loss=0.000125, rmse_test=0.0266]
#
#
#
#
#
#
#   1%|          | 106/10000 [00:02<04:07, 39.99it/s, loss=0.00013, rmse_test=0.0154]
#
#
#
#
#
#
#   1%|          | 106/10000 [00:02<04:07, 39.99it/s, loss=0.000113, rmse_test=0.0151]
#
#
#
#
#
#
#   1%|          | 106/10000 [00:02<04:07, 39.99it/s, loss=0.000111, rmse_test=0.0262]
#
#
#
#
#
#
#   1%|          | 106/10000 [00:02<04:07, 39.99it/s, loss=0.000118, rmse_test=0.0224]
#
#
#
#
#
#
#   1%|          | 111/10000 [00:02<04:07, 39.99it/s, loss=0.000118, rmse_test=0.0224]
#
#
#
#
#
#
#   1%|          | 111/10000 [00:02<04:07, 39.99it/s, loss=9.55e-5, rmse_test=0.0207]
#
#
#
#
#
#
#   1%|          | 111/10000 [00:02<04:07, 39.99it/s, loss=0.000101, rmse_test=0.0302]
#
#
#
#
#
#
#   1%|          | 111/10000 [00:03<04:07, 39.99it/s, loss=8.72e-5, rmse_test=0.0295]
#
#
#
#
#
#
#   1%|          | 111/10000 [00:03<04:07, 39.99it/s, loss=8.96e-5, rmse_test=0.0207]
#
#
#
#
#
#
#   1%|          | 111/10000 [00:03<04:07, 39.99it/s, loss=7.66e-5, rmse_test=0.0215]
#
#
#
#
#
#
#   1%|          | 116/10000 [00:03<04:08, 39.80it/s, loss=7.66e-5, rmse_test=0.0215]
#
#
#
#
#
#
#   1%|          | 116/10000 [00:03<04:08, 39.80it/s, loss=8.25e-5, rmse_test=0.031]
#
#
#
#
#
#
#   1%|          | 116/10000 [00:03<04:08, 39.80it/s, loss=9e-5, rmse_test=0.0246]
#
#
#
#
#
#
#   1%|          | 116/10000 [00:03<04:08, 39.80it/s, loss=7.67e-5, rmse_test=0.0153]
#
#
#
#
#
#
#   1%|          | 116/10000 [00:03<04:08, 39.80it/s, loss=8.89e-5, rmse_test=0.0205]
#
#
#
#
#
#
#   1%|          | 116/10000 [00:03<04:08, 39.80it/s, loss=9.33e-5, rmse_test=0.0176]
#
#
#
#
#
#
#   1%|          | 121/10000 [00:03<04:07, 39.93it/s, loss=9.33e-5, rmse_test=0.0176]
#   1%|          | 121/10000 [00:03<04:07, 39.93it/s, loss=7.81e-5, rmse_test=0.0156]
#
#
#
#
#
#
#   1%|          | 121/10000 [00:03<04:07, 39.93it/s, loss=7.33e-5, rmse_test=0.0199]
#
#
#
#
#
#
#   1%|          | 121/10000 [00:03<04:07, 39.93it/s, loss=7.37e-5, rmse_test=0.0189]
#
#
#
#
#
#
#   1%|          | 121/10000 [00:03<04:07, 39.93it/s, loss=8.12e-5, rmse_test=0.015]
#
#
#
#
#
#
#   1%|          | 121/10000 [00:03<04:07, 39.93it/s, loss=6.95e-5, rmse_test=0.0134]
#
#
#
#
#
#
#   1%|▏         | 126/10000 [00:03<03:59, 41.16it/s, loss=6.95e-5, rmse_test=0.0134]
#
#
#
#
#
#
#   1%|▏         | 126/10000 [00:03<03:59, 41.16it/s, loss=6.09e-5, rmse_test=0.0132]
#
#
#
#
#
#
#   1%|▏         | 126/10000 [00:03<03:59, 41.16it/s, loss=6.28e-5, rmse_test=0.0197]
#
#
#
#
#
#
#   1%|▏         | 126/10000 [00:03<03:59, 41.16it/s, loss=6.14e-5, rmse_test=0.0238]
#
#
#
#
#
#
#   1%|▏         | 126/10000 [00:03<03:59, 41.16it/s, loss=7.43e-5, rmse_test=0.0149]
#
#
#
#
#
#
#   1%|▏         | 126/10000 [00:03<03:59, 41.16it/s, loss=6.2e-5, rmse_test=0.016]
#
#
#
#
#
#
#   1%|▏         | 131/10000 [00:03<03:53, 42.25it/s, loss=6.2e-5, rmse_test=0.016]
#
#
#
#
#
#
#   1%|▏         | 131/10000 [00:03<03:53, 42.25it/s, loss=5.5e-5, rmse_test=0.0179]
#
#
#
#
#
#
#   1%|▏         | 131/10000 [00:03<03:53, 42.25it/s, loss=6.44e-5, rmse_test=0.0188]
#
#
#
#
#
#
#   1%|▏         | 131/10000 [00:03<03:53, 42.25it/s, loss=4.56e-5, rmse_test=0.0243]
#
#
#
#
#
#
#   1%|▏         | 131/10000 [00:03<03:53, 42.25it/s, loss=6.14e-5, rmse_test=0.0131]
#
#
#
#
#
#
#   1%|▏         | 131/10000 [00:03<03:53, 42.25it/s, loss=5.18e-5, rmse_test=0.0413]
#
#
#
#
#
#
#   1%|▏         | 136/10000 [00:03<03:57, 41.55it/s, loss=5.18e-5, rmse_test=0.0413]
#
#
#
#
#
#
#   1%|▏         | 136/10000 [00:03<03:57, 41.55it/s, loss=4.92e-5, rmse_test=0.0217]
#
#
#
#
#
#
#   1%|▏         | 136/10000 [00:03<03:57, 41.55it/s, loss=6e-5, rmse_test=0.0151]
#
#
#
#
#
#
#   1%|▏         | 136/10000 [00:03<03:57, 41.55it/s, loss=6.13e-5, rmse_test=0.017]
#
#
#
#
#
#
#   1%|▏         | 136/10000 [00:03<03:57, 41.55it/s, loss=5.49e-5, rmse_test=0.0229]
#
#
#
#
#
#
#   1%|▏         | 136/10000 [00:03<03:57, 41.55it/s, loss=4.05e-5, rmse_test=0.0126]
#
#
#
#
#
#
#   1%|▏         | 141/10000 [00:03<03:47, 43.27it/s, loss=4.05e-5, rmse_test=0.0126]
#
#
#
#
#
#
#   1%|▏         | 141/10000 [00:03<03:47, 43.27it/s, loss=5.79e-5, rmse_test=0.0168]
#
#
#
#
#
#
#   1%|▏         | 141/10000 [00:03<03:47, 43.27it/s, loss=6.02e-5, rmse_test=0.0143]
#
#
#
#
#
#
#   1%|▏         | 141/10000 [00:03<03:47, 43.27it/s, loss=4.78e-5, rmse_test=0.0158]
#
#
#
#
#
#
#   1%|▏         | 141/10000 [00:03<03:47, 43.27it/s, loss=3.46e-5, rmse_test=0.016]
#
#
#
#
#
#
#   1%|▏         | 141/10000 [00:03<03:47, 43.27it/s, loss=5.32e-5, rmse_test=0.0134]
#
#
#
#
#
#
#   1%|▏         | 146/10000 [00:03<03:44, 43.93it/s, loss=5.32e-5, rmse_test=0.0134]
#
#
#
#
#
#
#   1%|▏         | 146/10000 [00:03<03:44, 43.93it/s, loss=4.38e-5, rmse_test=0.0258]
#
#
#
#
#
#
#   1%|▏         | 146/10000 [00:03<03:44, 43.93it/s, loss=5.37e-5, rmse_test=0.0192]
#
#
#
#
#
#
#   1%|▏         | 146/10000 [00:03<03:44, 43.93it/s, loss=4.67e-5, rmse_test=0.0165]
#
#
#
#
#
#
#   1%|▏         | 146/10000 [00:03<03:44, 43.93it/s, loss=4.55e-5, rmse_test=0.0152]
#
#
#
#
#
#
#   1%|▏         | 146/10000 [00:03<03:44, 43.93it/s, loss=3.44e-5, rmse_test=0.0191]
#
#
#
#
#
#
#   2%|▏         | 151/10000 [00:03<03:38, 45.09it/s, loss=3.44e-5, rmse_test=0.0191]
#
#
#
#
#
#
#   2%|▏         | 151/10000 [00:03<03:38, 45.09it/s, loss=2.72e-5, rmse_test=0.0145]
#
#
#
#
#
#
#   2%|▏         | 151/10000 [00:03<03:38, 45.09it/s, loss=3e-5, rmse_test=0.0212]
#
#
#
#
#
#
#   2%|▏         | 151/10000 [00:03<03:38, 45.09it/s, loss=4.28e-5, rmse_test=0.0218]
#
#
#
#
#
#
#   2%|▏         | 151/10000 [00:03<03:38, 45.09it/s, loss=3.16e-5, rmse_test=0.0145]
#
#
#
#
#
#
#   2%|▏         | 151/10000 [00:03<03:38, 45.09it/s, loss=5.17e-5, rmse_test=0.0142]
#
#
#
#
#
#
#   2%|▏         | 156/10000 [00:03<03:48, 43.17it/s, loss=5.17e-5, rmse_test=0.0142]
#
#
#
#
#
#
#   2%|▏         | 156/10000 [00:03<03:48, 43.17it/s, loss=3.63e-5, rmse_test=0.0369]
#
#
#
#
#
#
#   2%|▏         | 156/10000 [00:04<03:48, 43.17it/s, loss=4.97e-5, rmse_test=0.0163]
#
#
#
#
#
#
#   2%|▏         | 156/10000 [00:04<03:48, 43.17it/s, loss=6.22e-5, rmse_test=0.0153]
#
#
#
#
#
#
#   2%|▏         | 156/10000 [00:04<03:48, 43.17it/s, loss=3.64e-5, rmse_test=0.0162]
#
#
#
#
#
#
#   2%|▏         | 156/10000 [00:04<03:48, 43.17it/s, loss=4.59e-5, rmse_test=0.0186]
#
#
#
#
#
#
#   2%|▏         | 161/10000 [00:04<03:48, 43.15it/s, loss=4.59e-5, rmse_test=0.0186]
#
#
#
#
#
#
#   2%|▏         | 161/10000 [00:04<03:48, 43.15it/s, loss=4.75e-5, rmse_test=0.0166]
#
#
#
#
#
#
#   2%|▏         | 161/10000 [00:04<03:48, 43.15it/s, loss=5.3e-5, rmse_test=0.0337]
#
#
#
#
#
#
#   2%|▏         | 161/10000 [00:04<03:48, 43.15it/s, loss=5.81e-5, rmse_test=0.0191]
#
#
#
#
#
#
#   2%|▏         | 161/10000 [00:04<03:48, 43.15it/s, loss=5.34e-5, rmse_test=0.0177]
#
#
#
#
#
#
#   2%|▏         | 161/10000 [00:04<03:48, 43.15it/s, loss=6.23e-5, rmse_test=0.0211]
#
#
#
#
#
#
#   2%|▏         | 166/10000 [00:04<03:40, 44.53it/s, loss=6.23e-5, rmse_test=0.0211]
#
#
#
#
#
#
#   2%|▏         | 166/10000 [00:04<03:40, 44.53it/s, loss=5.02e-5, rmse_test=0.0217]
#
#
#
#
#
#
#   2%|▏         | 166/10000 [00:04<03:40, 44.53it/s, loss=4.13e-5, rmse_test=0.0155]
#
#
#
#
#
#
#   2%|▏         | 166/10000 [00:04<03:40, 44.53it/s, loss=6.29e-5, rmse_test=0.0245]
#
#
#
#
#
#
#   2%|▏         | 166/10000 [00:04<03:40, 44.53it/s, loss=5.2e-5, rmse_test=0.0158]
#
#
#
#
#
#
#   2%|▏         | 166/10000 [00:04<03:40, 44.53it/s, loss=4.89e-5, rmse_test=0.0149]
#
#
#
#
#
#
#   2%|▏         | 171/10000 [00:04<03:47, 43.26it/s, loss=4.89e-5, rmse_test=0.0149]
#
#
#
#
#
#
#   2%|▏         | 171/10000 [00:04<03:47, 43.26it/s, loss=5.09e-5, rmse_test=0.0198]
#
#
#
#
#
#
#   2%|▏         | 171/10000 [00:04<03:47, 43.26it/s, loss=3.92e-5, rmse_test=0.0199]
#
#
#
#
#
#
#   2%|▏         | 171/10000 [00:04<03:47, 43.26it/s, loss=4.43e-5, rmse_test=0.0127]
#
#
#
#
#
#
#   2%|▏         | 171/10000 [00:04<03:47, 43.26it/s, loss=7.23e-5, rmse_test=0.0145]
#
#
#
#
#
#
#   2%|▏         | 171/10000 [00:04<03:47, 43.26it/s, loss=5.9e-5, rmse_test=0.0381]
#
#
#
#
#
#
#   2%|▏         | 176/10000 [00:04<03:49, 42.76it/s, loss=5.9e-5, rmse_test=0.0381]
#
#
#
#
#
#
#   2%|▏         | 176/10000 [00:04<03:49, 42.76it/s, loss=4.62e-5, rmse_test=0.0216]
#
#
#
#
#
#
#   2%|▏         | 176/10000 [00:04<03:49, 42.76it/s, loss=4.98e-5, rmse_test=0.0192]
#
#
#
#
#
#
#   2%|▏         | 176/10000 [00:04<03:49, 42.76it/s, loss=7.49e-5, rmse_test=0.0139]
#
#
#
#
#
#
#   2%|▏         | 176/10000 [00:04<03:49, 42.76it/s, loss=5.08e-5, rmse_test=0.0135]
#
#
#
#
#
#
#   2%|▏         | 176/10000 [00:04<03:49, 42.76it/s, loss=4.72e-5, rmse_test=0.0166]
#
#
#
#
#
#
#   2%|▏         | 181/10000 [00:04<03:44, 43.71it/s, loss=4.72e-5, rmse_test=0.0166]
#
#
#
#
#
#
#   2%|▏         | 181/10000 [00:04<03:44, 43.71it/s, loss=5.3e-5, rmse_test=0.0164]
#   2%|▏         | 181/10000 [00:04<03:44, 43.71it/s, loss=6.19e-5, rmse_test=0.0179]
#
#
#
#
#
#
#   2%|▏         | 181/10000 [00:04<03:44, 43.71it/s, loss=4.51e-5, rmse_test=0.0233]
#
#
#
#
#
#
#   2%|▏         | 181/10000 [00:04<03:44, 43.71it/s, loss=7.27e-5, rmse_test=0.0182]
#
#
#
#
#
#
#   2%|▏         | 181/10000 [00:04<03:44, 43.71it/s, loss=4.38e-5, rmse_test=0.0145]
#
#
#
#
#
#
#   2%|▏         | 186/10000 [00:04<03:36, 45.41it/s, loss=4.38e-5, rmse_test=0.0145]
#
#
#
#
#
#
#   2%|▏         | 186/10000 [00:04<03:36, 45.41it/s, loss=5.01e-5, rmse_test=0.0168]
#
#
#
#
#
#
#   2%|▏         | 186/10000 [00:04<03:36, 45.41it/s, loss=5.98e-5, rmse_test=0.0134]
#
#
#
#
#
#
#   2%|▏         | 186/10000 [00:04<03:36, 45.41it/s, loss=6.83e-5, rmse_test=0.0337]
#
#
#
#
#
#
#   2%|▏         | 186/10000 [00:04<03:36, 45.41it/s, loss=4.37e-5, rmse_test=0.017]
#
#
#
#
#
#
#   2%|▏         | 186/10000 [00:04<03:36, 45.41it/s, loss=5.27e-5, rmse_test=0.0184]
#
#
#
#
#
#
#   2%|▏         | 191/10000 [00:04<03:39, 44.71it/s, loss=5.27e-5, rmse_test=0.0184]
#
#
#
#
#
#
#   2%|▏         | 191/10000 [00:04<03:39, 44.71it/s, loss=5.92e-5, rmse_test=0.0171]
#
#
#
#
#
#
#   2%|▏         | 191/10000 [00:04<03:39, 44.71it/s, loss=5.38e-5, rmse_test=0.0219]
#
#
#
#
#
#
#   2%|▏         | 191/10000 [00:04<03:39, 44.71it/s, loss=8.13e-5, rmse_test=0.0174]
#
#
#
#
#
#
#   2%|▏         | 191/10000 [00:04<03:39, 44.71it/s, loss=5.99e-5, rmse_test=0.0295]
#
#
#
#
#
#
#   2%|▏         | 191/10000 [00:04<03:39, 44.71it/s, loss=6.36e-5, rmse_test=0.0131]
#
#
#
#
#
#
#   2%|▏         | 196/10000 [00:04<03:39, 44.76it/s, loss=6.36e-5, rmse_test=0.0131]
#
#
#
#
#
#
#   2%|▏         | 196/10000 [00:04<03:39, 44.76it/s, loss=5.19e-5, rmse_test=0.0179]
#
#
#
#
#
#
#   2%|▏         | 196/10000 [00:04<03:39, 44.76it/s, loss=7.54e-5, rmse_test=0.0151]
#
#
#
#
#
#
#   2%|▏         | 196/10000 [00:04<03:39, 44.76it/s, loss=5.13e-5, rmse_test=0.0215]
#
#
#
#
#
#
#   2%|▏         | 196/10000 [00:04<03:39, 44.76it/s, loss=5.77e-5, rmse_test=0.0157]
#
#
#
#
#
#
#   2%|▏         | 196/10000 [00:05<03:39, 44.76it/s, loss=4.94e-5, rmse_test=0.0208]
#
#
#
#
#
#
#   2%|▏         | 201/10000 [00:05<04:08, 39.50it/s, loss=4.94e-5, rmse_test=0.0208]
#
#
#
#
#
#
#   2%|▏         | 201/10000 [00:05<04:08, 39.50it/s, loss=4.11e-5, rmse_test=0.0139]
#
#
#
#
#
#
#   2%|▏         | 201/10000 [00:05<04:08, 39.50it/s, loss=5.59e-5, rmse_test=0.0165]
#
#
#
#
#
#
#   2%|▏         | 201/10000 [00:05<04:08, 39.50it/s, loss=4.83e-5, rmse_test=0.0353]
#
#
#
#
#
#
#   2%|▏         | 201/10000 [00:05<04:08, 39.50it/s, loss=4.71e-5, rmse_test=0.0331]
#
#
#
#
#
#
#   2%|▏         | 201/10000 [00:05<04:08, 39.50it/s, loss=4.9e-5, rmse_test=0.0245]
#
#
#
#
#
#
#   2%|▏         | 206/10000 [00:05<03:54, 41.78it/s, loss=4.9e-5, rmse_test=0.0245]
#
#
#
#
#
#
#   2%|▏         | 206/10000 [00:05<03:54, 41.78it/s, loss=3.74e-5, rmse_test=0.02]
#
#
#
#
#
#
#   2%|▏         | 206/10000 [00:05<03:54, 41.78it/s, loss=4.71e-5, rmse_test=0.0158]
#
#
#
#
#
#
#   2%|▏         | 206/10000 [00:05<03:54, 41.78it/s, loss=6.74e-5, rmse_test=0.0162]
#
#
#
#
#
#
#   2%|▏         | 206/10000 [00:05<03:54, 41.78it/s, loss=6.32e-5, rmse_test=0.0184]
#
#
#
#
#
#
#   2%|▏         | 206/10000 [00:05<03:54, 41.78it/s, loss=5.97e-5, rmse_test=0.0149]
#
#
#
#
#
#
#   2%|▏         | 211/10000 [00:05<03:58, 41.00it/s, loss=5.97e-5, rmse_test=0.0149]
#
#
#
#
#
#
#   2%|▏         | 211/10000 [00:05<03:58, 41.00it/s, loss=5.18e-5, rmse_test=0.0166]
#
#
#
#
#
#
#   2%|▏         | 211/10000 [00:05<03:58, 41.00it/s, loss=6.05e-5, rmse_test=0.0262]
#
#
#
#
#
#
#   2%|▏         | 211/10000 [00:05<03:58, 41.00it/s, loss=3.75e-5, rmse_test=0.0126]
#
#
#
#
#
#
#   2%|▏         | 211/10000 [00:05<03:58, 41.00it/s, loss=4.57e-5, rmse_test=0.025]
#
#
#
#
#
#
#   2%|▏         | 211/10000 [00:05<03:58, 41.00it/s, loss=5.43e-5, rmse_test=0.0234]
#
#
#
#
#
#
#   2%|▏         | 216/10000 [00:05<04:01, 40.59it/s, loss=5.43e-5, rmse_test=0.0234]
#
#
#
#
#
#
#   2%|▏         | 216/10000 [00:05<04:01, 40.59it/s, loss=4.76e-5, rmse_test=0.0263]
#
#
#
#
#
#
#   2%|▏         | 216/10000 [00:05<04:01, 40.59it/s, loss=6.31e-5, rmse_test=0.00962]
#
#
#
#
#
#
#   2%|▏         | 216/10000 [00:05<04:01, 40.59it/s, loss=5.56e-5, rmse_test=0.0136]
#
#
#
#
#
#
#   2%|▏         | 216/10000 [00:05<04:01, 40.59it/s, loss=5.8e-5, rmse_test=0.0138]
#
#
#
#
#
#
#   2%|▏         | 216/10000 [00:05<04:01, 40.59it/s, loss=6.25e-5, rmse_test=0.0173]
#
#
#
#
#
#
#   2%|▏         | 221/10000 [00:05<03:57, 41.12it/s, loss=6.25e-5, rmse_test=0.0173]
#
#
#
#
#
#
#   2%|▏         | 221/10000 [00:05<03:57, 41.12it/s, loss=7.12e-5, rmse_test=0.0169]
#
#
#
#
#
#
#   2%|▏         | 221/10000 [00:05<03:57, 41.12it/s, loss=5.33e-5, rmse_test=0.0166]
#
#
#
#
#
#
#   2%|▏         | 221/10000 [00:05<03:57, 41.12it/s, loss=5.65e-5, rmse_test=0.0276]
#
#
#
#
#
#
#   2%|▏         | 221/10000 [00:05<03:57, 41.12it/s, loss=5.57e-5, rmse_test=0.0189]
#
#
#
#
#
#
#   2%|▏         | 221/10000 [00:05<03:57, 41.12it/s, loss=6.22e-5, rmse_test=0.018]
#
#
#
#
#
#
#   2%|▏         | 226/10000 [00:05<03:59, 40.89it/s, loss=6.22e-5, rmse_test=0.018]
#
#
#
#
#
#
#   2%|▏         | 226/10000 [00:05<03:59, 40.89it/s, loss=4.93e-5, rmse_test=0.0198]
#
#
#
#
#
#
#   2%|▏         | 226/10000 [00:05<03:59, 40.89it/s, loss=6.68e-5, rmse_test=0.0195]
#
#
#
#
#
#
#   2%|▏         | 226/10000 [00:05<03:59, 40.89it/s, loss=6.05e-5, rmse_test=0.0154]
#
#
#
#
#
#
#   2%|▏         | 226/10000 [00:05<03:59, 40.89it/s, loss=6.22e-5, rmse_test=0.0278]
#
#
#
#
#
#
#   2%|▏         | 226/10000 [00:05<03:59, 40.89it/s, loss=4.13e-5, rmse_test=0.0245]
#
#
#
#
#
#
#   2%|▏         | 231/10000 [00:05<03:59, 40.87it/s, loss=4.13e-5, rmse_test=0.0245]
#
#
#
#
#
#
#   2%|▏         | 231/10000 [00:05<03:59, 40.87it/s, loss=4.98e-5, rmse_test=0.0125]
#
#
#
#
#
#
#   2%|▏         | 231/10000 [00:05<03:59, 40.87it/s, loss=5.11e-5, rmse_test=0.0293]
#
#
#
#
#
#
#   2%|▏         | 231/10000 [00:05<03:59, 40.87it/s, loss=4.74e-5, rmse_test=0.0166]
#
#
#
#
#
#
#   2%|▏         | 231/10000 [00:05<03:59, 40.87it/s, loss=6.86e-5, rmse_test=0.0181]
#
#
#
#
#
#
#   2%|▏         | 231/10000 [00:05<03:59, 40.87it/s, loss=5.54e-5, rmse_test=0.0269]
#
#
#
#
#
#
#   2%|▏         | 236/10000 [00:05<04:10, 39.00it/s, loss=5.54e-5, rmse_test=0.0269]
#
#
#
#
#
#
#   2%|▏         | 236/10000 [00:05<04:10, 39.00it/s, loss=6.39e-5, rmse_test=0.0124]
#
#
#
#
#
#
#   2%|▏         | 236/10000 [00:05<04:10, 39.00it/s, loss=5.92e-5, rmse_test=0.0195]
#
#
#
#
#
#
#   2%|▏         | 236/10000 [00:05<04:10, 39.00it/s, loss=6.59e-5, rmse_test=0.0162]
#
#
#
#
#
#
#   2%|▏         | 236/10000 [00:05<04:10, 39.00it/s, loss=6.07e-5, rmse_test=0.0156]
#
#
#
#
#
#
#   2%|▏         | 236/10000 [00:05<04:10, 39.00it/s, loss=5.83e-5, rmse_test=0.0154]
#
#
#
#
#
#
#   2%|▏         | 241/10000 [00:05<03:55, 41.50it/s, loss=5.83e-5, rmse_test=0.0154]
#
#
#
#
#
#
#   2%|▏         | 241/10000 [00:06<03:55, 41.50it/s, loss=4.38e-5, rmse_test=0.0237]
#
#
#
#
#
#
#   2%|▏         | 241/10000 [00:06<03:55, 41.50it/s, loss=5.84e-5, rmse_test=0.0242]
#   2%|▏         | 241/10000 [00:06<03:55, 41.50it/s, loss=4.83e-5, rmse_test=0.017]
#
#
#
#
#
#
#   2%|▏         | 241/10000 [00:06<03:55, 41.50it/s, loss=5.99e-5, rmse_test=0.0147]
#
#
#
#
#
#
#   2%|▏         | 241/10000 [00:06<03:55, 41.50it/s, loss=4.94e-5, rmse_test=0.0325]
#
#
#
#
#
#
#   2%|▏         | 246/10000 [00:06<03:44, 43.49it/s, loss=4.94e-5, rmse_test=0.0325]
#
#
#
#
#
#
#   2%|▏         | 246/10000 [00:06<03:44, 43.49it/s, loss=4.17e-5, rmse_test=0.0187]
#
#
#
#
#
#
#   2%|▏         | 246/10000 [00:06<03:44, 43.49it/s, loss=5.57e-5, rmse_test=0.017]
#
#
#
#
#
#
#   2%|▏         | 246/10000 [00:06<03:44, 43.49it/s, loss=7.09e-5, rmse_test=0.0176]
#
#
#
#
#
#
#   2%|▏         | 246/10000 [00:06<03:44, 43.49it/s, loss=4.67e-5, rmse_test=0.0266]
#
#
#
#
#
#
#   2%|▏         | 246/10000 [00:06<03:44, 43.49it/s, loss=7.67e-5, rmse_test=0.0178]
#
#
#
#
#
#
#   3%|▎         | 251/10000 [00:06<04:00, 40.61it/s, loss=7.67e-5, rmse_test=0.0178]
#
#
#
#
#
#
#   3%|▎         | 251/10000 [00:06<04:00, 40.61it/s, loss=5.81e-5, rmse_test=0.0585]
#
#
#
#
#
#
#   3%|▎         | 251/10000 [00:06<04:00, 40.61it/s, loss=4.83e-5, rmse_test=0.0227]
#
#
#
#
#
#
#   3%|▎         | 251/10000 [00:06<04:00, 40.61it/s, loss=6e-5, rmse_test=0.0173]
#
#
#
#
#
#
#   3%|▎         | 251/10000 [00:06<04:00, 40.61it/s, loss=5.91e-5, rmse_test=0.033]
#
#
#
#
#
#
#   3%|▎         | 251/10000 [00:06<04:00, 40.61it/s, loss=5.05e-5, rmse_test=0.0199]
#
#
#
#
#
#
#   3%|▎         | 256/10000 [00:06<04:26, 36.51it/s, loss=5.05e-5, rmse_test=0.0199]
#
#
#
#
#
#
#   3%|▎         | 256/10000 [00:06<04:26, 36.51it/s, loss=5.24e-5, rmse_test=0.0241]
#
#
#
#
#
#
#   3%|▎         | 256/10000 [00:06<04:26, 36.51it/s, loss=5.26e-5, rmse_test=0.0156]
#
#
#
#
#
#
#   3%|▎         | 256/10000 [00:06<04:26, 36.51it/s, loss=5.95e-5, rmse_test=0.0148]
#
#
#
#
#
#
#   3%|▎         | 256/10000 [00:06<04:26, 36.51it/s, loss=4.25e-5, rmse_test=0.0409]
#
#
#
#
#
#
#   3%|▎         | 260/10000 [00:06<04:33, 35.55it/s, loss=4.25e-5, rmse_test=0.0409]
#
#
#
#
#
#
#   3%|▎         | 260/10000 [00:06<04:33, 35.55it/s, loss=6.26e-5, rmse_test=0.0422]
#
#
#
#
#
#
#   3%|▎         | 260/10000 [00:06<04:33, 35.55it/s, loss=6.31e-5, rmse_test=0.0198]
#
#
#
#
#
#
#   3%|▎         | 260/10000 [00:06<04:33, 35.55it/s, loss=4.37e-5, rmse_test=0.0171]
#
#
#
#
#
#
#   3%|▎         | 260/10000 [00:06<04:33, 35.55it/s, loss=7.07e-5, rmse_test=0.0136]
#
#
#
#
#
#
#   3%|▎         | 264/10000 [00:06<04:37, 35.06it/s, loss=7.07e-5, rmse_test=0.0136]
#
#
#
#
#
#
#   3%|▎         | 264/10000 [00:06<04:37, 35.06it/s, loss=6.37e-5, rmse_test=0.0142]
#
#
#
#
#
#
#   3%|▎         | 264/10000 [00:06<04:37, 35.06it/s, loss=6.98e-5, rmse_test=0.0186]
#
#
#
#
#
#
#   3%|▎         | 264/10000 [00:06<04:37, 35.06it/s, loss=4.34e-5, rmse_test=0.0158]
#
#
#
#
#
#
#   3%|▎         | 264/10000 [00:06<04:37, 35.06it/s, loss=5.36e-5, rmse_test=0.0206]
#
#
#
#
#
#
#   3%|▎         | 268/10000 [00:06<04:31, 35.88it/s, loss=5.36e-5, rmse_test=0.0206]
#
#
#
#
#
#
#   3%|▎         | 268/10000 [00:06<04:31, 35.88it/s, loss=5.97e-5, rmse_test=0.0205]
#
#
#
#
#
#
#   3%|▎         | 268/10000 [00:06<04:31, 35.88it/s, loss=4.74e-5, rmse_test=0.0297]
#
#
#
#
#
#
#   3%|▎         | 268/10000 [00:06<04:31, 35.88it/s, loss=6.83e-5, rmse_test=0.0224]
#
#
#
#
#
#
#   3%|▎         | 268/10000 [00:06<04:31, 35.88it/s, loss=4.17e-5, rmse_test=0.0128]
#
#
#
#
#
#
#   3%|▎         | 272/10000 [00:06<04:26, 36.54it/s, loss=4.17e-5, rmse_test=0.0128]
#
#
#
#
#
#
#   3%|▎         | 272/10000 [00:06<04:26, 36.54it/s, loss=4.52e-5, rmse_test=0.0282]
#
#
#
#
#
#
#   3%|▎         | 272/10000 [00:06<04:26, 36.54it/s, loss=6.51e-5, rmse_test=0.0267]
#
#
#
#
#
#
#   3%|▎         | 272/10000 [00:06<04:26, 36.54it/s, loss=5.98e-5, rmse_test=0.047]
#
#
#
#
#
#
#   3%|▎         | 272/10000 [00:06<04:26, 36.54it/s, loss=5.41e-5, rmse_test=0.0309]
#
#
#
#
#
#
#   3%|▎         | 276/10000 [00:06<04:36, 35.14it/s, loss=5.41e-5, rmse_test=0.0309]
#
#
#
#
#
#
#   3%|▎         | 276/10000 [00:07<04:36, 35.14it/s, loss=5.66e-5, rmse_test=0.0168]
#
#
#
#
#
#
#   3%|▎         | 276/10000 [00:07<04:36, 35.14it/s, loss=6.76e-5, rmse_test=0.0472]
#
#
#
#
#
#
#   3%|▎         | 276/10000 [00:07<04:36, 35.14it/s, loss=6.47e-5, rmse_test=0.0145]
#
#
#
#
#
#
#   3%|▎         | 276/10000 [00:07<04:36, 35.14it/s, loss=5.05e-5, rmse_test=0.0148]
#
#
#
#
#
#
#   3%|▎         | 280/10000 [00:07<04:33, 35.56it/s, loss=5.05e-5, rmse_test=0.0148]
#
#
#
#
#
#
#   3%|▎         | 280/10000 [00:07<04:33, 35.56it/s, loss=6.94e-5, rmse_test=0.0289]
#
#
#
#
#
#
#   3%|▎         | 280/10000 [00:07<04:33, 35.56it/s, loss=6.33e-5, rmse_test=0.0129]
#
#
#
#
#
#
#   3%|▎         | 280/10000 [00:07<04:33, 35.56it/s, loss=5.47e-5, rmse_test=0.0178]
#
#
#
#
#
#
#   3%|▎         | 280/10000 [00:07<04:33, 35.56it/s, loss=4.83e-5, rmse_test=0.0168]
#
#
#
#
#
#
#   3%|▎         | 284/10000 [00:07<04:28, 36.18it/s, loss=4.83e-5, rmse_test=0.0168]
#
#
#
#
#
#
#   3%|▎         | 284/10000 [00:07<04:28, 36.18it/s, loss=6.08e-5, rmse_test=0.0162]
#
#
#
#
#
#
#   3%|▎         | 284/10000 [00:07<04:28, 36.18it/s, loss=6.33e-5, rmse_test=0.0765]
#
#
#
#
#
#
#   3%|▎         | 284/10000 [00:07<04:28, 36.18it/s, loss=7.6e-5, rmse_test=0.0364]
#
#
#
#
#
#
#   3%|▎         | 284/10000 [00:07<04:28, 36.18it/s, loss=7.35e-5, rmse_test=0.02]
#
#
#
#
#
#
#   3%|▎         | 288/10000 [00:07<04:49, 33.57it/s, loss=7.35e-5, rmse_test=0.02]
#
#
#
#
#
#
#   3%|▎         | 288/10000 [00:07<04:49, 33.57it/s, loss=7.92e-5, rmse_test=0.0544]
#
#
#
#
#
#
#   3%|▎         | 288/10000 [00:07<04:49, 33.57it/s, loss=6e-5, rmse_test=0.0173]
#
#
#
#
#
#
#   3%|▎         | 288/10000 [00:07<04:49, 33.57it/s, loss=5.57e-5, rmse_test=0.0166]
#
#
#
#
#
#
#   3%|▎         | 288/10000 [00:07<04:49, 33.57it/s, loss=6.58e-5, rmse_test=0.016]
#
#
#
#
#
#
#   3%|▎         | 288/10000 [00:07<04:49, 33.57it/s, loss=7e-5, rmse_test=0.0146]
#
#
#
#
#
#
#   3%|▎         | 293/10000 [00:07<04:25, 36.60it/s, loss=7e-5, rmse_test=0.0146]
#
#
#
#
#
#
#   3%|▎         | 293/10000 [00:07<04:25, 36.60it/s, loss=6.7e-5, rmse_test=0.0686]
#
#
#
#
#
#
#   3%|▎         | 293/10000 [00:07<04:25, 36.60it/s, loss=5.44e-5, rmse_test=0.0488]
#
#
#
#
#
#
#   3%|▎         | 293/10000 [00:07<04:25, 36.60it/s, loss=6.76e-5, rmse_test=0.0146]
#
#
#
#
#
#
#   3%|▎         | 293/10000 [00:07<04:25, 36.60it/s, loss=6.26e-5, rmse_test=0.0329]
#
#
#
#
#
#
#   3%|▎         | 293/10000 [00:07<04:25, 36.60it/s, loss=6.09e-5, rmse_test=0.031]
#
#
#
#
#
#
#   3%|▎         | 298/10000 [00:07<04:12, 38.35it/s, loss=6.09e-5, rmse_test=0.031]
#
#
#
#
#
#
#   3%|▎         | 298/10000 [00:07<04:12, 38.35it/s, loss=7.26e-5, rmse_test=0.0437]
#
#
#
#
#
#
#   3%|▎         | 298/10000 [00:07<04:12, 38.35it/s, loss=4.06e-5, rmse_test=0.0414]
#
#
#
#
#
#
#   3%|▎         | 298/10000 [00:07<04:12, 38.35it/s, loss=4.85e-5, rmse_test=0.0339]
#
#
#
#
#
#
#   3%|▎         | 298/10000 [00:07<04:12, 38.35it/s, loss=7.21e-5, rmse_test=0.014]
#
#
#
#
#
#
#   3%|▎         | 302/10000 [00:07<04:46, 33.87it/s, loss=7.21e-5, rmse_test=0.014]
#   3%|▎         | 302/10000 [00:07<04:46, 33.87it/s, loss=6.28e-5, rmse_test=0.0165]
#
#
#
#
#
#
#   3%|▎         | 302/10000 [00:07<04:46, 33.87it/s, loss=6.72e-5, rmse_test=0.049]
#
#
#
#
#
#
#   3%|▎         | 302/10000 [00:07<04:46, 33.87it/s, loss=5.86e-5, rmse_test=0.00974]
#
#
#
#
#
#
#   3%|▎         | 302/10000 [00:07<04:46, 33.87it/s, loss=6.42e-5, rmse_test=0.0218]
#
#
#
#
#
#
#   3%|▎         | 306/10000 [00:07<04:44, 34.09it/s, loss=6.42e-5, rmse_test=0.0218]
#
#
#
#
#
#
#   3%|▎         | 306/10000 [00:07<04:44, 34.09it/s, loss=7.91e-5, rmse_test=0.0194]
#
#
#
#
#
#
#   3%|▎         | 306/10000 [00:07<04:44, 34.09it/s, loss=6.58e-5, rmse_test=0.0303]
#
#
#
#
#
#
#   3%|▎         | 306/10000 [00:07<04:44, 34.09it/s, loss=7.53e-5, rmse_test=0.0331]
#
#
#
#
#
#
#   3%|▎         | 306/10000 [00:07<04:44, 34.09it/s, loss=5.76e-5, rmse_test=0.0206]
#
#
#
#
#
#
#   3%|▎         | 310/10000 [00:07<04:40, 34.48it/s, loss=5.76e-5, rmse_test=0.0206]
#
#
#
#
#
#
#   3%|▎         | 310/10000 [00:07<04:40, 34.48it/s, loss=6.02e-5, rmse_test=0.0182]
#
#
#
#
#
#
#   3%|▎         | 310/10000 [00:07<04:40, 34.48it/s, loss=6.57e-5, rmse_test=0.0161]
#
#
#
#
#
#
#   3%|▎         | 310/10000 [00:08<04:40, 34.48it/s, loss=8.05e-5, rmse_test=0.0135]
#
#
#
#
#
#
#   3%|▎         | 310/10000 [00:08<04:40, 34.48it/s, loss=7.11e-5, rmse_test=0.0385]
#
#
#
#
#
#
#   3%|▎         | 310/10000 [00:08<04:40, 34.48it/s, loss=5.55e-5, rmse_test=0.0186]
#
#
#
#
#
#
#   3%|▎         | 315/10000 [00:08<04:19, 37.37it/s, loss=5.55e-5, rmse_test=0.0186]
#
#
#
#
#
#
#   3%|▎         | 315/10000 [00:08<04:19, 37.37it/s, loss=5.48e-5, rmse_test=0.0192]
#
#
#
#
#
#
#   3%|▎         | 315/10000 [00:08<04:19, 37.37it/s, loss=5.92e-5, rmse_test=0.0519]
#
#
#
#
#
#
#   3%|▎         | 315/10000 [00:08<04:19, 37.37it/s, loss=6.31e-5, rmse_test=0.00961]
#
#
#
#
#
#
#   3%|▎         | 315/10000 [00:08<04:19, 37.37it/s, loss=5.41e-5, rmse_test=0.0381]
#
#
#
#
#
#
#   3%|▎         | 315/10000 [00:08<04:19, 37.37it/s, loss=6.49e-5, rmse_test=0.0708]
#
#
#
#
#
#
#   3%|▎         | 320/10000 [00:08<04:11, 38.55it/s, loss=6.49e-5, rmse_test=0.0708]
#
#
#
#
#
#
#   3%|▎         | 320/10000 [00:08<04:11, 38.55it/s, loss=6.79e-5, rmse_test=0.0114]
#
#
#
#
#
#
#   3%|▎         | 320/10000 [00:08<04:11, 38.55it/s, loss=4.56e-5, rmse_test=0.0135]
#
#
#
#
#
#
#   3%|▎         | 320/10000 [00:08<04:11, 38.55it/s, loss=5.31e-5, rmse_test=0.0244]
#
#
#
#
#
#
#   3%|▎         | 320/10000 [00:08<04:11, 38.55it/s, loss=5.45e-5, rmse_test=0.0743]
#
#
#
#
#
#
#   3%|▎         | 324/10000 [00:08<04:18, 37.43it/s, loss=5.45e-5, rmse_test=0.0743]
#
#
#
#
#
#
#   3%|▎         | 324/10000 [00:08<04:18, 37.43it/s, loss=5.29e-5, rmse_test=0.0548]
#
#
#
#
#
#
#   3%|▎         | 324/10000 [00:08<04:18, 37.43it/s, loss=4.65e-5, rmse_test=0.0153]
#
#
#
#
#
#
#   3%|▎         | 324/10000 [00:08<04:18, 37.43it/s, loss=4.88e-5, rmse_test=0.0426]
#
#
#
#
#
#
#   3%|▎         | 324/10000 [00:08<04:18, 37.43it/s, loss=4.9e-5, rmse_test=0.0403]
#
#
#
#
#
#
#   3%|▎         | 324/10000 [00:08<04:18, 37.43it/s, loss=6.25e-5, rmse_test=0.0213]
#
#
#
#
#
#
#   3%|▎         | 329/10000 [00:08<04:08, 38.88it/s, loss=6.25e-5, rmse_test=0.0213]
#
#
#
#
#
#
#   3%|▎         | 329/10000 [00:08<04:08, 38.88it/s, loss=6.16e-5, rmse_test=0.0373]
#
#
#
#
#
#
#   3%|▎         | 329/10000 [00:08<04:08, 38.88it/s, loss=5.84e-5, rmse_test=0.0252]
#
#
#
#
#
#
#   3%|▎         | 329/10000 [00:08<04:08, 38.88it/s, loss=4.96e-5, rmse_test=0.0261]
#
#
#
#
#
#
#   3%|▎         | 329/10000 [00:08<04:08, 38.88it/s, loss=5.72e-5, rmse_test=0.02]
#
#
#
#
#
#
#   3%|▎         | 333/10000 [00:08<04:14, 37.94it/s, loss=5.72e-5, rmse_test=0.02]
#
#
#
#
#
#
#   3%|▎         | 333/10000 [00:08<04:14, 37.94it/s, loss=5.16e-5, rmse_test=0.0117]
#
#
#
#
#
#
#   3%|▎         | 333/10000 [00:08<04:14, 37.94it/s, loss=8.75e-5, rmse_test=0.0339]
#
#
#
#
#
#
#   3%|▎         | 333/10000 [00:08<04:14, 37.94it/s, loss=5.67e-5, rmse_test=0.0199]
#
#
#
#
#
#
#   3%|▎         | 333/10000 [00:08<04:14, 37.94it/s, loss=6.32e-5, rmse_test=0.0719]
#
#
#
#
#
#
#   3%|▎         | 337/10000 [00:08<04:23, 36.71it/s, loss=6.32e-5, rmse_test=0.0719]
#
#
#
#
#
#
#   3%|▎         | 337/10000 [00:08<04:23, 36.71it/s, loss=5.14e-5, rmse_test=0.0521]
#
#
#
#
#
#
#   3%|▎         | 337/10000 [00:08<04:23, 36.71it/s, loss=7.13e-5, rmse_test=0.0214]
#
#
#
#
#
#
#   3%|▎         | 337/10000 [00:08<04:23, 36.71it/s, loss=3.34e-5, rmse_test=0.0114]
#
#
#
#
#
#
#   3%|▎         | 337/10000 [00:08<04:23, 36.71it/s, loss=4.38e-5, rmse_test=0.0157]
#
#
#
#
#
#
#   3%|▎         | 337/10000 [00:08<04:23, 36.71it/s, loss=7.07e-5, rmse_test=0.0257]
#
#
#
#
#
#
#   3%|▎         | 342/10000 [00:08<04:16, 37.72it/s, loss=7.07e-5, rmse_test=0.0257]
#
#
#
#
#
#
#   3%|▎         | 342/10000 [00:08<04:16, 37.72it/s, loss=6.55e-5, rmse_test=0.0254]
#
#
#
#
#
#
#   3%|▎         | 342/10000 [00:08<04:16, 37.72it/s, loss=5.9e-5, rmse_test=0.0189]
#
#
#
#
#
#
#   3%|▎         | 342/10000 [00:08<04:16, 37.72it/s, loss=5.4e-5, rmse_test=0.0161]
#
#
#
#
#
#
#   3%|▎         | 342/10000 [00:08<04:16, 37.72it/s, loss=5.31e-5, rmse_test=0.0153]
#
#
#
#
#
#
#   3%|▎         | 346/10000 [00:08<04:15, 37.79it/s, loss=5.31e-5, rmse_test=0.0153]
#
#
#
#
#
#
#   3%|▎         | 346/10000 [00:08<04:15, 37.79it/s, loss=7.25e-5, rmse_test=0.0141]
#
#
#
#
#
#
#   3%|▎         | 346/10000 [00:08<04:15, 37.79it/s, loss=8.17e-5, rmse_test=0.0222]
#
#
#
#
#
#
#   3%|▎         | 346/10000 [00:08<04:15, 37.79it/s, loss=4.37e-5, rmse_test=0.0141]
#
#
#
#
#
#
#   3%|▎         | 346/10000 [00:08<04:15, 37.79it/s, loss=5.75e-5, rmse_test=0.0489]
#
#
#
#
#
#
#   4%|▎         | 350/10000 [00:08<04:19, 37.24it/s, loss=5.75e-5, rmse_test=0.0489]
#
#
#
#
#
#
#   4%|▎         | 350/10000 [00:08<04:19, 37.24it/s, loss=5.58e-5, rmse_test=0.0675]
#
#
#
#
#
#
#   4%|▎         | 350/10000 [00:09<04:19, 37.24it/s, loss=5.34e-5, rmse_test=0.0677]
#
#
#
#
#
#
#   4%|▎         | 350/10000 [00:09<04:19, 37.24it/s, loss=5.61e-5, rmse_test=0.059]
#
#
#
#
#
#
#   4%|▎         | 350/10000 [00:09<04:19, 37.24it/s, loss=6.65e-5, rmse_test=0.0307]
#
#
#
#
#
#
#   4%|▎         | 354/10000 [00:09<04:27, 36.04it/s, loss=6.65e-5, rmse_test=0.0307]
#
#
#
#
#
#
#   4%|▎         | 354/10000 [00:09<04:27, 36.04it/s, loss=6.16e-5, rmse_test=0.0653]
#
#
#
#
#
#
#   4%|▎         | 354/10000 [00:09<04:27, 36.04it/s, loss=5.3e-5, rmse_test=0.0312]
#
#
#
#
#
#
#   4%|▎         | 354/10000 [00:09<04:27, 36.04it/s, loss=5.99e-5, rmse_test=0.0197]
#
#
#
#
#
#
#   4%|▎         | 354/10000 [00:09<04:27, 36.04it/s, loss=6.54e-5, rmse_test=0.0279]
#
#
#
#
#
#
#   4%|▎         | 358/10000 [00:09<04:38, 34.57it/s, loss=6.54e-5, rmse_test=0.0279]
#
#
#
#
#
#
#   4%|▎         | 358/10000 [00:09<04:38, 34.57it/s, loss=7.75e-5, rmse_test=0.0137]
#
#
#
#
#
#
#   4%|▎         | 358/10000 [00:09<04:38, 34.57it/s, loss=4.91e-5, rmse_test=0.0201]
#
#
#
#
#
#
#   4%|▎         | 358/10000 [00:09<04:38, 34.57it/s, loss=8.55e-5, rmse_test=0.036]
#
#
#
#
#
#
#   4%|▎         | 358/10000 [00:09<04:38, 34.57it/s, loss=7.21e-5, rmse_test=0.0186]
#   4%|▎         | 362/10000 [00:09<04:33, 35.20it/s, loss=7.21e-5, rmse_test=0.0186]
#
#
#
#
#
#
#   4%|▎         | 362/10000 [00:09<04:33, 35.20it/s, loss=5.26e-5, rmse_test=0.0245]
#
#
#
#
#
#
#   4%|▎         | 362/10000 [00:09<04:33, 35.20it/s, loss=7.12e-5, rmse_test=0.0251]
#
#
#
#
#
#
#   4%|▎         | 362/10000 [00:09<04:33, 35.20it/s, loss=6.25e-5, rmse_test=0.0172]
#
#
#
#
#
#
#   4%|▎         | 362/10000 [00:09<04:33, 35.20it/s, loss=5.71e-5, rmse_test=0.0199]
#
#
#
#
#
#
#   4%|▎         | 366/10000 [00:09<04:27, 35.95it/s, loss=5.71e-5, rmse_test=0.0199]
#
#
#
#
#
#
#   4%|▎         | 366/10000 [00:09<04:27, 35.95it/s, loss=7.49e-5, rmse_test=0.041]
#
#
#
#
#
#
#   4%|▎         | 366/10000 [00:09<04:27, 35.95it/s, loss=7.78e-5, rmse_test=0.0172]
#
#
#
#
#
#
#   4%|▎         | 366/10000 [00:09<04:27, 35.95it/s, loss=4.67e-5, rmse_test=0.023]
#
#
#
#
#
#
#   4%|▎         | 366/10000 [00:09<04:27, 35.95it/s, loss=6.34e-5, rmse_test=0.0124]
#
#
#
#
#
#
#   4%|▎         | 366/10000 [00:09<04:27, 35.95it/s, loss=5.02e-5, rmse_test=0.0208]
#
#
#
#
#
#
#   4%|▎         | 371/10000 [00:09<04:05, 39.15it/s, loss=5.02e-5, rmse_test=0.0208]
#
#
#
#
#
#
#   4%|▎         | 371/10000 [00:09<04:05, 39.15it/s, loss=5.31e-5, rmse_test=0.0202]
#
#
#
#
#
#
#   4%|▎         | 371/10000 [00:09<04:05, 39.15it/s, loss=5.14e-5, rmse_test=0.0278]
#
#
#
#
#
#
#   4%|▎         | 371/10000 [00:09<04:05, 39.15it/s, loss=6.34e-5, rmse_test=0.0342]
#
#
#
#
#
#
#   4%|▎         | 371/10000 [00:09<04:05, 39.15it/s, loss=5.63e-5, rmse_test=0.0224]
#
#
#
#
#
#
#   4%|▎         | 371/10000 [00:09<04:05, 39.15it/s, loss=8.54e-5, rmse_test=0.0255]
#
#
#
#
#
#
#   4%|▍         | 376/10000 [00:09<04:11, 38.33it/s, loss=8.54e-5, rmse_test=0.0255]
#
#
#
#
#
#
#   4%|▍         | 376/10000 [00:09<04:11, 38.33it/s, loss=7.37e-5, rmse_test=0.0247]
#
#
#
#
#
#
#   4%|▍         | 376/10000 [00:09<04:11, 38.33it/s, loss=6.22e-5, rmse_test=0.0819]
#
#
#
#
#
#
#   4%|▍         | 376/10000 [00:09<04:11, 38.33it/s, loss=6.9e-5, rmse_test=0.0413]
#
#
#
#
#
#
#   4%|▍         | 376/10000 [00:09<04:11, 38.33it/s, loss=6.38e-5, rmse_test=0.0128]
#
#
#
#
#
#
#   4%|▍         | 376/10000 [00:09<04:11, 38.33it/s, loss=7.23e-5, rmse_test=0.0129]
#
#
#
#
#
#
#   4%|▍         | 381/10000 [00:09<04:00, 40.01it/s, loss=7.23e-5, rmse_test=0.0129]
#
#
#
#
#
#
#   4%|▍         | 381/10000 [00:09<04:00, 40.01it/s, loss=5.95e-5, rmse_test=0.0789]
#
#
#
#
#
#
#   4%|▍         | 381/10000 [00:09<04:00, 40.01it/s, loss=5.79e-5, rmse_test=0.0118]
#
#
#
#
#
#
#   4%|▍         | 381/10000 [00:09<04:00, 40.01it/s, loss=7.69e-5, rmse_test=0.0121]
#
#
#
#
#
#
#   4%|▍         | 381/10000 [00:09<04:00, 40.01it/s, loss=5.5e-5, rmse_test=0.0236]
#
#
#
#
#
#
#   4%|▍         | 381/10000 [00:09<04:00, 40.01it/s, loss=5.67e-5, rmse_test=0.0136]
#
#
#
#
#
#
#   4%|▍         | 386/10000 [00:09<04:02, 39.69it/s, loss=5.67e-5, rmse_test=0.0136]
#
#
#
#
#
#
#   4%|▍         | 386/10000 [00:09<04:02, 39.69it/s, loss=4.9e-5, rmse_test=0.0514]
#
#
#
#
#
#
#   4%|▍         | 386/10000 [00:09<04:02, 39.69it/s, loss=6.86e-5, rmse_test=0.111]
#
#
#
#
#
#
#   4%|▍         | 386/10000 [00:09<04:02, 39.69it/s, loss=6.68e-5, rmse_test=0.0204]
#
#
#
#
#
#
#   4%|▍         | 386/10000 [00:09<04:02, 39.69it/s, loss=6.57e-5, rmse_test=0.0362]
#
#
#
#
#
#
#   4%|▍         | 386/10000 [00:10<04:02, 39.69it/s, loss=5.55e-5, rmse_test=0.0162]
#
#
#
#
#
#
#   4%|▍         | 391/10000 [00:10<03:54, 40.97it/s, loss=5.55e-5, rmse_test=0.0162]
#
#
#
#
#
#
#   4%|▍         | 391/10000 [00:10<03:54, 40.97it/s, loss=6.87e-5, rmse_test=0.0387]
#
#
#
#
#
#
#   4%|▍         | 391/10000 [00:10<03:54, 40.97it/s, loss=7.28e-5, rmse_test=0.0896]
#
#
#
#
#
#
#   4%|▍         | 391/10000 [00:10<03:54, 40.97it/s, loss=6.32e-5, rmse_test=0.00803]
#
#
#
#
#
#
#   4%|▍         | 391/10000 [00:10<03:54, 40.97it/s, loss=6.79e-5, rmse_test=0.0526]
#
#
#
#
#
#
#   4%|▍         | 391/10000 [00:10<03:54, 40.97it/s, loss=7.69e-5, rmse_test=0.0104]
#
#
#
#
#
#
#   4%|▍         | 396/10000 [00:10<03:47, 42.13it/s, loss=7.69e-5, rmse_test=0.0104]
#
#
#
#
#
#
#   4%|▍         | 396/10000 [00:10<03:47, 42.13it/s, loss=4.74e-5, rmse_test=0.022]
#
#
#
#
#
#
#   4%|▍         | 396/10000 [00:10<03:47, 42.13it/s, loss=6.88e-5, rmse_test=0.0256]
#
#
#
#
#
#
#   4%|▍         | 396/10000 [00:10<03:47, 42.13it/s, loss=4.18e-5, rmse_test=0.032]
#
#
#
#
#
#
#   4%|▍         | 396/10000 [00:10<03:47, 42.13it/s, loss=6.2e-5, rmse_test=0.0149]
#
#
#
#
#
#
#   4%|▍         | 396/10000 [00:10<03:47, 42.13it/s, loss=5.87e-5, rmse_test=0.0138]
#
#
#
#
#
#
#   4%|▍         | 401/10000 [00:10<04:21, 36.64it/s, loss=5.87e-5, rmse_test=0.0138]
#
#
#
#
#
#
#   4%|▍         | 401/10000 [00:10<04:21, 36.64it/s, loss=7.11e-5, rmse_test=0.0481]
#
#
#
#
#
#
#   4%|▍         | 401/10000 [00:10<04:21, 36.64it/s, loss=5.43e-5, rmse_test=0.0153]
#
#
#
#
#
#
#   4%|▍         | 401/10000 [00:10<04:21, 36.64it/s, loss=7.13e-5, rmse_test=0.0134]
#
#
#
#
#
#
#   4%|▍         | 401/10000 [00:10<04:21, 36.64it/s, loss=4.71e-5, rmse_test=0.0708]
#
#
#
#
#
#
#   4%|▍         | 401/10000 [00:10<04:21, 36.64it/s, loss=6.82e-5, rmse_test=0.0904]
#
#
#
#
#
#
#   4%|▍         | 406/10000 [00:10<04:07, 38.83it/s, loss=6.82e-5, rmse_test=0.0904]
#
#
#
#
#
#
#   4%|▍         | 406/10000 [00:10<04:07, 38.83it/s, loss=7.38e-5, rmse_test=0.0829]
#
#
#
#
#
#
#   4%|▍         | 406/10000 [00:10<04:07, 38.83it/s, loss=5.17e-5, rmse_test=0.0221]
#
#
#
#
#
#
#   4%|▍         | 406/10000 [00:10<04:07, 38.83it/s, loss=4.78e-5, rmse_test=0.0172]
#
#
#
#
#
#
#   4%|▍         | 406/10000 [00:10<04:07, 38.83it/s, loss=5.78e-5, rmse_test=0.0517]
#
#
#
#
#
#
#   4%|▍         | 406/10000 [00:10<04:07, 38.83it/s, loss=7.26e-5, rmse_test=0.0314]
#
#
#
#
#
#
#   4%|▍         | 411/10000 [00:10<04:07, 38.72it/s, loss=7.26e-5, rmse_test=0.0314]
#
#
#
#
#
#
#   4%|▍         | 411/10000 [00:10<04:07, 38.72it/s, loss=6.11e-5, rmse_test=0.0289]
#
#
#
#
#
#
#   4%|▍         | 411/10000 [00:10<04:07, 38.72it/s, loss=7.64e-5, rmse_test=0.0138]
#
#
#
#
#
#
#   4%|▍         | 411/10000 [00:10<04:07, 38.72it/s, loss=4.5e-5, rmse_test=0.0201]
#
#
#
#
#
#
#   4%|▍         | 411/10000 [00:10<04:07, 38.72it/s, loss=6.54e-5, rmse_test=0.0387]
#
#
#
#
#
#
#   4%|▍         | 411/10000 [00:10<04:07, 38.72it/s, loss=7.44e-5, rmse_test=0.0256]
#
#
#
#
#
#
#   4%|▍         | 416/10000 [00:10<04:02, 39.56it/s, loss=7.44e-5, rmse_test=0.0256]
#
#
#
#
#
#
#   4%|▍         | 416/10000 [00:10<04:02, 39.56it/s, loss=6.96e-5, rmse_test=0.0715]
#
#
#
#
#
#
#   4%|▍         | 416/10000 [00:10<04:02, 39.56it/s, loss=7.32e-5, rmse_test=0.14]
#
#
#
#
#
#
#   4%|▍         | 416/10000 [00:10<04:02, 39.56it/s, loss=6.58e-5, rmse_test=0.0184]
#
#
#
#
#
#
#   4%|▍         | 416/10000 [00:10<04:02, 39.56it/s, loss=7.39e-5, rmse_test=0.0246]
#
#
#
#
#
#
#   4%|▍         | 416/10000 [00:10<04:02, 39.56it/s, loss=5.56e-5, rmse_test=0.0249]
#
#
#
#
#
#
#   4%|▍         | 421/10000 [00:10<04:05, 39.08it/s, loss=5.56e-5, rmse_test=0.0249]
#
#
#
#
#
#
#   4%|▍         | 421/10000 [00:10<04:05, 39.08it/s, loss=6.03e-5, rmse_test=0.0647]
#   4%|▍         | 421/10000 [00:10<04:05, 39.08it/s, loss=5.81e-5, rmse_test=0.0197]
#
#
#
#
#
#
#   4%|▍         | 421/10000 [00:10<04:05, 39.08it/s, loss=4.94e-5, rmse_test=0.0378]
#
#
#
#
#
#
#   4%|▍         | 421/10000 [00:10<04:05, 39.08it/s, loss=6.09e-5, rmse_test=0.0114]
#
#
#
#
#
#
#   4%|▍         | 421/10000 [00:10<04:05, 39.08it/s, loss=7.25e-5, rmse_test=0.105]
#
#
#
#
#
#
#   4%|▍         | 426/10000 [00:10<03:59, 40.02it/s, loss=7.25e-5, rmse_test=0.105]
#
#
#
#
#
#
#   4%|▍         | 426/10000 [00:10<03:59, 40.02it/s, loss=6.52e-5, rmse_test=0.0632]
#
#
#
#
#
#
#   4%|▍         | 426/10000 [00:10<03:59, 40.02it/s, loss=8.49e-5, rmse_test=0.128]
#
#
#
#
#
#
#   4%|▍         | 426/10000 [00:10<03:59, 40.02it/s, loss=6.34e-5, rmse_test=0.0181]
#
#
#
#
#
#
#   4%|▍         | 426/10000 [00:11<03:59, 40.02it/s, loss=6.33e-5, rmse_test=0.0229]
#
#
#
#
#
#
#   4%|▍         | 426/10000 [00:11<03:59, 40.02it/s, loss=6.51e-5, rmse_test=0.0282]
#
#
#
#
#
#
#   4%|▍         | 431/10000 [00:11<04:02, 39.40it/s, loss=6.51e-5, rmse_test=0.0282]
#
#
#
#
#
#
#   4%|▍         | 431/10000 [00:11<04:02, 39.40it/s, loss=8.58e-5, rmse_test=0.0168]
#
#
#
#
#
#
#   4%|▍         | 431/10000 [00:11<04:02, 39.40it/s, loss=7.63e-5, rmse_test=0.0225]
#
#
#
#
#
#
#   4%|▍         | 431/10000 [00:11<04:02, 39.40it/s, loss=6.42e-5, rmse_test=0.0217]
#
#
#
#
#
#
#   4%|▍         | 431/10000 [00:11<04:02, 39.40it/s, loss=5.82e-5, rmse_test=0.0508]
#
#
#
#
#
#
#   4%|▍         | 431/10000 [00:11<04:02, 39.40it/s, loss=7.18e-5, rmse_test=0.0131]
#
#
#
#
#
#
#   4%|▍         | 436/10000 [00:11<03:50, 41.50it/s, loss=7.18e-5, rmse_test=0.0131]
#
#
#
#
#
#
#   4%|▍         | 436/10000 [00:11<03:50, 41.50it/s, loss=5.46e-5, rmse_test=0.0381]
#
#
#
#
#
#
#   4%|▍         | 436/10000 [00:11<03:50, 41.50it/s, loss=5.97e-5, rmse_test=0.0458]
#
#
#
#
#
#
#   4%|▍         | 436/10000 [00:11<03:50, 41.50it/s, loss=4.64e-5, rmse_test=0.018]
#
#
#
#
#
#
#   4%|▍         | 436/10000 [00:11<03:50, 41.50it/s, loss=5.7e-5, rmse_test=0.06]
#
#
#
#
#
#
#   4%|▍         | 436/10000 [00:11<03:50, 41.50it/s, loss=4.57e-5, rmse_test=0.041]
#
#
#
#
#
#
#   4%|▍         | 441/10000 [00:11<03:43, 42.74it/s, loss=4.57e-5, rmse_test=0.041]
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#  12%|█▏        | 1190/10000 [00:30<04:04, 35.98it/s, loss=2.36e-7, rmse_test=0.00741]
#
#
#
#
#
#
#  12%|█▏        | 1190/10000 [00:30<04:04, 35.98it/s, loss=2.03e-7, rmse_test=0.00646]
#
#
#
#
#
#
#  12%|█▏        | 1190/10000 [00:30<04:04, 35.98it/s, loss=1.82e-7, rmse_test=0.00654]
#
#
#
#
#
#
#  12%|█▏        | 1190/10000 [00:30<04:04, 35.98it/s, loss=1.64e-7, rmse_test=0.00649]
#
#
#
#
#
#
#  12%|█▏        | 1190/10000 [00:30<04:04, 35.98it/s, loss=1.46e-7, rmse_test=0.00651]
#
#
#
#
#
#
#  12%|█▏        | 1195/10000 [00:30<03:49, 38.43it/s, loss=1.46e-7, rmse_test=0.00651]
#
#
#
#
#
#
#  12%|█▏        | 1195/10000 [00:30<03:49, 38.43it/s, loss=1.3e-7, rmse_test=0.00675]
#
#
#
#
#
#
#  12%|█▏        | 1195/10000 [00:30<03:49, 38.43it/s, loss=1.19e-7, rmse_test=0.00671]
#
#
#
#
#
#
#  12%|█▏        | 1195/10000 [00:30<03:49, 38.43it/s, loss=1.08e-7, rmse_test=0.00655]
#
#
#
#
#
#
#  12%|█▏        | 1195/10000 [00:30<03:49, 38.43it/s, loss=9.96e-8, rmse_test=0.00654]
#
#
#
#
#
#
#  12%|█▏        | 1195/10000 [00:30<03:49, 38.43it/s, loss=9.21e-8, rmse_test=0.00657]
#
#
#
#
#
#
#  12%|█▏        | 1200/10000 [00:30<05:33, 26.42it/s, loss=9.21e-8, rmse_test=0.00657]
#
#
#
#
#
#
#  12%|█▏        | 1200/10000 [00:30<05:33, 26.42it/s, loss=8.55e-8, rmse_test=0.00661]
#
#
#
#
#
#
#  12%|█▏        | 1200/10000 [00:30<05:33, 26.42it/s, loss=7.95e-8, rmse_test=0.00648]
#
#
#
#
#
#
#  12%|█▏        | 1200/10000 [00:30<05:33, 26.42it/s, loss=7.27e-8, rmse_test=0.00648]
#
#
#
#
#
#
#  12%|█▏        | 1200/10000 [00:30<05:33, 26.42it/s, loss=6.63e-8, rmse_test=0.00641]
#
#
#
#
#
#
#  12%|█▏        | 1200/10000 [00:30<05:33, 26.42it/s, loss=5.88e-8, rmse_test=0.00638]
#
#
#
#
#
#
#  12%|█▏        | 1205/10000 [00:30<04:46, 30.68it/s, loss=5.88e-8, rmse_test=0.00638]
#
#
#
#
#
#
#  12%|█▏        | 1205/10000 [00:30<04:46, 30.68it/s, loss=5.5e-8, rmse_test=0.00658]
#
#
#
#
#
#
#  12%|█▏        | 1205/10000 [00:30<04:46, 30.68it/s, loss=5.16e-8, rmse_test=0.00633]
#
#
#
#
#
#
#  12%|█▏        | 1205/10000 [00:30<04:46, 30.68it/s, loss=4.68e-8, rmse_test=0.00649]
#
#
#
#
#
#
#  12%|█▏        | 1205/10000 [00:30<04:46, 30.68it/s, loss=4.26e-8, rmse_test=0.00664]
#
#
#
#
#
#
#  12%|█▏        | 1205/10000 [00:30<04:46, 30.68it/s, loss=4.01e-8, rmse_test=0.00657]
#
#
#
#
#
#
#  12%|█▏        | 1210/10000 [00:30<04:23, 33.38it/s, loss=4.01e-8, rmse_test=0.00657]
#  12%|█▏        | 1210/10000 [00:30<04:23, 33.38it/s, loss=3.71e-8, rmse_test=0.00725]
#
#
#
#
#
#
#  12%|█▏        | 1210/10000 [00:31<04:23, 33.38it/s, loss=3.53e-8, rmse_test=0.00634]
#
#
#
#
#
#
#  12%|█▏        | 1210/10000 [00:31<04:23, 33.38it/s, loss=3.35e-8, rmse_test=0.00622]
#
#
#
#
#
#
#  12%|█▏        | 1210/10000 [00:31<04:23, 33.38it/s, loss=3.19e-8, rmse_test=0.0063]
#
#
#
#
#
#
#  12%|█▏        | 1210/10000 [00:31<04:23, 33.38it/s, loss=3.04e-8, rmse_test=0.00632]
#
#
#
#
#
#
#  12%|█▏        | 1215/10000 [00:31<04:06, 35.66it/s, loss=3.04e-8, rmse_test=0.00632]
#
#
#
#
#
#
#  12%|█▏        | 1215/10000 [00:31<04:06, 35.66it/s, loss=2.9e-8, rmse_test=0.0067]
#
#
#
#
#
#
#  12%|█▏        | 1215/10000 [00:31<04:06, 35.66it/s, loss=2.77e-8, rmse_test=0.00628]
#
#
#
#
#
#
#  12%|█▏        | 1215/10000 [00:31<04:06, 35.66it/s, loss=2.64e-8, rmse_test=0.0063]
#
#
#
#
#
#
#  12%|█▏        | 1215/10000 [00:31<04:06, 35.66it/s, loss=2.49e-8, rmse_test=0.00637]
#
#
#
#
#
#
#  12%|█▏        | 1215/10000 [00:31<04:06, 35.66it/s, loss=2.36e-8, rmse_test=0.00641]
#
#
#
#
#
#
#  12%|█▏        | 1220/10000 [00:31<03:53, 37.53it/s, loss=2.36e-8, rmse_test=0.00641]
#
#
#
#
#
#
#  12%|█▏        | 1220/10000 [00:31<03:53, 37.53it/s, loss=2.23e-8, rmse_test=0.00649]
#
#
#
#
#
#
#  12%|█▏        | 1220/10000 [00:31<03:53, 37.53it/s, loss=2.14e-8, rmse_test=0.0067]
#
#
#
#
#
#
#  12%|█▏        | 1220/10000 [00:31<03:53, 37.53it/s, loss=2.06e-8, rmse_test=0.00632]
#
#
#
#
#
#
#  12%|█▏        | 1220/10000 [00:31<03:53, 37.53it/s, loss=1.97e-8, rmse_test=0.00646]
#
#
#
#
#
#
#  12%|█▏        | 1220/10000 [00:31<03:53, 37.53it/s, loss=1.85e-8, rmse_test=0.00658]
#
#
#
#
#
#
#  12%|█▏        | 1225/10000 [00:31<03:45, 38.96it/s, loss=1.85e-8, rmse_test=0.00658]
#
#
#
#
#
#
#  12%|█▏        | 1225/10000 [00:31<03:45, 38.96it/s, loss=1.78e-8, rmse_test=0.00647]
#
#
#
#
#
#
#  12%|█▏        | 1225/10000 [00:31<03:45, 38.96it/s, loss=1.7e-8, rmse_test=0.00644]
#
#
#
#
#
#
#  12%|█▏        | 1225/10000 [00:31<03:45, 38.96it/s, loss=1.64e-8, rmse_test=0.00647]
#
#
#
#
#
#
#  12%|█▏        | 1225/10000 [00:31<03:45, 38.96it/s, loss=1.59e-8, rmse_test=0.00771]
#
#
#
#
#
#
#  12%|█▏        | 1225/10000 [00:31<03:45, 38.96it/s, loss=1.54e-8, rmse_test=0.00673]
#
#
#
#
#
#
#  12%|█▏        | 1230/10000 [00:31<03:36, 40.44it/s, loss=1.54e-8, rmse_test=0.00673]
#
#
#
#
#
#
#  12%|█▏        | 1230/10000 [00:31<03:36, 40.44it/s, loss=1.5e-8, rmse_test=0.00628]
#
#
#
#
#
#
#  12%|█▏        | 1230/10000 [00:31<03:36, 40.44it/s, loss=1.45e-8, rmse_test=0.00635]
#
#
#
#
#
#
#  12%|█▏        | 1230/10000 [00:31<03:36, 40.44it/s, loss=1.4e-8, rmse_test=0.00642]
#
#
#
#
#
#
#  12%|█▏        | 1230/10000 [00:31<03:36, 40.44it/s, loss=1.34e-8, rmse_test=0.00644]
#
#
#
#
#
#
#  12%|█▏        | 1230/10000 [00:31<03:36, 40.44it/s, loss=1.29e-8, rmse_test=0.00633]
#
#
#
#
#
#
#  12%|█▏        | 1235/10000 [00:31<03:40, 39.66it/s, loss=1.29e-8, rmse_test=0.00633]
#
#
#
#
#
#
#  12%|█▏        | 1235/10000 [00:31<03:40, 39.66it/s, loss=1.25e-8, rmse_test=0.0063]
#
#
#
#
#
#
#  12%|█▏        | 1235/10000 [00:31<03:40, 39.66it/s, loss=1.14e-8, rmse_test=0.00642]
#
#
#
#
#
#
#  12%|█▏        | 1235/10000 [00:31<03:40, 39.66it/s, loss=1.09e-8, rmse_test=0.00655]
#
#
#
#
#
#
#  12%|█▏        | 1235/10000 [00:31<03:40, 39.66it/s, loss=1.07e-8, rmse_test=0.0065]
#
#
#
#
#
#
#  12%|█▏        | 1235/10000 [00:31<03:40, 39.66it/s, loss=1.04e-8, rmse_test=0.00647]
#
#
#
#
#
#
#  12%|█▏        | 1240/10000 [00:31<03:33, 41.12it/s, loss=1.04e-8, rmse_test=0.00647]
#
#
#
#
#
#
#  12%|█▏        | 1240/10000 [00:31<03:33, 41.12it/s, loss=1.02e-8, rmse_test=0.00674]
#
#
#
#
#
#
#  12%|█▏        | 1240/10000 [00:31<03:33, 41.12it/s, loss=1.01e-8, rmse_test=0.00643]
#
#
#
#
#
#
#  12%|█▏        | 1240/10000 [00:31<03:33, 41.12it/s, loss=9.82e-9, rmse_test=0.00653]
#
#
#
#
#
#
#  12%|█▏        | 1240/10000 [00:31<03:33, 41.12it/s, loss=9.62e-9, rmse_test=0.00665]
#
#
#
#
#
#
#  12%|█▏        | 1240/10000 [00:31<03:33, 41.12it/s, loss=9.26e-9, rmse_test=0.00647]
#
#
#
#
#
#
#  12%|█▏        | 1245/10000 [00:31<03:32, 41.20it/s, loss=9.26e-9, rmse_test=0.00647]
#
#
#
#
#
#
#  12%|█▏        | 1245/10000 [00:31<03:32, 41.20it/s, loss=9.05e-9, rmse_test=0.00647]
#
#
#
#
#
#
#  12%|█▏        | 1245/10000 [00:31<03:32, 41.20it/s, loss=8.89e-9, rmse_test=0.0065]
#
#
#
#
#
#
#  12%|█▏        | 1245/10000 [00:31<03:32, 41.20it/s, loss=8.72e-9, rmse_test=0.00661]
#
#
#
#
#
#
#  12%|█▏        | 1245/10000 [00:31<03:32, 41.20it/s, loss=8.61e-9, rmse_test=0.00671]
#
#
#
#
#
#
#  12%|█▏        | 1245/10000 [00:31<03:32, 41.20it/s, loss=8.47e-9, rmse_test=0.00642]
#
#
#
#
#
#
#  12%|█▎        | 1250/10000 [00:31<03:45, 38.74it/s, loss=8.47e-9, rmse_test=0.00642]
#
#
#
#
#
#
#  12%|█▎        | 1250/10000 [00:31<03:45, 38.74it/s, loss=8.33e-9, rmse_test=0.00653]
#
#
#
#
#
#
#  12%|█▎        | 1250/10000 [00:31<03:45, 38.74it/s, loss=8.19e-9, rmse_test=0.00668]
#
#
#
#
#
#
#  12%|█▎        | 1250/10000 [00:32<03:45, 38.74it/s, loss=8.1e-9, rmse_test=0.00656]
#
#
#
#
#
#
#  12%|█▎        | 1250/10000 [00:32<03:45, 38.74it/s, loss=7.92e-9, rmse_test=0.00666]
#
#
#
#
#
#
#  13%|█▎        | 1254/10000 [00:32<03:46, 38.54it/s, loss=7.92e-9, rmse_test=0.00666]
#
#
#
#
#
#
#  13%|█▎        | 1254/10000 [00:32<03:46, 38.54it/s, loss=7.8e-9, rmse_test=0.00658]
#
#
#
#
#
#
#  13%|█▎        | 1254/10000 [00:32<03:46, 38.54it/s, loss=7.66e-9, rmse_test=0.00622]
#
#
#
#
#
#
#  13%|█▎        | 1254/10000 [00:32<03:46, 38.54it/s, loss=7.6e-9, rmse_test=0.00627]
#
#
#
#
#
#
#  13%|█▎        | 1254/10000 [00:32<03:46, 38.54it/s, loss=7.46e-9, rmse_test=0.00667]
#
#
#
#
#
#
#  13%|█▎        | 1254/10000 [00:32<03:46, 38.54it/s, loss=7.41e-9, rmse_test=0.00647]
#
#
#
#
#
#
#  13%|█▎        | 1259/10000 [00:32<03:36, 40.46it/s, loss=7.41e-9, rmse_test=0.00647]
#
#
#
#
#
#
#  13%|█▎        | 1259/10000 [00:32<03:36, 40.46it/s, loss=7.27e-9, rmse_test=0.00645]
#
#
#
#
#
#
#  13%|█▎        | 1259/10000 [00:32<03:36, 40.46it/s, loss=7.17e-9, rmse_test=0.00648]
#
#
#
#
#
#
#  13%|█▎        | 1259/10000 [00:32<03:36, 40.46it/s, loss=7.13e-9, rmse_test=0.00664]
#
#
#
#
#
#
#  13%|█▎        | 1259/10000 [00:32<03:36, 40.46it/s, loss=7.06e-9, rmse_test=0.00656]
#
#
#
#
#
#
#  13%|█▎        | 1259/10000 [00:32<03:36, 40.46it/s, loss=6.9e-9, rmse_test=0.00652]
#
#
#
#
#
#
#  13%|█▎        | 1264/10000 [00:32<03:23, 42.88it/s, loss=6.9e-9, rmse_test=0.00652]
#
#
#
#
#
#
#  13%|█▎        | 1264/10000 [00:32<03:23, 42.88it/s, loss=6.78e-9, rmse_test=0.00674]
#
#
#
#
#
#
#  13%|█▎        | 1264/10000 [00:32<03:23, 42.88it/s, loss=6.76e-9, rmse_test=0.00647]
#
#
#
#
#
#
#  13%|█▎        | 1264/10000 [00:32<03:23, 42.88it/s, loss=6.67e-9, rmse_test=0.00659]
#
#
#
#
#
#
#  13%|█▎        | 1264/10000 [00:32<03:23, 42.88it/s, loss=6.62e-9, rmse_test=0.00648]
#
#
#
#
#
#
#  13%|█▎        | 1264/10000 [00:32<03:23, 42.88it/s, loss=6.52e-9, rmse_test=0.00668]
#
#
#
#
#
#
#  13%|█▎        | 1269/10000 [00:32<03:21, 43.36it/s, loss=6.52e-9, rmse_test=0.00668]
#
#
#
#
#
#
#  13%|█▎        | 1269/10000 [00:32<03:21, 43.36it/s, loss=6.53e-9, rmse_test=0.00664]
#  13%|█▎        | 1269/10000 [00:32<03:21, 43.36it/s, loss=6.44e-9, rmse_test=0.00631]
#
#
#
#
#
#
#  13%|█▎        | 1269/10000 [00:32<03:21, 43.36it/s, loss=6.38e-9, rmse_test=0.0065]
#
#
#
#
#
#
#  13%|█▎        | 1269/10000 [00:32<03:21, 43.36it/s, loss=6.39e-9, rmse_test=0.00637]
#
#
#
#
#
#
#  13%|█▎        | 1269/10000 [00:32<03:21, 43.36it/s, loss=6.26e-9, rmse_test=0.00647]
#
#
#
#
#
#
#  13%|█▎        | 1274/10000 [00:32<03:41, 39.34it/s, loss=6.26e-9, rmse_test=0.00647]
#
#
#
#
#
#
#  13%|█▎        | 1274/10000 [00:32<03:41, 39.34it/s, loss=6.22e-9, rmse_test=0.00676]
#
#
#
#
#
#
#  13%|█▎        | 1274/10000 [00:32<03:41, 39.34it/s, loss=6.25e-9, rmse_test=0.00663]
#
#
#
#
#
#
#  13%|█▎        | 1274/10000 [00:32<03:41, 39.34it/s, loss=6.31e-9, rmse_test=0.00672]
#
#
#
#
#
#
#  13%|█▎        | 1274/10000 [00:32<03:41, 39.34it/s, loss=6.2e-9, rmse_test=0.00657]
#
#
#
#
#
#
#  13%|█▎        | 1274/10000 [00:32<03:41, 39.34it/s, loss=6.1e-9, rmse_test=0.00653]
#
#
#
#
#
#
#  13%|█▎        | 1279/10000 [00:32<03:44, 38.91it/s, loss=6.1e-9, rmse_test=0.00653]
#
#
#
#
#
#
#  13%|█▎        | 1279/10000 [00:32<03:44, 38.91it/s, loss=6.05e-9, rmse_test=0.00658]
#
#
#
#
#
#
#  13%|█▎        | 1279/10000 [00:32<03:44, 38.91it/s, loss=6.05e-9, rmse_test=0.00732]
#
#
#
#
#
#
#  13%|█▎        | 1279/10000 [00:32<03:44, 38.91it/s, loss=5.98e-9, rmse_test=0.00673]
#
#
#
#
#
#
#  13%|█▎        | 1279/10000 [00:32<03:44, 38.91it/s, loss=6.07e-9, rmse_test=0.00635]
#
#
#
#
#
#
#  13%|█▎        | 1283/10000 [00:32<03:44, 38.80it/s, loss=6.07e-9, rmse_test=0.00635]
#
#
#
#
#
#
#  13%|█▎        | 1283/10000 [00:32<03:44, 38.80it/s, loss=5.96e-9, rmse_test=0.0079]
#
#
#
#
#
#
#  13%|█▎        | 1283/10000 [00:32<03:44, 38.80it/s, loss=5.93e-9, rmse_test=0.00707]
#
#
#
#
#
#
#  13%|█▎        | 1283/10000 [00:32<03:44, 38.80it/s, loss=5.87e-9, rmse_test=0.00645]
#
#
#
#
#
#
#  13%|█▎        | 1283/10000 [00:32<03:44, 38.80it/s, loss=5.87e-9, rmse_test=0.00633]
#
#
#
#
#
#
#  13%|█▎        | 1287/10000 [00:32<03:42, 39.15it/s, loss=5.87e-9, rmse_test=0.00633]
#
#
#
#
#
#
#  13%|█▎        | 1287/10000 [00:32<03:42, 39.15it/s, loss=5.8e-9, rmse_test=0.00639]
#
#
#
#
#
#
#  13%|█▎        | 1287/10000 [00:32<03:42, 39.15it/s, loss=5.8e-9, rmse_test=0.00634]
#
#
#
#
#
#
#  13%|█▎        | 1287/10000 [00:32<03:42, 39.15it/s, loss=5.82e-9, rmse_test=0.00635]
#
#
#
#
#
#
#  13%|█▎        | 1287/10000 [00:32<03:42, 39.15it/s, loss=5.85e-9, rmse_test=0.00641]
#
#
#
#
#
#
#  13%|█▎        | 1291/10000 [00:32<03:45, 38.61it/s, loss=5.85e-9, rmse_test=0.00641]
#
#
#
#
#
#
#  13%|█▎        | 1291/10000 [00:32<03:45, 38.61it/s, loss=5.84e-9, rmse_test=0.0064]
#
#
#
#
#
#
#  13%|█▎        | 1291/10000 [00:33<03:45, 38.61it/s, loss=5.75e-9, rmse_test=0.0064]
#
#
#
#
#
#
#  13%|█▎        | 1291/10000 [00:33<03:45, 38.61it/s, loss=5.75e-9, rmse_test=0.00667]
#
#
#
#
#
#
#  13%|█▎        | 1291/10000 [00:33<03:45, 38.61it/s, loss=5.74e-9, rmse_test=0.00777]
#
#
#
#
#
#
#  13%|█▎        | 1295/10000 [00:33<03:47, 38.30it/s, loss=5.74e-9, rmse_test=0.00777]
#
#
#
#
#
#
#  13%|█▎        | 1295/10000 [00:33<03:47, 38.30it/s, loss=5.82e-9, rmse_test=0.00639]
#
#
#
#
#
#
#  13%|█▎        | 1295/10000 [00:33<03:47, 38.30it/s, loss=5.85e-9, rmse_test=0.00648]
#
#
#
#
#
#
#  13%|█▎        | 1295/10000 [00:33<03:47, 38.30it/s, loss=5.74e-9, rmse_test=0.00647]
#
#
#
#
#
#
#  13%|█▎        | 1295/10000 [00:33<03:47, 38.30it/s, loss=5.7e-9, rmse_test=0.00669]
#
#
#
#
#
#
#  13%|█▎        | 1299/10000 [00:33<03:47, 38.23it/s, loss=5.7e-9, rmse_test=0.00669]
#
#
#
#
#
#
#  13%|█▎        | 1299/10000 [00:33<03:47, 38.23it/s, loss=5.96e-9, rmse_test=0.00636]
#
#
#
#
#
#
#  13%|█▎        | 1299/10000 [00:33<03:47, 38.23it/s, loss=5.79e-9, rmse_test=0.00641]
#
#
#
#
#
#
#  13%|█▎        | 1299/10000 [00:33<03:47, 38.23it/s, loss=5.83e-9, rmse_test=0.00645]
#
#
#
#
#
#
#  13%|█▎        | 1299/10000 [00:33<03:47, 38.23it/s, loss=5.7e-9, rmse_test=0.0065]
#
#
#
#
#
#
#  13%|█▎        | 1303/10000 [00:33<06:25, 22.57it/s, loss=5.7e-9, rmse_test=0.0065]
#
#
#
#
#
#
#  13%|█▎        | 1303/10000 [00:33<06:25, 22.57it/s, loss=5.65e-9, rmse_test=0.00656]
#
#
#
#
#
#
#  13%|█▎        | 1303/10000 [00:33<06:25, 22.57it/s, loss=5.63e-9, rmse_test=0.00669]
#
#
#
#
#
#
#  13%|█▎        | 1303/10000 [00:33<06:25, 22.57it/s, loss=5.66e-9, rmse_test=0.00637]
#
#
#
#
#
#
#  13%|█▎        | 1303/10000 [00:33<06:25, 22.57it/s, loss=5.65e-9, rmse_test=0.00653]
#
#
#
#
#
#
#  13%|█▎        | 1307/10000 [00:33<05:48, 24.92it/s, loss=5.65e-9, rmse_test=0.00653]
#
#
#
#
#
#
#  13%|█▎        | 1307/10000 [00:33<05:48, 24.92it/s, loss=5.65e-9, rmse_test=0.00734]
#
#
#
#
#
#
#  13%|█▎        | 1307/10000 [00:33<05:48, 24.92it/s, loss=5.66e-9, rmse_test=0.00639]
#
#
#
#
#
#
#  13%|█▎        | 1307/10000 [00:33<05:48, 24.92it/s, loss=5.65e-9, rmse_test=0.00635]
#
#
#
#
#
#
#  13%|█▎        | 1307/10000 [00:33<05:48, 24.92it/s, loss=5.62e-9, rmse_test=0.00645]
#
#
#
#
#
#
#  13%|█▎        | 1311/10000 [00:33<05:12, 27.77it/s, loss=5.62e-9, rmse_test=0.00645]
#
#
#
#
#
#
#  13%|█▎        | 1311/10000 [00:33<05:12, 27.77it/s, loss=5.58e-9, rmse_test=0.00749]
#
#
#
#
#
#
#  13%|█▎        | 1311/10000 [00:33<05:12, 27.77it/s, loss=5.58e-9, rmse_test=0.00641]
#
#
#
#
#
#
#  13%|█▎        | 1311/10000 [00:33<05:12, 27.77it/s, loss=5.64e-9, rmse_test=0.00677]
#
#
#
#
#
#
#  13%|█▎        | 1311/10000 [00:33<05:12, 27.77it/s, loss=5.64e-9, rmse_test=0.0065]
#
#
#
#
#
#
#  13%|█▎        | 1315/10000 [00:33<04:54, 29.48it/s, loss=5.64e-9, rmse_test=0.0065]
#
#
#
#
#
#
#  13%|█▎        | 1315/10000 [00:33<04:54, 29.48it/s, loss=5.69e-9, rmse_test=0.00637]
#
#
#
#
#
#
#  13%|█▎        | 1315/10000 [00:33<04:54, 29.48it/s, loss=5.64e-9, rmse_test=0.00637]
#
#
#
#
#
#
#  13%|█▎        | 1315/10000 [00:33<04:54, 29.48it/s, loss=5.86e-9, rmse_test=0.00628]
#
#
#
#
#
#
#  13%|█▎        | 1315/10000 [00:33<04:54, 29.48it/s, loss=5.68e-9, rmse_test=0.00675]
#
#
#
#
#
#
#  13%|█▎        | 1315/10000 [00:33<04:54, 29.48it/s, loss=5.72e-9, rmse_test=0.00616]
#
#
#
#
#
#
#  13%|█▎        | 1320/10000 [00:33<04:30, 32.14it/s, loss=5.72e-9, rmse_test=0.00616]
#
#
#
#
#
#
#  13%|█▎        | 1320/10000 [00:34<04:30, 32.14it/s, loss=5.61e-9, rmse_test=0.00654]
#
#
#
#
#
#
#  13%|█▎        | 1320/10000 [00:34<04:30, 32.14it/s, loss=5.63e-9, rmse_test=0.00626]
#
#
#
#
#
#
#  13%|█▎        | 1320/10000 [00:34<04:30, 32.14it/s, loss=5.68e-9, rmse_test=0.00656]
#
#
#
#
#
#
#  13%|█▎        | 1320/10000 [00:34<04:30, 32.14it/s, loss=5.82e-9, rmse_test=0.00729]
#
#
#
#
#
#
#  13%|█▎        | 1320/10000 [00:34<04:30, 32.14it/s, loss=5.63e-9, rmse_test=0.00649]
#
#
#
#
#
#
#  13%|█▎        | 1325/10000 [00:34<04:01, 35.87it/s, loss=5.63e-9, rmse_test=0.00649]
#
#
#
#
#
#
#  13%|█▎        | 1325/10000 [00:34<04:01, 35.87it/s, loss=5.65e-9, rmse_test=0.00631]
#
#
#
#
#
#
#  13%|█▎        | 1325/10000 [00:34<04:01, 35.87it/s, loss=5.61e-9, rmse_test=0.00707]
#
#
#
#
#
#
#  13%|█▎        | 1325/10000 [00:34<04:01, 35.87it/s, loss=5.59e-9, rmse_test=0.00649]
#
#
#
#
#
#
#  13%|█▎        | 1325/10000 [00:34<04:01, 35.87it/s, loss=5.66e-9, rmse_test=0.00681]
#  13%|█▎        | 1325/10000 [00:34<04:01, 35.87it/s, loss=5.75e-9, rmse_test=0.00684]
#
#
#
#
#
#
#  13%|█▎        | 1330/10000 [00:34<03:54, 36.96it/s, loss=5.75e-9, rmse_test=0.00684]
#
#
#
#
#
#
#  13%|█▎        | 1330/10000 [00:34<03:54, 36.96it/s, loss=5.84e-9, rmse_test=0.00644]
#
#
#
#
#
#
#  13%|█▎        | 1330/10000 [00:34<03:54, 36.96it/s, loss=5.68e-9, rmse_test=0.00631]
#
#
#
#
#
#
#  13%|█▎        | 1330/10000 [00:34<03:54, 36.96it/s, loss=5.62e-9, rmse_test=0.0064]
#
#
#
#
#
#
#  13%|█▎        | 1330/10000 [00:34<03:54, 36.96it/s, loss=5.61e-9, rmse_test=0.00667]

# %%
run train_xstnn.py --dataset heat --outputdir output_heat --manualSeed 5718 --xp stnn_r --mode refine --patience 800 --l1_rel 1e-8
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#   0%|          | 0/10000 [00:00<?, ?it/s, loss=0.139, rmse_test=0.253]
#
#
#
#
#
#
#
#   0%|          | 0/10000 [00:00<?, ?it/s, loss=0.138, rmse_test=0.252]
#
#
#
#
#
#
#
#   0%|          | 0/10000 [00:00<?, ?it/s, loss=0.138, rmse_test=0.254]
#
#
#
#
#
#
#
#   0%|          | 3/10000 [00:00<07:42, 21.62it/s, loss=0.138, rmse_test=0.254]
#
#
#
#
#
#
#
#   0%|          | 3/10000 [00:00<07:42, 21.62it/s, loss=0.137, rmse_test=0.255]
#
#
#
#
#
#
#
#   0%|          | 3/10000 [00:00<07:42, 21.62it/s, loss=0.135, rmse_test=0.255]
#
#
#
#
#
#
#
#   0%|          | 3/10000 [00:00<07:42, 21.62it/s, loss=0.133, rmse_test=0.255]
#
#
#
#
#
#
#
#   0%|          | 6/10000 [00:00<07:33, 22.03it/s, loss=0.133, rmse_test=0.255]
#
#
#
#
#
#
#
#   0%|          | 6/10000 [00:00<07:33, 22.03it/s, loss=0.131, rmse_test=0.253]
#
#
#
#
#
#
#
#   0%|          | 6/10000 [00:00<07:33, 22.03it/s, loss=0.128, rmse_test=0.25]
#
#
#
#
#
#
#
#   0%|          | 6/10000 [00:00<07:33, 22.03it/s, loss=0.125, rmse_test=0.244]
#
#
#
#
#
#
#
#   0%|          | 9/10000 [00:00<07:04, 23.54it/s, loss=0.125, rmse_test=0.244]
#
#
#
#
#
#
#
#   0%|          | 9/10000 [00:00<07:04, 23.54it/s, loss=0.122, rmse_test=0.236]
#
#
#
#
#
#
#
#   0%|          | 9/10000 [00:00<07:04, 23.54it/s, loss=0.118, rmse_test=0.224]
#
#
#
#
#
#
#
#   0%|          | 9/10000 [00:00<07:04, 23.54it/s, loss=0.114, rmse_test=0.216]
#
#
#
#
#
#
#
#   0%|          | 12/10000 [00:00<06:50, 24.32it/s, loss=0.114, rmse_test=0.216]
#
#
#
#
#
#
#
#   0%|          | 12/10000 [00:00<06:50, 24.32it/s, loss=0.11, rmse_test=0.198]
#
#
#
#
#
#
#
#   0%|          | 12/10000 [00:00<06:50, 24.32it/s, loss=0.106, rmse_test=0.205]
#
#
#
#
#
#
#
#   0%|          | 12/10000 [00:00<06:50, 24.32it/s, loss=0.101, rmse_test=0.192]
#
#
#
#
#
#
#
#   0%|          | 15/10000 [00:00<06:31, 25.52it/s, loss=0.101, rmse_test=0.192]
#
#
#
#
#
#
#
#   0%|          | 15/10000 [00:00<06:31, 25.52it/s, loss=0.0963, rmse_test=0.17]
#
#
#
#
#
#
#
#   0%|          | 15/10000 [00:00<06:31, 25.52it/s, loss=0.0917, rmse_test=0.181]
#
#
#
#
#
#
#
#   0%|          | 15/10000 [00:00<06:31, 25.52it/s, loss=0.0871, rmse_test=0.179]
#
#
#
#
#
#
#
#   0%|          | 18/10000 [00:00<06:44, 24.69it/s, loss=0.0871, rmse_test=0.179]
#
#
#
#
#
#
#
#   0%|          | 18/10000 [00:00<06:44, 24.69it/s, loss=0.0824, rmse_test=0.115]
#
#
#
#
#
#
#
#   0%|          | 18/10000 [00:00<06:44, 24.69it/s, loss=0.0778, rmse_test=0.137]
#
#
#
#
#
#
#
#   0%|          | 18/10000 [00:00<06:44, 24.69it/s, loss=0.0733, rmse_test=0.164]
#
#
#
#
#
#
#
#   0%|          | 21/10000 [00:00<06:46, 24.56it/s, loss=0.0733, rmse_test=0.164]
#
#
#
#
#
#
#
#   0%|          | 21/10000 [00:00<06:46, 24.56it/s, loss=0.069, rmse_test=0.11]
#
#
#
#
#
#
#
#   0%|          | 21/10000 [00:00<06:46, 24.56it/s, loss=0.0646, rmse_test=0.101]
#
#
#
#
#
#
#
#   0%|          | 21/10000 [00:00<06:46, 24.56it/s, loss=0.0606, rmse_test=0.152]
#
#
#
#
#
#
#
#   0%|          | 24/10000 [00:00<06:36, 25.14it/s, loss=0.0606, rmse_test=0.152]
#
#
#
#
#
#
#
#   0%|          | 24/10000 [00:01<06:36, 25.14it/s, loss=0.0564, rmse_test=0.0903]
#
#
#
#
#
#
#
#   0%|          | 24/10000 [00:01<06:36, 25.14it/s, loss=0.0525, rmse_test=0.132]
#
#
#
#
#
#
#
#   0%|          | 24/10000 [00:01<06:36, 25.14it/s, loss=0.0488, rmse_test=0.101]
#
#
#
#
#
#
#
#   0%|          | 27/10000 [00:01<06:50, 24.30it/s, loss=0.0488, rmse_test=0.101]
#
#
#
#
#
#
#
#   0%|          | 27/10000 [00:01<06:50, 24.30it/s, loss=0.0452, rmse_test=0.126]
#
#
#
#
#
#
#
#   0%|          | 27/10000 [00:01<06:50, 24.30it/s, loss=0.0419, rmse_test=0.281]
#
#
#
#
#
#
#
#   0%|          | 27/10000 [00:01<06:50, 24.30it/s, loss=0.0388, rmse_test=0.14]
#
#
#
#
#
#
#
#   0%|          | 30/10000 [00:01<06:46, 24.52it/s, loss=0.0388, rmse_test=0.14]
#
#
#
#
#
#
#
#   0%|          | 30/10000 [00:01<06:46, 24.52it/s, loss=0.0359, rmse_test=0.079]
#
#
#
#
#
#
#
#   0%|          | 30/10000 [00:01<06:46, 24.52it/s, loss=0.0331, rmse_test=0.16]
#
#
#
#
#
#
#
#   0%|          | 30/10000 [00:01<06:46, 24.52it/s, loss=0.0305, rmse_test=0.0579]
#
#
#
#
#
#
#
#   0%|          | 33/10000 [00:01<06:38, 25.01it/s, loss=0.0305, rmse_test=0.0579]
#
#
#
#
#
#
#
#   0%|          | 33/10000 [00:01<06:38, 25.01it/s, loss=0.028, rmse_test=0.168]
#
#
#
#
#
#
#
#   0%|          | 33/10000 [00:01<06:38, 25.01it/s, loss=0.0258, rmse_test=0.0704]
#
#
#
#
#
#
#
#   0%|          | 33/10000 [00:01<06:38, 25.01it/s, loss=0.0237, rmse_test=0.0877]
#
#
#
#
#
#
#
#   0%|          | 36/10000 [00:01<06:42, 24.77it/s, loss=0.0237, rmse_test=0.0877]
#
#
#
#
#
#
#
#   0%|          | 36/10000 [00:01<06:42, 24.77it/s, loss=0.0218, rmse_test=1.23]
#
#
#
#
#
#
#
#   0%|          | 36/10000 [00:01<06:42, 24.77it/s, loss=0.0201, rmse_test=0.109]
#
#
#
#
#
#
#
#   0%|          | 36/10000 [00:01<06:42, 24.77it/s, loss=0.0185, rmse_test=0.0425]
#
#
#
#
#
#
#
#   0%|          | 39/10000 [00:01<06:26, 25.75it/s, loss=0.0185, rmse_test=0.0425]
#
#
#
#
#
#
#
#   0%|          | 39/10000 [00:01<06:26, 25.75it/s, loss=0.017, rmse_test=0.109]
#
#
#
#
#
#
#
#   0%|          | 39/10000 [00:01<06:26, 25.75it/s, loss=0.0156, rmse_test=0.081]
#
#
#
#
#
#
#
#   0%|          | 39/10000 [00:01<06:26, 25.75it/s, loss=0.0143, rmse_test=0.153]
#
#
#
#
#
#
#
#   0%|          | 42/10000 [00:01<06:47, 24.46it/s, loss=0.0143, rmse_test=0.153]
#
#
#
#
#
#
#
#   0%|          | 42/10000 [00:01<06:47, 24.46it/s, loss=0.013, rmse_test=0.0683]
#
#
#
#
#
#
#
#   0%|          | 42/10000 [00:01<06:47, 24.46it/s, loss=0.0119, rmse_test=0.131]
#
#
#
#
#
#
#
#   0%|          | 42/10000 [00:01<06:47, 24.46it/s, loss=0.0109, rmse_test=0.0415]
#
#
#
#
#
#
#
#   0%|          | 45/10000 [00:01<06:39, 24.90it/s, loss=0.0109, rmse_test=0.0415]
#
#
#
#
#
#
#
#   0%|          | 45/10000 [00:01<06:39, 24.90it/s, loss=0.00997, rmse_test=0.0503]
#
#
#
#
#
#
#
#   0%|          | 45/10000 [00:01<06:39, 24.90it/s, loss=0.00917, rmse_test=0.124]
#
#
#
#
#
#
#
#   0%|          | 45/10000 [00:01<06:39, 24.90it/s, loss=0.00843, rmse_test=0.9]
#
#
#
#
#
#
#
#   0%|          | 48/10000 [00:01<06:26, 25.73it/s, loss=0.00843, rmse_test=0.9]
#
#
#
#
#
#
#
#   0%|          | 48/10000 [00:01<06:26, 25.73it/s, loss=0.00778, rmse_test=0.121]
#
#
#
#
#
#
#
#   0%|          | 48/10000 [00:02<06:26, 25.73it/s, loss=0.00716, rmse_test=0.169]
#
#
#
#
#
#
#
#   0%|          | 48/10000 [00:02<06:26, 25.73it/s, loss=0.00656, rmse_test=0.164]
#
#
#
#
#
#
#
#   1%|          | 51/10000 [00:02<06:36, 25.09it/s, loss=0.00656, rmse_test=0.164]
#
#
#
#
#
#
#
#   1%|          | 51/10000 [00:02<06:36, 25.09it/s, loss=0.00605, rmse_test=0.476]
#
#
#
#
#
#
#
#   1%|          | 51/10000 [00:02<06:36, 25.09it/s, loss=0.00561, rmse_test=0.537]
#
#
#
#
#
#
#  13%|█▎        | 1330/10000 [00:53<03:54, 36.96it/s, loss=5.61e-9, rmse_test=0.00667]
#
#
#
#
#
#
#
#   1%|          | 51/10000 [00:02<06:36, 25.09it/s, loss=0.00514, rmse_test=0.113]
#   1%|          | 54/10000 [00:02<07:51, 21.09it/s, loss=0.00514, rmse_test=0.113]
#
#
#
#
#
#
#
#   1%|          | 54/10000 [00:02<07:51, 21.09it/s, loss=0.00476, rmse_test=0.192]
#
#
#
#
#
#
#
#   1%|          | 54/10000 [00:02<07:51, 21.09it/s, loss=0.00441, rmse_test=0.133]
#
#
#
#
#
#
#
#   1%|          | 54/10000 [00:02<07:51, 21.09it/s, loss=0.00407, rmse_test=0.151]
#
#
#
#
#
#
#
#   1%|          | 57/10000 [00:02<07:43, 21.45it/s, loss=0.00407, rmse_test=0.151]
#
#
#
#
#
#
#
#   1%|          | 57/10000 [00:02<07:43, 21.45it/s, loss=0.00377, rmse_test=0.076]
#
#
#
#
#
#
#
#   1%|          | 57/10000 [00:02<07:43, 21.45it/s, loss=0.0035, rmse_test=0.0601]
#
#
#
#
#
#
#
#   1%|          | 57/10000 [00:02<07:43, 21.45it/s, loss=0.00323, rmse_test=0.0344]
#
#
#
#
#
#
#
#   1%|          | 60/10000 [00:02<07:10, 23.08it/s, loss=0.00323, rmse_test=0.0344]
#
#
#
#
#
#
#
#   1%|          | 60/10000 [00:02<07:10, 23.08it/s, loss=0.00301, rmse_test=0.125]
#
#
#
#
#
#
#
#   1%|          | 60/10000 [00:02<07:10, 23.08it/s, loss=0.00278, rmse_test=0.164]
#
#
#
#
#
#
#
#   1%|          | 60/10000 [00:02<07:10, 23.08it/s, loss=0.00254, rmse_test=0.0285]
#
#
#
#
#
#
#
#   1%|          | 63/10000 [00:02<06:47, 24.40it/s, loss=0.00254, rmse_test=0.0285]
#
#
#
#
#
#
#
#   1%|          | 63/10000 [00:02<06:47, 24.40it/s, loss=0.00236, rmse_test=0.12]
#
#
#
#
#
#
#
#   1%|          | 63/10000 [00:02<06:47, 24.40it/s, loss=0.00218, rmse_test=0.148]
#
#
#
#
#
#
#
#   1%|          | 63/10000 [00:02<06:47, 24.40it/s, loss=0.00201, rmse_test=0.131]
#
#
#
#
#
#
#
#   1%|          | 66/10000 [00:02<06:30, 25.45it/s, loss=0.00201, rmse_test=0.131]
#
#
#
#
#
#
#
#   1%|          | 66/10000 [00:02<06:30, 25.45it/s, loss=0.00185, rmse_test=0.0466]
#
#
#
#
#
#
#
#   1%|          | 66/10000 [00:02<06:30, 25.45it/s, loss=0.00172, rmse_test=0.0666]
#
#
#
#
#
#
#
#   1%|          | 66/10000 [00:02<06:30, 25.45it/s, loss=0.00161, rmse_test=0.048]
#
#
#
#
#
#
#
#   1%|          | 69/10000 [00:02<06:24, 25.84it/s, loss=0.00161, rmse_test=0.048]
#
#
#
#
#
#
#
#   1%|          | 69/10000 [00:02<06:24, 25.84it/s, loss=0.0015, rmse_test=0.0521]
#
#
#
#
#
#
#
#   1%|          | 69/10000 [00:02<06:24, 25.84it/s, loss=0.00139, rmse_test=0.123]
#
#
#
#
#
#
#
#   1%|          | 69/10000 [00:02<06:24, 25.84it/s, loss=0.00128, rmse_test=0.162]
#
#
#
#
#
#
#
#   1%|          | 72/10000 [00:02<06:08, 26.91it/s, loss=0.00128, rmse_test=0.162]
#
#
#
#
#
#
#
#   1%|          | 72/10000 [00:02<06:08, 26.91it/s, loss=0.00121, rmse_test=0.0429]
#
#
#
#
#
#
#
#   1%|          | 72/10000 [00:02<06:08, 26.91it/s, loss=0.00113, rmse_test=0.0515]
#
#
#
#
#
#
#
#   1%|          | 72/10000 [00:03<06:08, 26.91it/s, loss=0.00105, rmse_test=0.149]
#
#
#
#
#
#
#
#   1%|          | 75/10000 [00:03<06:07, 27.02it/s, loss=0.00105, rmse_test=0.149]
#
#
#
#
#
#
#
#   1%|          | 75/10000 [00:03<06:07, 27.02it/s, loss=0.000975, rmse_test=0.0288]
#
#
#
#
#
#
#
#   1%|          | 75/10000 [00:03<06:07, 27.02it/s, loss=0.0009, rmse_test=0.132]
#
#
#
#
#
#
#
#   1%|          | 75/10000 [00:03<06:07, 27.02it/s, loss=0.000838, rmse_test=0.0533]
#
#
#
#
#
#
#
#   1%|          | 78/10000 [00:03<06:04, 27.20it/s, loss=0.000838, rmse_test=0.0533]
#
#
#
#
#
#
#
#   1%|          | 78/10000 [00:03<06:04, 27.20it/s, loss=0.000782, rmse_test=0.323]
#
#
#
#
#
#
#
#   1%|          | 78/10000 [00:03<06:04, 27.20it/s, loss=0.000729, rmse_test=0.124]
#
#
#
#
#
#
#
#   1%|          | 78/10000 [00:03<06:04, 27.20it/s, loss=0.000671, rmse_test=0.0445]
#
#
#
#
#
#
#
#   1%|          | 81/10000 [00:03<06:13, 26.56it/s, loss=0.000671, rmse_test=0.0445]
#
#
#
#
#
#
#
#   1%|          | 81/10000 [00:03<06:13, 26.56it/s, loss=0.000621, rmse_test=0.0299]
#
#
#
#
#
#
#
#   1%|          | 81/10000 [00:03<06:13, 26.56it/s, loss=0.000582, rmse_test=0.109]
#
#
#
#
#
#
#
#   1%|          | 81/10000 [00:03<06:13, 26.56it/s, loss=0.000549, rmse_test=0.0771]
#
#
#
#
#
#
#
#   1%|          | 84/10000 [00:03<06:18, 26.19it/s, loss=0.000549, rmse_test=0.0771]
#
#
#
#
#
#
#
#   1%|          | 84/10000 [00:03<06:18, 26.19it/s, loss=0.000503, rmse_test=0.0351]
#
#
#
#
#
#
#
#   1%|          | 84/10000 [00:03<06:18, 26.19it/s, loss=0.000473, rmse_test=0.0687]
#
#
#
#
#
#
#
#   1%|          | 84/10000 [00:03<06:18, 26.19it/s, loss=0.000437, rmse_test=0.114]
#
#
#
#
#
#
#
#   1%|          | 87/10000 [00:03<06:10, 26.78it/s, loss=0.000437, rmse_test=0.114]
#
#
#
#
#
#
#
#   1%|          | 87/10000 [00:03<06:10, 26.78it/s, loss=0.000414, rmse_test=0.145]
#
#
#
#
#
#
#
#   1%|          | 87/10000 [00:03<06:10, 26.78it/s, loss=0.000398, rmse_test=0.0653]
#
#
#
#
#
#
#
#   1%|          | 87/10000 [00:03<06:10, 26.78it/s, loss=0.000371, rmse_test=0.229]
#
#
#
#
#
#
#
#   1%|          | 90/10000 [00:03<06:15, 26.36it/s, loss=0.000371, rmse_test=0.229]
#
#
#
#
#
#
#
#   1%|          | 90/10000 [00:03<06:15, 26.36it/s, loss=0.000346, rmse_test=0.0398]
#
#
#
#
#
#
#
#   1%|          | 90/10000 [00:03<06:15, 26.36it/s, loss=0.000316, rmse_test=0.266]
#
#
#
#
#
#
#
#   1%|          | 90/10000 [00:03<06:15, 26.36it/s, loss=0.000301, rmse_test=0.0492]
#
#
#
#
#
#
#
#   1%|          | 93/10000 [00:03<06:08, 26.92it/s, loss=0.000301, rmse_test=0.0492]
#
#
#
#
#
#
#
#   1%|          | 93/10000 [00:03<06:08, 26.92it/s, loss=0.000287, rmse_test=0.0917]
#
#
#
#
#
#
#
#   1%|          | 93/10000 [00:03<06:08, 26.92it/s, loss=0.000264, rmse_test=0.102]
#
#
#
#
#
#
#
#   1%|          | 93/10000 [00:03<06:08, 26.92it/s, loss=0.000245, rmse_test=0.0951]
#
#
#
#
#
#
#
#   1%|          | 96/10000 [00:03<06:06, 27.00it/s, loss=0.000245, rmse_test=0.0951]
#
#
#
#
#
#
#
#   1%|          | 96/10000 [00:03<06:06, 27.00it/s, loss=0.000229, rmse_test=0.0855]
#
#
#
#
#
#
#
#   1%|          | 96/10000 [00:03<06:06, 27.00it/s, loss=0.000221, rmse_test=0.0743]
#
#
#
#
#
#
#
#   1%|          | 96/10000 [00:03<06:06, 27.00it/s, loss=0.000207, rmse_test=0.0363]
#
#
#
#
#
#
#
#   1%|          | 99/10000 [00:03<06:02, 27.34it/s, loss=0.000207, rmse_test=0.0363]
#
#
#
#
#
#
#
#   1%|          | 99/10000 [00:03<06:02, 27.34it/s, loss=0.000196, rmse_test=0.0396]
#
#
#
#
#
#
#
#   1%|          | 99/10000 [00:03<06:02, 27.34it/s, loss=0.000187, rmse_test=0.0306]
#
#
#
#
#
#
#
#   1%|          | 99/10000 [00:04<06:02, 27.34it/s, loss=0.000168, rmse_test=0.0312]
#
#
#
#
#
#
#
#   1%|          | 102/10000 [00:04<06:17, 26.21it/s, loss=0.000168, rmse_test=0.0312]
#
#
#
#
#
#
#
#   1%|          | 102/10000 [00:04<06:17, 26.21it/s, loss=0.000153, rmse_test=0.123]
#
#
#
#
#
#
#
#   1%|          | 102/10000 [00:04<06:17, 26.21it/s, loss=0.000148, rmse_test=0.0344]
#
#
#
#
#
#
#
#   1%|          | 102/10000 [00:04<06:17, 26.21it/s, loss=0.000139, rmse_test=0.0485]
#
#
#
#
#
#
#
#   1%|          | 105/10000 [00:04<06:18, 26.15it/s, loss=0.000139, rmse_test=0.0485]
#
#
#
#
#
#
#
#   1%|          | 105/10000 [00:04<06:18, 26.15it/s, loss=0.000139, rmse_test=0.0288]
#
#
#
#
#
#
#
#   1%|          | 105/10000 [00:04<06:18, 26.15it/s, loss=0.000125, rmse_test=0.0319]
#   1%|          | 105/10000 [00:04<06:18, 26.15it/s, loss=0.000116, rmse_test=0.064]
#
#
#
#
#
#
#
#   1%|          | 108/10000 [00:04<06:12, 26.58it/s, loss=0.000116, rmse_test=0.064]
#
#
#
#
#
#
#
#   1%|          | 108/10000 [00:04<06:12, 26.58it/s, loss=0.000117, rmse_test=0.103]
#
#
#
#
#
#
#
#   1%|          | 108/10000 [00:04<06:12, 26.58it/s, loss=0.000108, rmse_test=0.0433]
#
#
#
#
#
#
#
#   1%|          | 108/10000 [00:04<06:12, 26.58it/s, loss=0.000105, rmse_test=0.0325]
#
#
#
#
#
#
#
#   1%|          | 111/10000 [00:04<06:16, 26.26it/s, loss=0.000105, rmse_test=0.0325]
#
#
#
#
#
#
#
#   1%|          | 111/10000 [00:04<06:16, 26.26it/s, loss=9.75e-5, rmse_test=0.0619]
#
#
#
#
#
#
#
#   1%|          | 111/10000 [00:04<06:16, 26.26it/s, loss=8.86e-5, rmse_test=0.0876]
#
#
#
#
#
#
#
#   1%|          | 111/10000 [00:04<06:16, 26.26it/s, loss=8.63e-5, rmse_test=0.0309]
#
#
#
#
#
#
#
#   1%|          | 114/10000 [00:04<06:05, 27.07it/s, loss=8.63e-5, rmse_test=0.0309]
#
#
#
#
#
#
#
#   1%|          | 114/10000 [00:04<06:05, 27.07it/s, loss=8.32e-5, rmse_test=0.0272]
#
#
#
#
#
#
#
#   1%|          | 114/10000 [00:04<06:05, 27.07it/s, loss=8.4e-5, rmse_test=0.0548]
#
#
#
#
#
#
#
#   1%|          | 114/10000 [00:04<06:05, 27.07it/s, loss=8.34e-5, rmse_test=0.0263]
#
#
#
#
#
#
#
#   1%|          | 117/10000 [00:04<06:07, 26.86it/s, loss=8.34e-5, rmse_test=0.0263]
#
#
#
#
#
#
#
#   1%|          | 117/10000 [00:04<06:07, 26.86it/s, loss=7.8e-5, rmse_test=0.0786]
#
#
#
#
#
#
#
#   1%|          | 117/10000 [00:04<06:07, 26.86it/s, loss=6.37e-5, rmse_test=0.0469]
#
#
#
#
#
#
#
#   1%|          | 117/10000 [00:04<06:07, 26.86it/s, loss=6.91e-5, rmse_test=0.0337]
#
#
#
#
#
#
#
#   1%|          | 120/10000 [00:04<06:03, 27.16it/s, loss=6.91e-5, rmse_test=0.0337]
#
#
#
#
#
#
#
#   1%|          | 120/10000 [00:04<06:03, 27.16it/s, loss=5.95e-5, rmse_test=0.0431]
#
#
#
#
#
#
#
#   1%|          | 120/10000 [00:04<06:03, 27.16it/s, loss=5.97e-5, rmse_test=0.0328]
#
#
#
#
#
#
#
#   1%|          | 120/10000 [00:04<06:03, 27.16it/s, loss=5.95e-5, rmse_test=0.0756]
#
#
#
#
#
#
#
#   1%|          | 123/10000 [00:04<05:59, 27.51it/s, loss=5.95e-5, rmse_test=0.0756]
#
#
#
#
#
#
#
#   1%|          | 123/10000 [00:04<05:59, 27.51it/s, loss=6.42e-5, rmse_test=0.0692]
#
#
#
#
#
#
#
#   1%|          | 123/10000 [00:04<05:59, 27.51it/s, loss=5.72e-5, rmse_test=0.0651]
#
#
#
#
#
#
#
#   1%|          | 123/10000 [00:04<05:59, 27.51it/s, loss=4.8e-5, rmse_test=0.106]
#
#
#
#
#
#
#
#   1%|▏         | 126/10000 [00:04<05:57, 27.59it/s, loss=4.8e-5, rmse_test=0.106]
#
#
#
#
#
#
#
#   1%|▏         | 126/10000 [00:04<05:57, 27.59it/s, loss=5.68e-5, rmse_test=0.0391]
#
#
#
#
#
#
#
#   1%|▏         | 126/10000 [00:04<05:57, 27.59it/s, loss=4.78e-5, rmse_test=0.12]
#
#
#
#
#
#
#
#   1%|▏         | 126/10000 [00:05<05:57, 27.59it/s, loss=5.2e-5, rmse_test=0.0237]
#
#
#
#
#
#
#
#   1%|▏         | 129/10000 [00:05<05:59, 27.45it/s, loss=5.2e-5, rmse_test=0.0237]
#
#
#
#
#
#
#
#   1%|▏         | 129/10000 [00:05<05:59, 27.45it/s, loss=4.29e-5, rmse_test=0.0309]
#
#
#
#
#
#
#
#   1%|▏         | 129/10000 [00:05<05:59, 27.45it/s, loss=4.91e-5, rmse_test=0.0346]
#
#
#
#
#
#
#
#   1%|▏         | 129/10000 [00:05<05:59, 27.45it/s, loss=3.84e-5, rmse_test=0.0518]
#
#
#
#
#
#
#
#   1%|▏         | 132/10000 [00:05<05:55, 27.73it/s, loss=3.84e-5, rmse_test=0.0518]
#
#
#
#
#
#
#
#   1%|▏         | 132/10000 [00:05<05:55, 27.73it/s, loss=3.64e-5, rmse_test=0.0289]
#
#
#
#
#
#
#
#   1%|▏         | 132/10000 [00:05<05:55, 27.73it/s, loss=3.32e-5, rmse_test=0.0293]
#
#
#
#
#
#
#
#   1%|▏         | 132/10000 [00:05<05:55, 27.73it/s, loss=4.27e-5, rmse_test=0.0517]
#
#
#
#
#
#
#
#   1%|▏         | 135/10000 [00:05<06:03, 27.16it/s, loss=4.27e-5, rmse_test=0.0517]
#
#
#
#
#
#
#
#   1%|▏         | 135/10000 [00:05<06:03, 27.16it/s, loss=4.72e-5, rmse_test=0.0557]
#
#
#
#
#
#
#
#   1%|▏         | 135/10000 [00:05<06:03, 27.16it/s, loss=3.98e-5, rmse_test=0.0328]
#
#
#
#
#
#
#
#   1%|▏         | 135/10000 [00:05<06:03, 27.16it/s, loss=4.85e-5, rmse_test=0.0281]
#
#
#
#
#
#
#
#   1%|▏         | 138/10000 [00:05<06:18, 26.06it/s, loss=4.85e-5, rmse_test=0.0281]
#
#
#
#
#
#
#
#   1%|▏         | 138/10000 [00:05<06:18, 26.06it/s, loss=3.42e-5, rmse_test=0.0276]
#
#
#
#
#
#
#
#   1%|▏         | 138/10000 [00:05<06:18, 26.06it/s, loss=3.61e-5, rmse_test=0.0614]
#
#
#
#
#
#
#
#   1%|▏         | 138/10000 [00:05<06:18, 26.06it/s, loss=3.4e-5, rmse_test=0.025]
#
#
#
#
#
#
#
#   1%|▏         | 141/10000 [00:05<06:19, 25.96it/s, loss=3.4e-5, rmse_test=0.025]
#
#
#
#
#
#
#
#   1%|▏         | 141/10000 [00:05<06:19, 25.96it/s, loss=3.42e-5, rmse_test=0.0339]
#
#
#
#
#
#
#
#   1%|▏         | 141/10000 [00:05<06:19, 25.96it/s, loss=3.58e-5, rmse_test=0.0275]
#
#
#
#
#
#
#
#   1%|▏         | 141/10000 [00:05<06:19, 25.96it/s, loss=3.88e-5, rmse_test=0.051]
#
#
#
#
#
#
#
#   1%|▏         | 144/10000 [00:05<06:10, 26.63it/s, loss=3.88e-5, rmse_test=0.051]
#
#
#
#
#
#
#
#   1%|▏         | 144/10000 [00:05<06:10, 26.63it/s, loss=2.57e-5, rmse_test=0.0487]
#
#
#
#
#
#
#
#   1%|▏         | 144/10000 [00:05<06:10, 26.63it/s, loss=3.75e-5, rmse_test=0.033]
#
#
#
#
#
#
#
#   1%|▏         | 144/10000 [00:05<06:10, 26.63it/s, loss=3.07e-5, rmse_test=0.0324]
#
#
#
#
#
#
#
#   1%|▏         | 147/10000 [00:05<06:07, 26.79it/s, loss=3.07e-5, rmse_test=0.0324]
#
#
#
#
#
#
#
#   1%|▏         | 147/10000 [00:05<06:07, 26.79it/s, loss=2.68e-5, rmse_test=0.0754]
#
#
#
#
#
#
#
#   1%|▏         | 147/10000 [00:05<06:07, 26.79it/s, loss=3.35e-5, rmse_test=0.0274]
#
#
#
#
#
#
#
#   1%|▏         | 147/10000 [00:05<06:07, 26.79it/s, loss=3.2e-5, rmse_test=0.0494]
#
#
#
#
#
#
#
#   2%|▏         | 150/10000 [00:05<06:09, 26.67it/s, loss=3.2e-5, rmse_test=0.0494]
#
#
#
#
#
#
#
#   2%|▏         | 150/10000 [00:05<06:09, 26.67it/s, loss=4.16e-5, rmse_test=0.0265]
#
#
#
#
#
#
#
#   2%|▏         | 150/10000 [00:05<06:09, 26.67it/s, loss=3.31e-5, rmse_test=0.0389]
#
#
#
#
#
#
#
#   2%|▏         | 150/10000 [00:05<06:09, 26.67it/s, loss=4.03e-5, rmse_test=0.0531]
#
#
#
#
#
#
#
#   2%|▏         | 153/10000 [00:05<06:08, 26.76it/s, loss=4.03e-5, rmse_test=0.0531]
#
#
#
#
#
#
#
#   2%|▏         | 153/10000 [00:05<06:08, 26.76it/s, loss=3.84e-5, rmse_test=0.0329]
#
#
#
#
#
#
#
#   2%|▏         | 153/10000 [00:06<06:08, 26.76it/s, loss=2.46e-5, rmse_test=0.0428]
#
#
#
#
#
#
#
#   2%|▏         | 153/10000 [00:06<06:08, 26.76it/s, loss=2.66e-5, rmse_test=0.0306]
#
#
#
#
#
#
#
#   2%|▏         | 156/10000 [00:06<06:05, 26.96it/s, loss=2.66e-5, rmse_test=0.0306]
#
#
#
#
#
#
#
#   2%|▏         | 156/10000 [00:06<06:05, 26.96it/s, loss=3.31e-5, rmse_test=0.0268]
#
#
#
#
#
#
#
#   2%|▏         | 156/10000 [00:06<06:05, 26.96it/s, loss=3.43e-5, rmse_test=0.0574]
#
#
#
#
#
#
#
#   2%|▏         | 156/10000 [00:06<06:05, 26.96it/s, loss=4.04e-5, rmse_test=0.0249]
#
#
#
#
#
#
#
#   2%|▏         | 159/10000 [00:06<06:00, 27.31it/s, loss=4.04e-5, rmse_test=0.0249]
#
#
#
#
#
#
#
#   2%|▏         | 159/10000 [00:06<06:00, 27.31it/s, loss=3.73e-5, rmse_test=0.0305]
#   2%|▏         | 159/10000 [00:06<06:00, 27.31it/s, loss=4.06e-5, rmse_test=0.0309]
#
#
#
#
#
#
#
#   2%|▏         | 159/10000 [00:06<06:00, 27.31it/s, loss=3.7e-5, rmse_test=0.0477]
#
#
#
#
#
#
#
#   2%|▏         | 162/10000 [00:06<05:59, 27.38it/s, loss=3.7e-5, rmse_test=0.0477]
#
#
#
#
#
#
#
#   2%|▏         | 162/10000 [00:06<05:59, 27.38it/s, loss=2.18e-5, rmse_test=0.0265]
#
#
#
#
#
#
#
#   2%|▏         | 162/10000 [00:06<05:59, 27.38it/s, loss=3.35e-5, rmse_test=0.0362]
#
#
#
#
#
#
#
#   2%|▏         | 162/10000 [00:06<05:59, 27.38it/s, loss=3.63e-5, rmse_test=0.0241]
#
#
#
#
#
#
#
#   2%|▏         | 165/10000 [00:06<05:55, 27.67it/s, loss=3.63e-5, rmse_test=0.0241]
#
#
#
#
#
#
#
#   2%|▏         | 165/10000 [00:06<05:55, 27.67it/s, loss=2.57e-5, rmse_test=0.0293]
#
#
#
#
#
#
#
#   2%|▏         | 165/10000 [00:06<05:55, 27.67it/s, loss=3.43e-5, rmse_test=0.0455]
#
#
#
#
#
#
#
#   2%|▏         | 165/10000 [00:06<05:55, 27.67it/s, loss=3.22e-5, rmse_test=0.0311]
#
#
#
#
#
#
#
#   2%|▏         | 168/10000 [00:06<05:58, 27.39it/s, loss=3.22e-5, rmse_test=0.0311]
#
#
#
#
#
#
#
#   2%|▏         | 168/10000 [00:06<05:58, 27.39it/s, loss=4.02e-5, rmse_test=0.0627]
#
#
#
#
#
#
#
#   2%|▏         | 168/10000 [00:06<05:58, 27.39it/s, loss=3.72e-5, rmse_test=0.0469]
#
#
#
#
#
#
#
#   2%|▏         | 168/10000 [00:06<05:58, 27.39it/s, loss=2.17e-5, rmse_test=0.024]
#
#
#
#
#
#
#
#   2%|▏         | 171/10000 [00:06<06:08, 26.64it/s, loss=2.17e-5, rmse_test=0.024]
#
#
#
#
#
#
#
#   2%|▏         | 171/10000 [00:06<06:08, 26.64it/s, loss=2.98e-5, rmse_test=0.0347]
#
#
#
#
#
#
#
#   2%|▏         | 171/10000 [00:06<06:08, 26.64it/s, loss=2.47e-5, rmse_test=0.0222]
#
#
#
#
#
#
#
#   2%|▏         | 171/10000 [00:06<06:08, 26.64it/s, loss=2.83e-5, rmse_test=0.0562]
#
#
#
#
#
#
#
#   2%|▏         | 174/10000 [00:06<06:09, 26.60it/s, loss=2.83e-5, rmse_test=0.0562]
#
#
#
#
#
#
#
#   2%|▏         | 174/10000 [00:06<06:09, 26.60it/s, loss=3.86e-5, rmse_test=0.0255]
#
#
#
#
#
#
#
#   2%|▏         | 174/10000 [00:06<06:09, 26.60it/s, loss=3.29e-5, rmse_test=0.0281]
#
#
#
#
#
#
#
#   2%|▏         | 174/10000 [00:06<06:09, 26.60it/s, loss=2.95e-5, rmse_test=0.0241]
#
#
#
#
#
#
#
#   2%|▏         | 177/10000 [00:06<06:02, 27.12it/s, loss=2.95e-5, rmse_test=0.0241]
#
#
#
#
#
#
#
#   2%|▏         | 177/10000 [00:06<06:02, 27.12it/s, loss=1.8e-5, rmse_test=0.0578]
#
#
#
#
#
#
#
#   2%|▏         | 177/10000 [00:06<06:02, 27.12it/s, loss=2.7e-5, rmse_test=0.0325]
#
#
#
#
#
#
#
#   2%|▏         | 177/10000 [00:06<06:02, 27.12it/s, loss=3e-5, rmse_test=0.027]
#
#
#
#
#
#
#
#   2%|▏         | 180/10000 [00:06<06:06, 26.81it/s, loss=3e-5, rmse_test=0.027]
#
#
#
#
#
#
#
#   2%|▏         | 180/10000 [00:06<06:06, 26.81it/s, loss=2.5e-5, rmse_test=0.0283]
#
#
#
#
#
#
#
#   2%|▏         | 180/10000 [00:06<06:06, 26.81it/s, loss=2.85e-5, rmse_test=0.0313]
#
#
#
#
#
#
#
#   2%|▏         | 180/10000 [00:07<06:06, 26.81it/s, loss=2.35e-5, rmse_test=0.0327]
#
#
#
#
#
#
#
#   2%|▏         | 183/10000 [00:07<06:06, 26.80it/s, loss=2.35e-5, rmse_test=0.0327]
#
#
#
#
#
#
#
#   2%|▏         | 183/10000 [00:07<06:06, 26.80it/s, loss=3.31e-5, rmse_test=0.034]
#
#
#
#
#
#
#
#   2%|▏         | 183/10000 [00:07<06:06, 26.80it/s, loss=2.95e-5, rmse_test=0.0188]
#
#
#
#
#
#
#
#   2%|▏         | 183/10000 [00:07<06:06, 26.80it/s, loss=5.02e-5, rmse_test=0.0298]
#
#
#
#
#
#
#
#   2%|▏         | 186/10000 [00:07<06:12, 26.36it/s, loss=5.02e-5, rmse_test=0.0298]
#
#
#
#
#
#
#
#   2%|▏         | 186/10000 [00:07<06:12, 26.36it/s, loss=3.9e-5, rmse_test=0.0326]
#
#
#
#
#
#
#
#   2%|▏         | 186/10000 [00:07<06:12, 26.36it/s, loss=2.86e-5, rmse_test=0.0227]
#
#
#
#
#
#
#
#   2%|▏         | 186/10000 [00:07<06:12, 26.36it/s, loss=2.63e-5, rmse_test=0.0265]
#
#
#
#
#
#
#
#   2%|▏         | 189/10000 [00:07<06:04, 26.94it/s, loss=2.63e-5, rmse_test=0.0265]
#
#
#
#
#
#
#
#   2%|▏         | 189/10000 [00:07<06:04, 26.94it/s, loss=3.16e-5, rmse_test=0.0394]
#
#
#
#
#
#
#
#   2%|▏         | 189/10000 [00:07<06:04, 26.94it/s, loss=3.81e-5, rmse_test=0.0484]
#
#
#
#
#
#
#
#   2%|▏         | 189/10000 [00:07<06:04, 26.94it/s, loss=2.86e-5, rmse_test=0.0246]
#
#
#
#
#
#
#
#   2%|▏         | 192/10000 [00:07<06:10, 26.50it/s, loss=2.86e-5, rmse_test=0.0246]
#
#
#
#
#
#
#
#   2%|▏         | 192/10000 [00:07<06:10, 26.50it/s, loss=3.35e-5, rmse_test=0.0548]
#
#
#
#
#
#
#
#   2%|▏         | 192/10000 [00:07<06:10, 26.50it/s, loss=4.25e-5, rmse_test=0.0546]
#
#
#
#
#
#
#
#   2%|▏         | 192/10000 [00:07<06:10, 26.50it/s, loss=4.36e-5, rmse_test=0.0309]
#
#
#
#
#
#
#
#   2%|▏         | 195/10000 [00:07<06:29, 25.18it/s, loss=4.36e-5, rmse_test=0.0309]
#
#
#
#
#
#
#
#   2%|▏         | 195/10000 [00:07<06:29, 25.18it/s, loss=3.96e-5, rmse_test=0.0319]
#
#
#
#
#
#
#
#   2%|▏         | 195/10000 [00:07<06:29, 25.18it/s, loss=4.22e-5, rmse_test=0.0244]
#
#
#
#
#
#
#
#   2%|▏         | 195/10000 [00:07<06:29, 25.18it/s, loss=4.06e-5, rmse_test=0.0887]
#
#
#
#
#
#
#
#   2%|▏         | 195/10000 [00:07<06:29, 25.18it/s, loss=4.21e-5, rmse_test=0.0279]
#
#
#
#
#
#
#
#   2%|▏         | 199/10000 [00:07<06:09, 26.53it/s, loss=4.21e-5, rmse_test=0.0279]
#
#
#
#
#
#
#
#   2%|▏         | 199/10000 [00:07<06:09, 26.53it/s, loss=3.94e-5, rmse_test=0.0764]
#
#
#
#
#
#
#
#   2%|▏         | 199/10000 [00:07<06:09, 26.53it/s, loss=3.62e-5, rmse_test=0.0962]
#
#
#
#
#
#
#
#   2%|▏         | 199/10000 [00:07<06:09, 26.53it/s, loss=4.54e-5, rmse_test=0.0578]
#
#
#
#
#
#
#
#   2%|▏         | 202/10000 [00:07<06:34, 24.84it/s, loss=4.54e-5, rmse_test=0.0578]
#
#
#
#
#
#
#
#   2%|▏         | 202/10000 [00:07<06:34, 24.84it/s, loss=3.48e-5, rmse_test=0.035]
#
#
#
#
#
#
#
#   2%|▏         | 202/10000 [00:07<06:34, 24.84it/s, loss=4.2e-5, rmse_test=0.019]
#
#
#
#
#
#
#
#   2%|▏         | 202/10000 [00:07<06:34, 24.84it/s, loss=4.38e-5, rmse_test=0.0216]
#
#
#
#
#
#
#
#   2%|▏         | 205/10000 [00:07<06:15, 26.05it/s, loss=4.38e-5, rmse_test=0.0216]
#
#
#
#
#
#
#
#   2%|▏         | 205/10000 [00:07<06:15, 26.05it/s, loss=4.06e-5, rmse_test=0.0213]
#
#
#
#
#
#
#
#   2%|▏         | 205/10000 [00:07<06:15, 26.05it/s, loss=4.36e-5, rmse_test=0.0242]
#
#
#
#
#
#
#
#   2%|▏         | 205/10000 [00:07<06:15, 26.05it/s, loss=4.08e-5, rmse_test=0.0249]
#
#
#
#
#
#
#
#   2%|▏         | 208/10000 [00:07<06:08, 26.59it/s, loss=4.08e-5, rmse_test=0.0249]
#
#
#
#
#
#
#
#   2%|▏         | 208/10000 [00:08<06:08, 26.59it/s, loss=3.65e-5, rmse_test=0.03]
#
#
#
#
#
#
#
#   2%|▏         | 208/10000 [00:08<06:08, 26.59it/s, loss=4.01e-5, rmse_test=0.05]
#
#
#
#
#
#
#
#   2%|▏         | 208/10000 [00:08<06:08, 26.59it/s, loss=4.56e-5, rmse_test=0.0554]
#
#
#
#
#
#
#
#   2%|▏         | 208/10000 [00:08<06:08, 26.59it/s, loss=3.87e-5, rmse_test=0.042]
#
#
#
#
#
#
#
#   2%|▏         | 212/10000 [00:08<05:51, 27.85it/s, loss=3.87e-5, rmse_test=0.042]
#
#
#
#
#
#
#
#   2%|▏         | 212/10000 [00:08<05:51, 27.85it/s, loss=4.09e-5, rmse_test=0.0927]
#
#
#
#
#
#
#
#   2%|▏         | 212/10000 [00:08<05:51, 27.85it/s, loss=3.57e-5, rmse_test=0.0844]
#   2%|▏         | 212/10000 [00:08<05:51, 27.85it/s, loss=3.23e-5, rmse_test=0.391]
#
#
#
#
#
#
#
#   2%|▏         | 215/10000 [00:08<05:52, 27.78it/s, loss=3.23e-5, rmse_test=0.391]
#
#
#
#
#
#
#
#   2%|▏         | 215/10000 [00:08<05:52, 27.78it/s, loss=3.86e-5, rmse_test=0.17]
#
#
#
#
#
#
#
#   2%|▏         | 215/10000 [00:08<05:52, 27.78it/s, loss=3.41e-5, rmse_test=0.223]
#
#
#
#
#
#
#
#   2%|▏         | 215/10000 [00:08<05:52, 27.78it/s, loss=4.3e-5, rmse_test=0.106]
#
#
#
#
#
#
#
#   2%|▏         | 218/10000 [00:08<05:51, 27.83it/s, loss=4.3e-5, rmse_test=0.106]
#
#
#
#
#
#
#
#   2%|▏         | 218/10000 [00:08<05:51, 27.83it/s, loss=3.7e-5, rmse_test=0.177]
#
#
#
#
#
#
#
#   2%|▏         | 218/10000 [00:08<05:51, 27.83it/s, loss=4.63e-5, rmse_test=0.126]
#
#
#
#
#
#
#
#   2%|▏         | 218/10000 [00:08<05:51, 27.83it/s, loss=4.73e-5, rmse_test=0.144]
#
#
#
#
#
#
#
#   2%|▏         | 218/10000 [00:08<05:51, 27.83it/s, loss=4.4e-5, rmse_test=0.0409]
#
#
#
#
#
#
#
#   2%|▏         | 222/10000 [00:08<05:50, 27.93it/s, loss=4.4e-5, rmse_test=0.0409]
#
#
#
#
#
#
#
#   2%|▏         | 222/10000 [00:08<05:50, 27.93it/s, loss=3.62e-5, rmse_test=0.0332]
#
#
#
#
#
#
#
#   2%|▏         | 222/10000 [00:08<05:50, 27.93it/s, loss=3.67e-5, rmse_test=0.0267]
#
#
#
#
#
#
#
#   2%|▏         | 222/10000 [00:08<05:50, 27.93it/s, loss=3.87e-5, rmse_test=0.0327]
#
#
#
#
#
#
#
#   2%|▏         | 225/10000 [00:08<05:50, 27.86it/s, loss=3.87e-5, rmse_test=0.0327]
#
#
#
#
#
#
#
#   2%|▏         | 225/10000 [00:08<05:50, 27.86it/s, loss=4.11e-5, rmse_test=0.0276]
#
#
#
#
#
#
#
#   2%|▏         | 225/10000 [00:08<05:50, 27.86it/s, loss=4.11e-5, rmse_test=0.0275]
#
#
#
#
#
#
#
#   2%|▏         | 225/10000 [00:08<05:50, 27.86it/s, loss=3.37e-5, rmse_test=0.0348]
#
#
#
#
#
#
#
#   2%|▏         | 225/10000 [00:08<05:50, 27.86it/s, loss=4.04e-5, rmse_test=0.0227]
#
#
#
#
#
#
#
#   2%|▏         | 229/10000 [00:08<05:39, 28.78it/s, loss=4.04e-5, rmse_test=0.0227]
#
#
#
#
#
#
#
#   2%|▏         | 229/10000 [00:08<05:39, 28.78it/s, loss=4.42e-5, rmse_test=0.024]
#
#
#
#
#
#
#
#   2%|▏         | 229/10000 [00:08<05:39, 28.78it/s, loss=3.93e-5, rmse_test=0.0416]
#
#
#
#
#
#
#
#   2%|▏         | 229/10000 [00:08<05:39, 28.78it/s, loss=4.89e-5, rmse_test=0.036]
#
#
#
#
#
#
#
#   2%|▏         | 232/10000 [00:08<05:35, 29.12it/s, loss=4.89e-5, rmse_test=0.036]
#
#
#
#
#
#
#
#   2%|▏         | 232/10000 [00:08<05:35, 29.12it/s, loss=4e-5, rmse_test=0.0237]
#
#
#
#
#
#
#
#   2%|▏         | 232/10000 [00:08<05:35, 29.12it/s, loss=2.84e-5, rmse_test=0.0306]
#
#
#
#
#
#
#
#   2%|▏         | 232/10000 [00:08<05:35, 29.12it/s, loss=3.47e-5, rmse_test=0.0427]
#
#
#
#
#
#
#
#   2%|▏         | 235/10000 [00:08<05:40, 28.65it/s, loss=3.47e-5, rmse_test=0.0427]
#
#
#
#
#
#
#
#   2%|▏         | 235/10000 [00:08<05:40, 28.65it/s, loss=3.4e-5, rmse_test=0.029]
#
#
#
#
#
#
#
#   2%|▏         | 235/10000 [00:08<05:40, 28.65it/s, loss=4.3e-5, rmse_test=0.047]
#
#
#
#
#
#
#
#   2%|▏         | 235/10000 [00:09<05:40, 28.65it/s, loss=3.68e-5, rmse_test=0.0873]
#
#
#
#
#
#
#
#   2%|▏         | 235/10000 [00:09<05:40, 28.65it/s, loss=3.75e-5, rmse_test=0.084]
#
#
#
#
#
#
#
#   2%|▏         | 239/10000 [00:09<05:29, 29.65it/s, loss=3.75e-5, rmse_test=0.084]
#
#
#
#
#
#
#
#   2%|▏         | 239/10000 [00:09<05:29, 29.65it/s, loss=4.09e-5, rmse_test=0.084]
#
#
#
#
#
#
#
#   2%|▏         | 239/10000 [00:09<05:29, 29.65it/s, loss=3.27e-5, rmse_test=0.133]
#
#
#
#
#
#
#
#   2%|▏         | 239/10000 [00:09<05:29, 29.65it/s, loss=3.59e-5, rmse_test=0.119]
#
#
#
#
#
#
#
#   2%|▏         | 239/10000 [00:09<05:29, 29.65it/s, loss=2.97e-5, rmse_test=0.159]
#
#
#
#
#
#
#
#   2%|▏         | 243/10000 [00:09<05:19, 30.52it/s, loss=2.97e-5, rmse_test=0.159]
#
#
#
#
#
#
#
#   2%|▏         | 243/10000 [00:09<05:19, 30.52it/s, loss=3.15e-5, rmse_test=0.15]
#
#
#
#
#
#
#
#   2%|▏         | 243/10000 [00:09<05:19, 30.52it/s, loss=4.29e-5, rmse_test=0.618]
#
#
#
#
#
#
#
#   2%|▏         | 243/10000 [00:09<05:19, 30.52it/s, loss=3.68e-5, rmse_test=0.185]
#
#
#
#
#
#
#
#   2%|▏         | 243/10000 [00:09<05:19, 30.52it/s, loss=4.14e-5, rmse_test=0.113]
#
#
#
#
#
#
#
#   2%|▏         | 247/10000 [00:09<05:13, 31.07it/s, loss=4.14e-5, rmse_test=0.113]
#
#
#
#
#
#
#
#   2%|▏         | 247/10000 [00:09<05:13, 31.07it/s, loss=3.92e-5, rmse_test=0.0245]
#
#
#
#
#
#
#
#   2%|▏         | 247/10000 [00:09<05:13, 31.07it/s, loss=4.62e-5, rmse_test=0.0252]
#
#
#
#
#
#
#
#   2%|▏         | 247/10000 [00:09<05:13, 31.07it/s, loss=4.13e-5, rmse_test=0.0201]
#
#
#
#
#
#
#
#   2%|▏         | 247/10000 [00:09<05:13, 31.07it/s, loss=3.05e-5, rmse_test=0.0943]
#
#
#
#
#
#
#
#   3%|▎         | 251/10000 [00:09<05:15, 30.88it/s, loss=3.05e-5, rmse_test=0.0943]
#
#
#
#
#
#
#
#   3%|▎         | 251/10000 [00:09<05:15, 30.88it/s, loss=3.9e-5, rmse_test=0.0295]
#
#
#
#
#
#
#
#   3%|▎         | 251/10000 [00:09<05:15, 30.88it/s, loss=4.1e-5, rmse_test=0.0614]
#
#
#
#
#
#
#
#   3%|▎         | 251/10000 [00:09<05:15, 30.88it/s, loss=4.13e-5, rmse_test=0.0251]
#
#
#
#
#
#
#
#   3%|▎         | 251/10000 [00:09<05:15, 30.88it/s, loss=3.29e-5, rmse_test=0.0594]
#
#
#
#
#
#
#
#   3%|▎         | 255/10000 [00:09<05:11, 31.24it/s, loss=3.29e-5, rmse_test=0.0594]
#
#
#
#
#
#
#
#   3%|▎         | 255/10000 [00:09<05:11, 31.24it/s, loss=3.5e-5, rmse_test=0.0358]
#
#
#
#
#
#
#
#   3%|▎         | 255/10000 [00:09<05:11, 31.24it/s, loss=3.78e-5, rmse_test=0.0251]
#
#
#
#
#
#
#
#   3%|▎         | 255/10000 [00:09<05:11, 31.24it/s, loss=3.82e-5, rmse_test=0.0337]
#
#
#
#
#
#
#
#   3%|▎         | 255/10000 [00:09<05:11, 31.24it/s, loss=3.76e-5, rmse_test=0.0249]
#
#
#
#
#
#
#
#   3%|▎         | 259/10000 [00:09<05:15, 30.92it/s, loss=3.76e-5, rmse_test=0.0249]
#
#
#
#
#
#
#
#   3%|▎         | 259/10000 [00:09<05:15, 30.92it/s, loss=2.93e-5, rmse_test=0.0387]
#
#
#
#
#
#
#
#   3%|▎         | 259/10000 [00:09<05:15, 30.92it/s, loss=3.27e-5, rmse_test=0.0242]
#
#
#
#
#
#
#
#   3%|▎         | 259/10000 [00:09<05:15, 30.92it/s, loss=4.37e-5, rmse_test=0.056]
#
#
#
#
#
#
#
#   3%|▎         | 259/10000 [00:09<05:15, 30.92it/s, loss=4.01e-5, rmse_test=0.073]
#
#
#
#
#
#
#
#   3%|▎         | 263/10000 [00:09<05:12, 31.12it/s, loss=4.01e-5, rmse_test=0.073]
#
#
#
#
#
#
#
#   3%|▎         | 263/10000 [00:09<05:12, 31.12it/s, loss=3.79e-5, rmse_test=0.0629]
#
#
#
#
#
#
#
#   3%|▎         | 263/10000 [00:09<05:12, 31.12it/s, loss=4.07e-5, rmse_test=0.0685]
#
#
#
#
#
#
#
#   3%|▎         | 263/10000 [00:09<05:12, 31.12it/s, loss=4.85e-5, rmse_test=0.0713]
#
#
#
#
#
#
#
#   3%|▎         | 263/10000 [00:09<05:12, 31.12it/s, loss=3.78e-5, rmse_test=0.131]
#
#
#
#
#
#
#
#   3%|▎         | 267/10000 [00:09<05:01, 32.27it/s, loss=3.78e-5, rmse_test=0.131]
#
#
#
#
#
#
#
#   3%|▎         | 267/10000 [00:09<05:01, 32.27it/s, loss=3.25e-5, rmse_test=0.102]
#
#
#
#
#
#
#
#   3%|▎         | 267/10000 [00:09<05:01, 32.27it/s, loss=4.5e-5, rmse_test=0.463]
#
#
#
#
#
#
#
#   3%|▎         | 267/10000 [00:10<05:01, 32.27it/s, loss=5.09e-5, rmse_test=0.2]
#   3%|▎         | 267/10000 [00:10<05:01, 32.27it/s, loss=5.8e-5, rmse_test=0.899]
#
#
#
#
#
#
#
#   3%|▎         | 271/10000 [00:10<04:58, 32.60it/s, loss=5.8e-5, rmse_test=0.899]
#
#
#
#
#
#
#
#   3%|▎         | 271/10000 [00:10<04:58, 32.60it/s, loss=4.78e-5, rmse_test=0.0727]
#
#
#
#
#
#
#
#   3%|▎         | 271/10000 [00:10<04:58, 32.60it/s, loss=3.36e-5, rmse_test=0.0896]
#
#
#
#
#
#
#
#   3%|▎         | 271/10000 [00:10<04:58, 32.60it/s, loss=3.92e-5, rmse_test=0.0705]
#
#
#
#
#
#
#
#   3%|▎         | 271/10000 [00:10<04:58, 32.60it/s, loss=4.03e-5, rmse_test=0.0548]
#
#
#
#
#
#
#
#   3%|▎         | 275/10000 [00:10<04:56, 32.82it/s, loss=4.03e-5, rmse_test=0.0548]
#
#
#
#
#
#
#
#   3%|▎         | 275/10000 [00:10<04:56, 32.82it/s, loss=5.06e-5, rmse_test=0.0221]
#
#
#
#
#
#
#
#   3%|▎         | 275/10000 [00:10<04:56, 32.82it/s, loss=3.92e-5, rmse_test=0.0266]
#
#
#
#
#
#
#
#   3%|▎         | 275/10000 [00:10<04:56, 32.82it/s, loss=4.3e-5, rmse_test=0.0602]
#
#
#
#
#
#
#
#   3%|▎         | 275/10000 [00:10<04:56, 32.82it/s, loss=3.64e-5, rmse_test=0.0242]
#
#
#
#
#
#
#
#   3%|▎         | 279/10000 [00:10<04:58, 32.56it/s, loss=3.64e-5, rmse_test=0.0242]
#
#
#
#
#
#
#
#   3%|▎         | 279/10000 [00:10<04:58, 32.56it/s, loss=4.73e-5, rmse_test=0.0441]
#
#
#
#
#
#
#
#   3%|▎         | 279/10000 [00:10<04:58, 32.56it/s, loss=3.58e-5, rmse_test=0.0386]
#
#
#
#
#
#
#
#   3%|▎         | 279/10000 [00:10<04:58, 32.56it/s, loss=4.09e-5, rmse_test=0.0349]
#
#
#
#
#
#
#
#   3%|▎         | 279/10000 [00:10<04:58, 32.56it/s, loss=3.71e-5, rmse_test=0.0512]
#
#
#
#
#
#
#
#   3%|▎         | 283/10000 [00:10<04:56, 32.81it/s, loss=3.71e-5, rmse_test=0.0512]
#
#
#
#
#
#
#
#   3%|▎         | 283/10000 [00:10<04:56, 32.81it/s, loss=3.4e-5, rmse_test=0.0189]
#
#
#
#
#
#
#
#   3%|▎         | 283/10000 [00:10<04:56, 32.81it/s, loss=3.63e-5, rmse_test=0.0175]
#
#
#
#
#
#
#
#   3%|▎         | 283/10000 [00:10<04:56, 32.81it/s, loss=4.8e-5, rmse_test=0.0445]
#
#
#
#
#
#
#
#   3%|▎         | 283/10000 [00:10<04:56, 32.81it/s, loss=4.06e-5, rmse_test=0.0583]
#
#
#
#
#
#
#
#   3%|▎         | 287/10000 [00:10<04:53, 33.06it/s, loss=4.06e-5, rmse_test=0.0583]
#
#
#
#
#
#
#
#   3%|▎         | 287/10000 [00:10<04:53, 33.06it/s, loss=3.53e-5, rmse_test=0.0893]
#
#
#
#
#
#
#
#   3%|▎         | 287/10000 [00:10<04:53, 33.06it/s, loss=4.63e-5, rmse_test=0.0965]
#
#
#
#
#
#
#
#   3%|▎         | 287/10000 [00:10<04:53, 33.06it/s, loss=3.36e-5, rmse_test=0.0608]
#
#
#
#
#
#
#
#   3%|▎         | 287/10000 [00:10<04:53, 33.06it/s, loss=4.16e-5, rmse_test=0.0857]
#
#
#
#
#
#
#
#   3%|▎         | 291/10000 [00:10<04:50, 33.46it/s, loss=4.16e-5, rmse_test=0.0857]
#
#
#
#
#
#
#
#   3%|▎         | 291/10000 [00:10<04:50, 33.46it/s, loss=3.16e-5, rmse_test=0.041]
#
#
#
#
#
#
#
#   3%|▎         | 291/10000 [00:10<04:50, 33.46it/s, loss=3.56e-5, rmse_test=0.0276]
#
#
#
#
#
#
#
#   3%|▎         | 291/10000 [00:10<04:50, 33.46it/s, loss=3.99e-5, rmse_test=0.0544]
#
#
#
#
#
#
#
#   3%|▎         | 291/10000 [00:10<04:50, 33.46it/s, loss=3.84e-5, rmse_test=0.0598]
#
#
#
#
#
#
#
#   3%|▎         | 295/10000 [00:10<05:08, 31.42it/s, loss=3.84e-5, rmse_test=0.0598]
#
#
#
#
#
#
#
#   3%|▎         | 295/10000 [00:10<05:08, 31.42it/s, loss=4.05e-5, rmse_test=0.0913]
#
#
#
#
#
#
#
#   3%|▎         | 295/10000 [00:10<05:08, 31.42it/s, loss=3.87e-5, rmse_test=0.106]
#
#
#
#
#
#
#
#   3%|▎         | 295/10000 [00:10<05:08, 31.42it/s, loss=3.36e-5, rmse_test=0.3]
#
#
#
#
#
#
#
#   3%|▎         | 295/10000 [00:10<05:08, 31.42it/s, loss=4.01e-5, rmse_test=0.092]
#
#
#
#
#
#
#
#   3%|▎         | 299/10000 [00:10<05:15, 30.74it/s, loss=4.01e-5, rmse_test=0.092]
#
#
#
#
#
#
#
#   3%|▎         | 299/10000 [00:10<05:15, 30.74it/s, loss=3.77e-5, rmse_test=0.152]
#
#
#
#
#
#
#
#   3%|▎         | 299/10000 [00:11<05:15, 30.74it/s, loss=3.58e-5, rmse_test=0.069]
#
#
#
#
#
#
#
#   3%|▎         | 299/10000 [00:11<05:15, 30.74it/s, loss=3.78e-5, rmse_test=0.247]
#
#
#
#
#
#
#
#   3%|▎         | 299/10000 [00:11<05:15, 30.74it/s, loss=3.12e-5, rmse_test=0.141]
#
#
#
#
#
#
#
#   3%|▎         | 303/10000 [00:11<05:51, 27.56it/s, loss=3.12e-5, rmse_test=0.141]
#
#
#
#
#
#
#
#   3%|▎         | 303/10000 [00:11<05:51, 27.56it/s, loss=3.59e-5, rmse_test=0.253]
#
#
#
#
#
#
#
#   3%|▎         | 303/10000 [00:11<05:51, 27.56it/s, loss=4.18e-5, rmse_test=0.179]
#
#
#
#
#
#
#
#   3%|▎         | 303/10000 [00:11<05:51, 27.56it/s, loss=3.53e-5, rmse_test=0.192]
#
#
#
#
#
#
#
#   3%|▎         | 303/10000 [00:11<05:51, 27.56it/s, loss=4.87e-5, rmse_test=0.097]
#
#
#
#
#
#
#
#   3%|▎         | 307/10000 [00:11<05:37, 28.75it/s, loss=4.87e-5, rmse_test=0.097]
#
#
#
#
#
#
#
#   3%|▎         | 307/10000 [00:11<05:37, 28.75it/s, loss=4.17e-5, rmse_test=0.14]
#
#
#
#
#
#
#
#   3%|▎         | 307/10000 [00:11<05:37, 28.75it/s, loss=4.48e-5, rmse_test=0.131]
#
#
#
#
#
#
#
#   3%|▎         | 307/10000 [00:11<05:37, 28.75it/s, loss=3.11e-5, rmse_test=0.161]
#
#
#
#
#
#
#
#   3%|▎         | 307/10000 [00:11<05:37, 28.75it/s, loss=3.34e-5, rmse_test=0.103]
#
#
#
#
#
#
#
#   3%|▎         | 311/10000 [00:11<05:18, 30.46it/s, loss=3.34e-5, rmse_test=0.103]
#
#
#
#
#
#
#
#   3%|▎         | 311/10000 [00:11<05:18, 30.46it/s, loss=3.59e-5, rmse_test=0.377]
#
#
#
#
#
#
#
#   3%|▎         | 311/10000 [00:11<05:18, 30.46it/s, loss=3.16e-5, rmse_test=0.132]
#
#
#
#
#
#
#
#   3%|▎         | 311/10000 [00:11<05:18, 30.46it/s, loss=3.8e-5, rmse_test=0.2]
#
#
#
#
#
#
#
#   3%|▎         | 311/10000 [00:11<05:18, 30.46it/s, loss=4.68e-5, rmse_test=0.0924]
#
#
#
#
#
#
#
#   3%|▎         | 315/10000 [00:11<05:11, 31.14it/s, loss=4.68e-5, rmse_test=0.0924]
#
#
#
#
#
#
#
#   3%|▎         | 315/10000 [00:11<05:11, 31.14it/s, loss=3.5e-5, rmse_test=0.024]
#
#
#
#
#
#
#
#   3%|▎         | 315/10000 [00:11<05:11, 31.14it/s, loss=3.41e-5, rmse_test=0.0252]
#
#
#
#
#
#
#
#   3%|▎         | 315/10000 [00:11<05:11, 31.14it/s, loss=3.66e-5, rmse_test=0.0496]
#
#
#
#
#
#
#
#   3%|▎         | 315/10000 [00:11<05:11, 31.14it/s, loss=4.03e-5, rmse_test=0.0638]
#
#
#
#
#
#
#
#   3%|▎         | 319/10000 [00:11<05:05, 31.66it/s, loss=4.03e-5, rmse_test=0.0638]
#
#
#
#
#
#
#
#   3%|▎         | 319/10000 [00:11<05:05, 31.66it/s, loss=5.29e-5, rmse_test=0.103]
#
#
#
#
#
#
#
#   3%|▎         | 319/10000 [00:11<05:05, 31.66it/s, loss=4.74e-5, rmse_test=0.077]
#
#
#
#
#
#
#
#   3%|▎         | 319/10000 [00:11<05:05, 31.66it/s, loss=4.42e-5, rmse_test=0.121]
#
#
#
#
#
#
#
#   3%|▎         | 319/10000 [00:11<05:05, 31.66it/s, loss=3.05e-5, rmse_test=0.0278]
#
#
#
#
#
#
#
#   3%|▎         | 323/10000 [00:11<05:01, 32.10it/s, loss=3.05e-5, rmse_test=0.0278]
#
#
#
#
#
#
#
#   3%|▎         | 323/10000 [00:11<05:01, 32.10it/s, loss=2.89e-5, rmse_test=0.07]
#
#
#
#
#
#
#
#   3%|▎         | 323/10000 [00:11<05:01, 32.10it/s, loss=3.69e-5, rmse_test=0.0927]
#
#
#
#
#
#
#
#   3%|▎         | 323/10000 [00:11<05:01, 32.10it/s, loss=3.82e-5, rmse_test=0.161]
#
#
#
#
#
#
#
#   3%|▎         | 323/10000 [00:11<05:01, 32.10it/s, loss=2.82e-5, rmse_test=0.182]
#   3%|▎         | 327/10000 [00:11<04:59, 32.33it/s, loss=2.82e-5, rmse_test=0.182]
#
#
#
#
#
#
#
#   3%|▎         | 327/10000 [00:11<04:59, 32.33it/s, loss=2.67e-5, rmse_test=0.57]
#
#
#
#
#
#
#
#   3%|▎         | 327/10000 [00:11<04:59, 32.33it/s, loss=4.26e-5, rmse_test=0.124]
#
#
#
#
#
#
#
#   3%|▎         | 327/10000 [00:11<04:59, 32.33it/s, loss=3.37e-5, rmse_test=0.0775]
#
#
#
#
#
#
#
#   3%|▎         | 327/10000 [00:11<04:59, 32.33it/s, loss=4.09e-5, rmse_test=0.0631]
#
#
#
#
#
#
#
#   3%|▎         | 331/10000 [00:11<04:56, 32.56it/s, loss=4.09e-5, rmse_test=0.0631]
#
#
#
#
#
#
#
#   3%|▎         | 331/10000 [00:11<04:56, 32.56it/s, loss=2.82e-5, rmse_test=0.0938]
#
#
#
#
#
#
#
#   3%|▎         | 331/10000 [00:12<04:56, 32.56it/s, loss=3.87e-5, rmse_test=0.0981]
#
#
#
#
#
#
#
#   3%|▎         | 331/10000 [00:12<04:56, 32.56it/s, loss=2.95e-5, rmse_test=0.223]
#
#
#
#
#
#
#
#   3%|▎         | 331/10000 [00:12<04:56, 32.56it/s, loss=3.98e-5, rmse_test=0.0933]
#
#
#
#
#
#
#
#   3%|▎         | 335/10000 [00:12<04:52, 33.01it/s, loss=3.98e-5, rmse_test=0.0933]
#
#
#
#
#
#
#
#   3%|▎         | 335/10000 [00:12<04:52, 33.01it/s, loss=5.02e-5, rmse_test=0.244]
#
#
#
#
#
#
#
#   3%|▎         | 335/10000 [00:12<04:52, 33.01it/s, loss=4.37e-5, rmse_test=0.175]
#
#
#
#
#
#
#
#   3%|▎         | 335/10000 [00:12<04:52, 33.01it/s, loss=4.16e-5, rmse_test=0.144]
#
#
#
#
#
#
#
#   3%|▎         | 335/10000 [00:12<04:52, 33.01it/s, loss=3.12e-5, rmse_test=0.12]
#
#
#
#
#
#
#
#   3%|▎         | 339/10000 [00:12<04:55, 32.65it/s, loss=3.12e-5, rmse_test=0.12]
#
#
#
#
#
#
#
#   3%|▎         | 339/10000 [00:12<04:55, 32.65it/s, loss=4.15e-5, rmse_test=0.272]
#
#
#
#
#
#
#
#   3%|▎         | 339/10000 [00:12<04:55, 32.65it/s, loss=4.37e-5, rmse_test=0.167]
#
#
#
#
#
#
#
#   3%|▎         | 339/10000 [00:12<04:55, 32.65it/s, loss=3.55e-5, rmse_test=0.426]
#
#
#
#
#
#
#
#   3%|▎         | 339/10000 [00:12<04:55, 32.65it/s, loss=3.47e-5, rmse_test=0.204]
#
#
#
#
#
#
#
#   3%|▎         | 343/10000 [00:12<04:51, 33.15it/s, loss=3.47e-5, rmse_test=0.204]
#
#
#
#
#
#
#
#   3%|▎         | 343/10000 [00:12<04:51, 33.15it/s, loss=3.57e-5, rmse_test=0.393]
#
#
#
#
#
#
#
#   3%|▎         | 343/10000 [00:12<04:51, 33.15it/s, loss=4.25e-5, rmse_test=0.186]
#
#
#
#
#
#
#
#   3%|▎         | 343/10000 [00:12<04:51, 33.15it/s, loss=3.78e-5, rmse_test=0.193]
#
#
#
#
#
#
#
#   3%|▎         | 343/10000 [00:12<04:51, 33.15it/s, loss=3.44e-5, rmse_test=0.101]
#
#
#
#
#
#
#
#   3%|▎         | 347/10000 [00:12<05:00, 32.11it/s, loss=3.44e-5, rmse_test=0.101]
#
#
#
#
#
#
#
#   3%|▎         | 347/10000 [00:12<05:00, 32.11it/s, loss=4.56e-5, rmse_test=0.0917]
#
#
#
#
#
#
#
#   3%|▎         | 347/10000 [00:12<05:00, 32.11it/s, loss=4.86e-5, rmse_test=0.0282]
#
#
#
#
#
#
#
#   3%|▎         | 347/10000 [00:12<05:00, 32.11it/s, loss=3.57e-5, rmse_test=0.0307]
#
#
#
#
#
#
#
#   3%|▎         | 347/10000 [00:12<05:00, 32.11it/s, loss=3.89e-5, rmse_test=0.0226]
#
#
#
#
#
#
#
#   4%|▎         | 351/10000 [00:12<05:06, 31.52it/s, loss=3.89e-5, rmse_test=0.0226]
#
#
#
#
#
#
#
#   4%|▎         | 351/10000 [00:12<05:06, 31.52it/s, loss=3.26e-5, rmse_test=0.0408]
#
#
#
#
#
#
#
#   4%|▎         | 351/10000 [00:12<05:06, 31.52it/s, loss=3.04e-5, rmse_test=0.0661]
#
#
#
#
#
#
#
#   4%|▎         | 351/10000 [00:12<05:06, 31.52it/s, loss=4.71e-5, rmse_test=0.0154]
#
#
#
#
#
#
#
#   4%|▎         | 351/10000 [00:12<05:06, 31.52it/s, loss=3.75e-5, rmse_test=0.0325]
#
#
#
#
#
#
#
#   4%|▎         | 355/10000 [00:12<05:15, 30.57it/s, loss=3.75e-5, rmse_test=0.0325]
#
#
#
#
#
#
#
#   4%|▎         | 355/10000 [00:12<05:15, 30.57it/s, loss=4.62e-5, rmse_test=0.0424]
#
#
#
#
#
#
#
#   4%|▎         | 355/10000 [00:12<05:15, 30.57it/s, loss=2.55e-5, rmse_test=0.0219]
#
#
#
#
#
#
#
#   4%|▎         | 355/10000 [00:12<05:15, 30.57it/s, loss=3.29e-5, rmse_test=0.109]
#
#
#
#
#
#
#
#   4%|▎         | 355/10000 [00:12<05:15, 30.57it/s, loss=3.87e-5, rmse_test=0.124]
#
#
#
#
#
#
#
#   4%|▎         | 359/10000 [00:12<05:16, 30.42it/s, loss=3.87e-5, rmse_test=0.124]
#
#
#
#
#
#
#
#   4%|▎         | 359/10000 [00:12<05:16, 30.42it/s, loss=4.42e-5, rmse_test=0.41]
#
#
#
#
#
#
#
#   4%|▎         | 359/10000 [00:12<05:16, 30.42it/s, loss=4.68e-5, rmse_test=0.122]
#
#
#
#
#
#
#
#   4%|▎         | 359/10000 [00:12<05:16, 30.42it/s, loss=4.41e-5, rmse_test=0.232]
#
#
#
#
#
#
#
#   4%|▎         | 359/10000 [00:12<05:16, 30.42it/s, loss=3.76e-5, rmse_test=0.085]
#
#
#
#
#
#
#
#   4%|▎         | 363/10000 [00:12<05:13, 30.71it/s, loss=3.76e-5, rmse_test=0.085]
#
#
#
#
#
#
#
#   4%|▎         | 363/10000 [00:13<05:13, 30.71it/s, loss=4.17e-5, rmse_test=0.0264]
#
#
#
#
#
#
#
#   4%|▎         | 363/10000 [00:13<05:13, 30.71it/s, loss=5.6e-5, rmse_test=0.0231]
#
#
#
#
#
#
#
#   4%|▎         | 363/10000 [00:13<05:13, 30.71it/s, loss=5.03e-5, rmse_test=0.0863]
#
#
#
#
#
#
#
#   4%|▎         | 363/10000 [00:13<05:13, 30.71it/s, loss=5.02e-5, rmse_test=0.0411]
#
#
#
#
#
#
#
#   4%|▎         | 367/10000 [00:13<05:17, 30.34it/s, loss=5.02e-5, rmse_test=0.0411]
#
#
#
#
#
#
#
#   4%|▎         | 367/10000 [00:13<05:17, 30.34it/s, loss=4.38e-5, rmse_test=0.105]
#
#
#
#
#
#
#
#   4%|▎         | 367/10000 [00:13<05:17, 30.34it/s, loss=3.18e-5, rmse_test=0.128]
#
#
#
#
#
#
#
#   4%|▎         | 367/10000 [00:13<05:17, 30.34it/s, loss=4.11e-5, rmse_test=0.308]
#
#
#
#
#
#
#
#   4%|▎         | 367/10000 [00:13<05:17, 30.34it/s, loss=4.42e-5, rmse_test=0.179]
#
#
#
#
#
#
#
#   4%|▎         | 371/10000 [00:13<05:17, 30.29it/s, loss=4.42e-5, rmse_test=0.179]
#
#
#
#
#
#
#
#   4%|▎         | 371/10000 [00:13<05:17, 30.29it/s, loss=5.83e-5, rmse_test=0.557]
#
#
#
#
#
#
#
#   4%|▎         | 371/10000 [00:13<05:17, 30.29it/s, loss=4.45e-5, rmse_test=0.226]
#
#
#
#
#
#
#
#   4%|▎         | 371/10000 [00:13<05:17, 30.29it/s, loss=4.3e-5, rmse_test=0.624]
#
#
#
#
#
#
#
#   4%|▎         | 371/10000 [00:13<05:17, 30.29it/s, loss=3.35e-5, rmse_test=0.195]
#
#
#
#
#
#
#
#   4%|▍         | 375/10000 [00:13<05:21, 29.90it/s, loss=3.35e-5, rmse_test=0.195]
#
#
#
#
#
#
#
#   4%|▍         | 375/10000 [00:13<05:21, 29.90it/s, loss=3.59e-5, rmse_test=0.131]
#
#
#
#
#
#
#
#   4%|▍         | 375/10000 [00:13<05:21, 29.90it/s, loss=5.6e-5, rmse_test=0.0432]
#
#
#
#
#
#
#
#   4%|▍         | 375/10000 [00:13<05:21, 29.90it/s, loss=5.62e-5, rmse_test=0.0744]
#
#
#
#
#
#
#
#   4%|▍         | 378/10000 [00:13<05:46, 27.75it/s, loss=5.62e-5, rmse_test=0.0744]
#
#
#
#
#
#
#
#   4%|▍         | 378/10000 [00:13<05:46, 27.75it/s, loss=3.5e-5, rmse_test=0.0307]
#
#
#
#
#
#
#
#   4%|▍         | 378/10000 [00:13<05:46, 27.75it/s, loss=5.28e-5, rmse_test=0.0424]
#
#
#
#
#
#
#
#   4%|▍         | 378/10000 [00:13<05:46, 27.75it/s, loss=3.55e-5, rmse_test=0.0779]
#
#
#
#
#
#
#
#   4%|▍         | 381/10000 [00:13<05:53, 27.20it/s, loss=3.55e-5, rmse_test=0.0779]
#
#
#
#
#
#
#
#   4%|▍         | 381/10000 [00:13<05:53, 27.20it/s, loss=2.64e-5, rmse_test=0.073]
#
#
#
#
#
#
#
#   4%|▍         | 381/10000 [00:13<05:53, 27.20it/s, loss=4.36e-5, rmse_test=0.126]
#   4%|▍         | 381/10000 [00:13<05:53, 27.20it/s, loss=4.58e-5, rmse_test=0.098]
#
#
#
#
#
#
#
#   4%|▍         | 384/10000 [00:13<05:58, 26.83it/s, loss=4.58e-5, rmse_test=0.098]
#
#
#
#
#
#
#
#   4%|▍         | 384/10000 [00:13<05:58, 26.83it/s, loss=4.3e-5, rmse_test=0.134]
#
#
#
#
#
#
#
#   4%|▍         | 384/10000 [00:13<05:58, 26.83it/s, loss=3.52e-5, rmse_test=0.0449]
#
#
#
#
#
#
#
#   4%|▍         | 384/10000 [00:13<05:58, 26.83it/s, loss=5.09e-5, rmse_test=0.0921]
#
#
#
#
#
#
#
#   4%|▍         | 387/10000 [00:13<06:03, 26.46it/s, loss=5.09e-5, rmse_test=0.0921]
#
#
#
#
#
#
#
#   4%|▍         | 387/10000 [00:13<06:03, 26.46it/s, loss=3.05e-5, rmse_test=0.109]
#
#
#
#
#
#
#
#   4%|▍         | 387/10000 [00:13<06:03, 26.46it/s, loss=3.74e-5, rmse_test=0.301]
#
#
#
#
#
#
#
#   4%|▍         | 387/10000 [00:13<06:03, 26.46it/s, loss=4.37e-5, rmse_test=0.269]
#
#
#
#
#
#
#
#   4%|▍         | 390/10000 [00:13<06:09, 26.01it/s, loss=4.37e-5, rmse_test=0.269]
#
#
#
#
#
#
#
#   4%|▍         | 390/10000 [00:14<06:09, 26.01it/s, loss=4.65e-5, rmse_test=0.751]
#
#
#
#
#
#
#
#   4%|▍         | 390/10000 [00:14<06:09, 26.01it/s, loss=4.33e-5, rmse_test=0.239]
#
#
#
#
#
#
#
#   4%|▍         | 390/10000 [00:14<06:09, 26.01it/s, loss=4.55e-5, rmse_test=0.324]
#
#
#
#
#
#
#
#   4%|▍         | 393/10000 [00:14<06:08, 26.09it/s, loss=4.55e-5, rmse_test=0.324]
#
#
#
#
#
#
#
#   4%|▍         | 393/10000 [00:14<06:08, 26.09it/s, loss=4.66e-5, rmse_test=0.141]
#
#
#
#
#
#
#
#   4%|▍         | 393/10000 [00:14<06:08, 26.09it/s, loss=4.6e-5, rmse_test=0.269]
#
#
#
#
#
#
#
#   4%|▍         | 393/10000 [00:14<06:08, 26.09it/s, loss=3.09e-5, rmse_test=0.0521]
#
#
#
#
#
#
#
#   4%|▍         | 396/10000 [00:14<06:01, 26.55it/s, loss=3.09e-5, rmse_test=0.0521]
#
#
#
#
#
#
#
#   4%|▍         | 396/10000 [00:14<06:01, 26.55it/s, loss=3.19e-5, rmse_test=0.0436]
#
#
#
#
#
#
#
#   4%|▍         | 396/10000 [00:14<06:01, 26.55it/s, loss=4.99e-5, rmse_test=0.0517]
#
#
#
#
#
#
#
#   4%|▍         | 396/10000 [00:14<06:01, 26.55it/s, loss=4.24e-5, rmse_test=0.026]
#
#
#
#
#
#
#
#   4%|▍         | 399/10000 [00:14<05:53, 27.15it/s, loss=4.24e-5, rmse_test=0.026]
#
#
#
#
#
#
#
#   4%|▍         | 399/10000 [00:14<05:53, 27.15it/s, loss=4.44e-5, rmse_test=0.0764]
#
#
#
#
#
#
#
#   4%|▍         | 399/10000 [00:14<05:53, 27.15it/s, loss=5.19e-5, rmse_test=0.1]
#
#
#
#
#
#
#
#   4%|▍         | 399/10000 [00:14<05:53, 27.15it/s, loss=3.2e-5, rmse_test=0.0408]
#
#
#
#
#
#
#
#   4%|▍         | 402/10000 [00:14<06:56, 23.06it/s, loss=3.2e-5, rmse_test=0.0408]
#
#
#
#
#
#
#
#   4%|▍         | 402/10000 [00:14<06:56, 23.06it/s, loss=2.92e-5, rmse_test=0.0275]
#
#
#
#
#
#
#
#   4%|▍         | 402/10000 [00:14<06:56, 23.06it/s, loss=4.21e-5, rmse_test=0.0227]
#
#
#
#
#
#
#
#   4%|▍         | 402/10000 [00:14<06:56, 23.06it/s, loss=3.64e-5, rmse_test=0.121]
#
#
#
#
#
#
#
#   4%|▍         | 405/10000 [00:14<06:32, 24.44it/s, loss=3.64e-5, rmse_test=0.121]
#
#
#
#
#
#
#
#   4%|▍         | 405/10000 [00:14<06:32, 24.44it/s, loss=4.34e-5, rmse_test=0.0796]
#
#
#
#
#
#
#
#   4%|▍         | 405/10000 [00:14<06:32, 24.44it/s, loss=6.25e-5, rmse_test=0.0577]
#
#
#
#
#
#
#
#   4%|▍         | 405/10000 [00:14<06:32, 24.44it/s, loss=3.63e-5, rmse_test=0.0478]
#
#
#
#
#
#
#
#   4%|▍         | 408/10000 [00:14<06:13, 25.66it/s, loss=3.63e-5, rmse_test=0.0478]
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#  47%|████▋     | 4744/10000 [03:15<03:20, 26.25it/s, loss=4.62e-8, rmse_test=0.00892]
#
#
#
#
#
#
#
#  47%|████▋     | 4744/10000 [03:15<03:20, 26.25it/s, loss=4.49e-8, rmse_test=0.0226]
#
#
#
#
#
#
#
#  47%|████▋     | 4747/10000 [03:15<03:15, 26.82it/s, loss=4.49e-8, rmse_test=0.0226]
#
#
#
#
#
#
#
#  47%|████▋     | 4747/10000 [03:15<03:15, 26.82it/s, loss=4.76e-8, rmse_test=0.0134]
#
#
#
#
#
#
#
#  47%|████▋     | 4747/10000 [03:15<03:15, 26.82it/s, loss=4.29e-8, rmse_test=0.0125]
#
#
#
#
#
#
#
#  47%|████▋     | 4747/10000 [03:15<03:15, 26.82it/s, loss=4.35e-8, rmse_test=0.0111]
#
#
#
#
#
#
#
#  48%|████▊     | 4750/10000 [03:15<03:16, 26.68it/s, loss=4.35e-8, rmse_test=0.0111]
#
#
#
#
#
#
#
#  48%|████▊     | 4750/10000 [03:15<03:16, 26.68it/s, loss=4.48e-8, rmse_test=0.0124]
#
#
#
#
#
#
#
#  48%|████▊     | 4750/10000 [03:15<03:16, 26.68it/s, loss=4.65e-8, rmse_test=0.0116]
#
#
#
#
#
#
#
#  48%|████▊     | 4750/10000 [03:16<03:16, 26.68it/s, loss=4.66e-8, rmse_test=0.00894]
#
#
#
#
#
#
#
#  48%|████▊     | 4753/10000 [03:16<03:13, 27.10it/s, loss=4.66e-8, rmse_test=0.00894]
#
#
#
#
#
#
#
#  48%|████▊     | 4753/10000 [03:16<03:13, 27.10it/s, loss=4.56e-8, rmse_test=0.0133]
#
#
#
#
#
#
#
#  48%|████▊     | 4753/10000 [03:16<03:13, 27.10it/s, loss=4.52e-8, rmse_test=0.0129]
#
#
#
#
#
#
#
#  48%|████▊     | 4753/10000 [03:16<03:13, 27.10it/s, loss=4.45e-8, rmse_test=0.0172]
#
#
#
#
#
#
#
#  48%|████▊     | 4756/10000 [03:16<03:08, 27.75it/s, loss=4.45e-8, rmse_test=0.0172]
#
#
#
#
#
#
#
#  48%|████▊     | 4756/10000 [03:16<03:08, 27.75it/s, loss=4.39e-8, rmse_test=0.021]
#
#
#
#
#
#
#
#  48%|████▊     | 4756/10000 [03:16<03:08, 27.75it/s, loss=4.35e-8, rmse_test=0.00951]
#
#
#
#
#
#
#
#  48%|████▊     | 4756/10000 [03:16<03:08, 27.75it/s, loss=4.42e-8, rmse_test=0.0118]
#  48%|████▊     | 4759/10000 [03:16<03:14, 27.00it/s, loss=4.42e-8, rmse_test=0.0118]
#
#
#
#
#
#
#
#  48%|████▊     | 4759/10000 [03:16<03:14, 27.00it/s, loss=4.17e-8, rmse_test=0.0155]
#
#
#
#
#
#
#
#  48%|████▊     | 4759/10000 [03:16<03:14, 27.00it/s, loss=4.55e-8, rmse_test=0.0124]
#
#
#
#
#
#
#
#  48%|████▊     | 4759/10000 [03:16<03:14, 27.00it/s, loss=4.42e-8, rmse_test=0.0096]
#
#
#
#
#
#
#
#  48%|████▊     | 4762/10000 [03:16<03:11, 27.41it/s, loss=4.42e-8, rmse_test=0.0096]
#
#
#
#
#
#
#
#  48%|████▊     | 4762/10000 [03:16<03:11, 27.41it/s, loss=4.41e-8, rmse_test=0.0119]
#
#
#
#
#
#
#
#  48%|████▊     | 4762/10000 [03:16<03:11, 27.41it/s, loss=4.39e-8, rmse_test=0.012]
#
#
#
#
#
#
#
#  48%|████▊     | 4762/10000 [03:16<03:11, 27.41it/s, loss=4.3e-8, rmse_test=0.00857]
#
#
#
#
#
#
#
#  48%|████▊     | 4765/10000 [03:16<03:07, 27.88it/s, loss=4.3e-8, rmse_test=0.00857]
#
#
#
#
#
#
#
#  48%|████▊     | 4765/10000 [03:16<03:07, 27.88it/s, loss=4.43e-8, rmse_test=0.00974]
#
#
#
#
#
#
#
#  48%|████▊     | 4765/10000 [03:16<03:07, 27.88it/s, loss=4.5e-8, rmse_test=0.0183]
#
#
#
#
#
#
#
#  48%|████▊     | 4765/10000 [03:16<03:07, 27.88it/s, loss=4.41e-8, rmse_test=0.0133]
#
#
#
#
#
#
#
#  48%|████▊     | 4768/10000 [03:16<03:07, 27.89it/s, loss=4.41e-8, rmse_test=0.0133]
#
#
#
#
#
#
#
#  48%|████▊     | 4768/10000 [03:16<03:07, 27.89it/s, loss=4.32e-8, rmse_test=0.00874]
#
#
#
#
#
#
#
#  48%|████▊     | 4768/10000 [03:16<03:07, 27.89it/s, loss=4.29e-8, rmse_test=0.0157]
#
#
#
#
#
#
#
#  48%|████▊     | 4768/10000 [03:16<03:07, 27.89it/s, loss=4.33e-8, rmse_test=0.0188]
#
#
#
#
#
#
#
#  48%|████▊     | 4771/10000 [03:16<03:08, 27.81it/s, loss=4.33e-8, rmse_test=0.0188]
#
#
#
#
#
#
#
#  48%|████▊     | 4771/10000 [03:16<03:08, 27.81it/s, loss=4.46e-8, rmse_test=0.0159]
#
#
#
#
#
#
#
#  48%|████▊     | 4771/10000 [03:16<03:08, 27.81it/s, loss=4.25e-8, rmse_test=0.0119]
#
#
#
#
#
#
#
#  48%|████▊     | 4771/10000 [03:16<03:08, 27.81it/s, loss=4.45e-8, rmse_test=0.0203]
#
#
#
#
#
#
#
#  48%|████▊     | 4774/10000 [03:16<03:05, 28.10it/s, loss=4.45e-8, rmse_test=0.0203]
#
#
#
#
#
#
#
#  48%|████▊     | 4774/10000 [03:16<03:05, 28.10it/s, loss=4.35e-8, rmse_test=0.0214]
#
#
#
#
#
#
#
#  48%|████▊     | 4774/10000 [03:16<03:05, 28.10it/s, loss=4.5e-8, rmse_test=0.0138]
#
#
#
#
#
#
#
#  48%|████▊     | 4774/10000 [03:16<03:05, 28.10it/s, loss=4.41e-8, rmse_test=0.0139]
#
#
#
#
#
#
#
#  48%|████▊     | 4777/10000 [03:16<03:10, 27.38it/s, loss=4.41e-8, rmse_test=0.0139]
#
#
#
#
#
#
#
#  48%|████▊     | 4777/10000 [03:16<03:10, 27.38it/s, loss=4.51e-8, rmse_test=0.0124]
#
#
#
#
#
#
#
#  48%|████▊     | 4777/10000 [03:16<03:10, 27.38it/s, loss=4.54e-8, rmse_test=0.0127]
#
#
#
#
#
#
#
#  48%|████▊     | 4777/10000 [03:16<03:10, 27.38it/s, loss=4.44e-8, rmse_test=0.0154]
#
#
#
#
#
#
#
#  48%|████▊     | 4780/10000 [03:16<03:08, 27.76it/s, loss=4.44e-8, rmse_test=0.0154]
#
#
#
#
#
#
#
#  48%|████▊     | 4780/10000 [03:17<03:08, 27.76it/s, loss=4.27e-8, rmse_test=0.0151]
#
#
#
#
#
#
#
#  48%|████▊     | 4780/10000 [03:17<03:08, 27.76it/s, loss=4.44e-8, rmse_test=0.0138]
#
#
#
#
#
#
#
#  48%|████▊     | 4780/10000 [03:17<03:08, 27.76it/s, loss=4.23e-8, rmse_test=0.011]
#
#
#
#
#
#
#
#  48%|████▊     | 4783/10000 [03:17<03:06, 27.97it/s, loss=4.23e-8, rmse_test=0.011]
#
#
#
#
#
#
#
#  48%|████▊     | 4783/10000 [03:17<03:06, 27.97it/s, loss=4.4e-8, rmse_test=0.024]
#
#
#
#
#
#
#
#  48%|████▊     | 4783/10000 [03:17<03:06, 27.97it/s, loss=4.47e-8, rmse_test=0.0113]
#
#
#
#
#
#
#
#  48%|████▊     | 4783/10000 [03:17<03:06, 27.97it/s, loss=4.54e-8, rmse_test=0.013]
#
#
#
#
#
#
#
#  48%|████▊     | 4786/10000 [03:17<03:06, 27.99it/s, loss=4.54e-8, rmse_test=0.013]
#
#
#
#
#
#
#
#  48%|████▊     | 4786/10000 [03:17<03:06, 27.99it/s, loss=4.47e-8, rmse_test=0.0125]
#
#
#
#
#
#
#
#  48%|████▊     | 4786/10000 [03:17<03:06, 27.99it/s, loss=4.81e-8, rmse_test=0.0227]
#
#
#
#
#
#
#
#  48%|████▊     | 4786/10000 [03:17<03:06, 27.99it/s, loss=4.73e-8, rmse_test=0.0106]
#
#
#
#
#
#
#
#  48%|████▊     | 4789/10000 [03:17<03:10, 27.35it/s, loss=4.73e-8, rmse_test=0.0106]
#
#
#
#
#
#
#
#  48%|████▊     | 4789/10000 [03:17<03:10, 27.35it/s, loss=4.21e-8, rmse_test=0.0131]
#
#
#
#
#
#
#
#  48%|████▊     | 4789/10000 [03:17<03:10, 27.35it/s, loss=4.28e-8, rmse_test=0.0107]
#
#
#
#
#
#
#
#  48%|████▊     | 4789/10000 [03:17<03:10, 27.35it/s, loss=4.21e-8, rmse_test=0.0119]
#
#
#
#
#
#
#
#  48%|████▊     | 4792/10000 [03:17<03:13, 26.86it/s, loss=4.21e-8, rmse_test=0.0119]
#
#
#
#
#
#
#
#  48%|████▊     | 4792/10000 [03:17<03:13, 26.86it/s, loss=4.48e-8, rmse_test=0.0122]
#
#
#
#
#
#
#
#  48%|████▊     | 4792/10000 [03:17<03:13, 26.86it/s, loss=4.52e-8, rmse_test=0.0129]
#
#
#
#
#
#
#
#  48%|████▊     | 4792/10000 [03:17<03:13, 26.86it/s, loss=4.48e-8, rmse_test=0.0149]
#
#
#
#
#
#
#
#  48%|████▊     | 4795/10000 [03:17<03:08, 27.60it/s, loss=4.48e-8, rmse_test=0.0149]
#
#
#
#
#
#
#
#  48%|████▊     | 4795/10000 [03:17<03:08, 27.60it/s, loss=4.77e-8, rmse_test=0.0326]
#
#
#
#
#
#
#
#  48%|████▊     | 4795/10000 [03:17<03:08, 27.60it/s, loss=4.47e-8, rmse_test=0.0124]
#
#
#
#
#
#
#
#  48%|████▊     | 4795/10000 [03:17<03:08, 27.60it/s, loss=4.33e-8, rmse_test=0.0137]
#
#
#
#
#
#
#
#  48%|████▊     | 4798/10000 [03:17<03:08, 27.64it/s, loss=4.33e-8, rmse_test=0.0137]
#
#
#
#
#
#
#
#  48%|████▊     | 4798/10000 [03:17<03:08, 27.64it/s, loss=4.5e-8, rmse_test=0.0161]
#
#
#
#
#
#
#
#  48%|████▊     | 4798/10000 [03:17<03:08, 27.64it/s, loss=4.45e-8, rmse_test=0.0097]
#
#
#
#
#
#
#
#  48%|████▊     | 4798/10000 [03:18<03:08, 27.64it/s, loss=4.51e-8, rmse_test=0.0136]
#
#
#
#
#
#
#
#  48%|████▊     | 4801/10000 [03:18<10:15,  8.44it/s, loss=4.51e-8, rmse_test=0.0136]
#
#
#
#
#
#
#
#  48%|████▊     | 4801/10000 [03:18<10:15,  8.44it/s, loss=4.34e-8, rmse_test=0.00926]
#
#
#
#
#
#
#
#  48%|████▊     | 4801/10000 [03:18<10:15,  8.44it/s, loss=4.46e-8, rmse_test=0.0148]
#
#
#
#
#
#
#
#  48%|████▊     | 4801/10000 [03:18<10:15,  8.44it/s, loss=4.43e-8, rmse_test=0.0148]
#
#
#
#
#
#
#
#  48%|████▊     | 4804/10000 [03:18<08:20, 10.38it/s, loss=4.43e-8, rmse_test=0.0148]
#
#
#
#
#
#
#
#  48%|████▊     | 4804/10000 [03:18<08:20, 10.38it/s, loss=4.42e-8, rmse_test=0.012]
#
#
#
#
#
#
#
#  48%|████▊     | 4804/10000 [03:18<08:20, 10.38it/s, loss=4.37e-8, rmse_test=0.0118]
#
#
#
#
#
#
#
#  48%|████▊     | 4804/10000 [03:18<08:20, 10.38it/s, loss=4.24e-8, rmse_test=0.00954]
#
#
#
#
#
#
#
#  48%|████▊     | 4807/10000 [03:18<06:55, 12.50it/s, loss=4.24e-8, rmse_test=0.00954]
#
#
#
#
#
#
#
#  48%|████▊     | 4807/10000 [03:18<06:55, 12.50it/s, loss=4.37e-8, rmse_test=0.00936]
#
#
#
#
#
#
#
#  48%|████▊     | 4807/10000 [03:18<06:55, 12.50it/s, loss=4.21e-8, rmse_test=0.0106]
#
#
#
#
#
#
#
#  48%|████▊     | 4807/10000 [03:18<06:55, 12.50it/s, loss=4.43e-8, rmse_test=0.0194]
#
#
#
#
#
#
#
#  48%|████▊     | 4810/10000 [03:18<05:53, 14.68it/s, loss=4.43e-8, rmse_test=0.0194]
#
#
#
#
#
#
#
#  48%|████▊     | 4810/10000 [03:18<05:53, 14.68it/s, loss=4.46e-8, rmse_test=0.00855]
#  48%|████▊     | 4810/10000 [03:19<05:53, 14.68it/s, loss=4.26e-8, rmse_test=0.0116]
#
#
#
#
#
#
#
#  48%|████▊     | 4810/10000 [03:19<05:53, 14.68it/s, loss=4.24e-8, rmse_test=0.0113]
#
#
#
#
#
#
#
#  48%|████▊     | 4813/10000 [03:19<05:10, 16.68it/s, loss=4.24e-8, rmse_test=0.0113]
#
#
#
#
#
#
#
#  48%|████▊     | 4813/10000 [03:19<05:10, 16.68it/s, loss=4.27e-8, rmse_test=0.0125]
#
#
#
#
#
#
#
#  48%|████▊     | 4813/10000 [03:19<05:10, 16.68it/s, loss=4.32e-8, rmse_test=0.0117]
#
#
#
#
#
#
#
#  48%|████▊     | 4813/10000 [03:19<05:10, 16.68it/s, loss=4.53e-8, rmse_test=0.0158]
#
#
#
#
#
#
#
#  48%|████▊     | 4816/10000 [03:19<04:41, 18.44it/s, loss=4.53e-8, rmse_test=0.0158]
#
#
#
#
#
#
#
#  48%|████▊     | 4816/10000 [03:19<04:41, 18.44it/s, loss=4.48e-8, rmse_test=0.0142]
#
#
#
#
#
#
#
#  48%|████▊     | 4816/10000 [03:19<04:41, 18.44it/s, loss=4.25e-8, rmse_test=0.0152]
#
#
#
#
#
#
#
#  48%|████▊     | 4816/10000 [03:19<04:41, 18.44it/s, loss=4.35e-8, rmse_test=0.0119]
#
#
#
#
#
#
#
#  48%|████▊     | 4819/10000 [03:19<04:25, 19.49it/s, loss=4.35e-8, rmse_test=0.0119]
#
#
#
#
#
#
#
#  48%|████▊     | 4819/10000 [03:19<04:25, 19.49it/s, loss=4.7e-8, rmse_test=0.0162]
#
#
#
#
#
#
#
#  48%|████▊     | 4819/10000 [03:19<04:25, 19.49it/s, loss=4.41e-8, rmse_test=0.00895]
#
#
#
#
#
#
#
#  48%|████▊     | 4819/10000 [03:19<04:25, 19.49it/s, loss=4.35e-8, rmse_test=0.00951]
#
#
#
#
#
#
#
#  48%|████▊     | 4822/10000 [03:19<03:58, 21.74it/s, loss=4.35e-8, rmse_test=0.00951]
#
#
#
#
#
#
#
#  48%|████▊     | 4822/10000 [03:19<03:58, 21.74it/s, loss=4.42e-8, rmse_test=0.00932]
#
#
#
#
#
#
#
#  48%|████▊     | 4822/10000 [03:19<03:58, 21.74it/s, loss=4.22e-8, rmse_test=0.0177]
#
#
#
#
#
#
#
#  48%|████▊     | 4822/10000 [03:19<03:58, 21.74it/s, loss=4.24e-8, rmse_test=0.011]
#
#
#
#
#
#
#
#  48%|████▊     | 4825/10000 [03:19<03:50, 22.40it/s, loss=4.24e-8, rmse_test=0.011]
#
#
#
#
#
#
#
#  48%|████▊     | 4825/10000 [03:19<03:50, 22.40it/s, loss=4.3e-8, rmse_test=0.0182]
#
#
#
#
#
#
#
#  48%|████▊     | 4825/10000 [03:19<03:50, 22.40it/s, loss=4.44e-8, rmse_test=0.0108]
#
#
#
#
#
#
#
#  48%|████▊     | 4825/10000 [03:19<03:50, 22.40it/s, loss=4.42e-8, rmse_test=0.0282]
#
#
#
#
#
#
#
#  48%|████▊     | 4828/10000 [03:19<03:38, 23.72it/s, loss=4.42e-8, rmse_test=0.0282]
#
#
#
#
#
#
#
#  48%|████▊     | 4828/10000 [03:19<03:38, 23.72it/s, loss=4.5e-8, rmse_test=0.0148]
#
#
#
#
#
#
#
#  48%|████▊     | 4828/10000 [03:19<03:38, 23.72it/s, loss=4.3e-8, rmse_test=0.0127]
#
#
#
#
#
#
#
#  48%|████▊     | 4828/10000 [03:19<03:38, 23.72it/s, loss=4.26e-8, rmse_test=0.00905]
#
#
#
#
#
#
#
#  48%|████▊     | 4831/10000 [03:19<03:26, 25.08it/s, loss=4.26e-8, rmse_test=0.00905]
#
#
#
#
#
#
#
#  48%|████▊     | 4831/10000 [03:19<03:26, 25.08it/s, loss=4.54e-8, rmse_test=0.0352]
#
#
#
#
#
#
#
#  48%|████▊     | 4831/10000 [03:19<03:26, 25.08it/s, loss=4.78e-8, rmse_test=0.0215]
#
#
#
#
#
#
#
#  48%|████▊     | 4831/10000 [03:19<03:26, 25.08it/s, loss=4.46e-8, rmse_test=0.015]
#
#
#
#
#
#
#
#  48%|████▊     | 4834/10000 [03:19<03:30, 24.52it/s, loss=4.46e-8, rmse_test=0.015]
#
#
#
#
#
#
#
#  48%|████▊     | 4834/10000 [03:19<03:30, 24.52it/s, loss=4.39e-8, rmse_test=0.00988]
#
#
#
#
#
#
#
#  48%|████▊     | 4834/10000 [03:19<03:30, 24.52it/s, loss=5.1e-8, rmse_test=0.0163]
#
#
#
#
#
#
#
#  48%|████▊     | 4834/10000 [03:20<03:30, 24.52it/s, loss=4.41e-8, rmse_test=0.011]
#
#
#
#
#
#
#
#  48%|████▊     | 4837/10000 [03:20<03:28, 24.72it/s, loss=4.41e-8, rmse_test=0.011]
#
#
#
#
#
#
#
#  48%|████▊     | 4837/10000 [03:20<03:28, 24.72it/s, loss=4.33e-8, rmse_test=0.00897]
#
#
#
#
#
#
#
#  48%|████▊     | 4837/10000 [03:20<03:28, 24.72it/s, loss=4.32e-8, rmse_test=0.0124]
#
#
#
#
#
#
#
#  48%|████▊     | 4837/10000 [03:20<03:28, 24.72it/s, loss=4.53e-8, rmse_test=0.0152]
#
#
#
#
#
#
#
#  48%|████▊     | 4840/10000 [03:20<03:23, 25.37it/s, loss=4.53e-8, rmse_test=0.0152]
#
#
#
#
#
#
#
#  48%|████▊     | 4840/10000 [03:20<03:23, 25.37it/s, loss=4.54e-8, rmse_test=0.0172]
#
#
#
#
#
#
#
#  48%|████▊     | 4840/10000 [03:20<03:23, 25.37it/s, loss=4.61e-8, rmse_test=0.00998]
#
#
#
#
#
#
#
#  48%|████▊     | 4840/10000 [03:20<03:23, 25.37it/s, loss=4.52e-8, rmse_test=0.0116]
#
#
#
#
#
#
#
#  48%|████▊     | 4843/10000 [03:20<03:23, 25.36it/s, loss=4.52e-8, rmse_test=0.0116]
#
#
#
#
#
#
#
#  48%|████▊     | 4843/10000 [03:20<03:23, 25.36it/s, loss=4.42e-8, rmse_test=0.0141]
#
#
#
#
#
#
#
#  48%|████▊     | 4843/10000 [03:20<03:23, 25.36it/s, loss=4.41e-8, rmse_test=0.0152]
#
#
#
#
#
#
#
#  48%|████▊     | 4843/10000 [03:20<03:23, 25.36it/s, loss=4.43e-8, rmse_test=0.0155]
#
#
#
#
#
#
#
#  48%|████▊     | 4846/10000 [03:20<03:21, 25.56it/s, loss=4.43e-8, rmse_test=0.0155]
#
#
#
#
#
#
#
#  48%|████▊     | 4846/10000 [03:20<03:21, 25.56it/s, loss=4.37e-8, rmse_test=0.0122]
#
#
#
#
#
#
#
#  48%|████▊     | 4846/10000 [03:20<03:21, 25.56it/s, loss=4.78e-8, rmse_test=0.0245]
#
#
#
#
#
#
#
#  48%|████▊     | 4846/10000 [03:20<03:21, 25.56it/s, loss=4.31e-8, rmse_test=0.0135]
#
#
#
#
#
#
#
#  48%|████▊     | 4849/10000 [03:20<03:24, 25.21it/s, loss=4.31e-8, rmse_test=0.0135]
#
#
#
#
#
#
#
#  48%|████▊     | 4849/10000 [03:20<03:24, 25.21it/s, loss=4.25e-8, rmse_test=0.0153]
#
#
#
#
#
#
#
#  48%|████▊     | 4849/10000 [03:20<03:24, 25.21it/s, loss=4.53e-8, rmse_test=0.0118]
#
#
#
#
#
#
#
#  48%|████▊     | 4849/10000 [03:20<03:24, 25.21it/s, loss=4.31e-8, rmse_test=0.0329]
#
#
#
#
#
#
#
#  49%|████▊     | 4852/10000 [03:20<03:17, 26.03it/s, loss=4.31e-8, rmse_test=0.0329]
#
#
#
#
#
#
#
#  49%|████▊     | 4852/10000 [03:20<03:17, 26.03it/s, loss=4.45e-8, rmse_test=0.00977]
#
#
#
#
#
#
#
#  49%|████▊     | 4852/10000 [03:20<03:17, 26.03it/s, loss=4.5e-8, rmse_test=0.0121]
#
#
#
#
#
#
#
#  49%|████▊     | 4852/10000 [03:20<03:17, 26.03it/s, loss=4.15e-8, rmse_test=0.02]
#
#
#
#
#
#
#
#  49%|████▊     | 4855/10000 [03:20<03:25, 25.01it/s, loss=4.15e-8, rmse_test=0.02]
#
#
#
#
#
#
#
#  49%|████▊     | 4855/10000 [03:20<03:25, 25.01it/s, loss=4.34e-8, rmse_test=0.0118]
#
#
#
#
#
#
#
#  49%|████▊     | 4855/10000 [03:20<03:25, 25.01it/s, loss=4.75e-8, rmse_test=0.0107]
#
#
#
#
#
#
#
#  49%|████▊     | 4855/10000 [03:20<03:25, 25.01it/s, loss=4.69e-8, rmse_test=0.0185]
#
#
#
#
#
#
#
#  49%|████▊     | 4858/10000 [03:20<03:36, 23.74it/s, loss=4.69e-8, rmse_test=0.0185]
#
#
#
#
#
#
#
#  49%|████▊     | 4858/10000 [03:20<03:36, 23.74it/s, loss=4.47e-8, rmse_test=0.0138]
#
#
#
#
#
#
#
#  49%|████▊     | 4858/10000 [03:20<03:36, 23.74it/s, loss=4.7e-8, rmse_test=0.0119]
#
#
#
#
#
#
#
#  49%|████▊     | 4858/10000 [03:20<03:36, 23.74it/s, loss=4.47e-8, rmse_test=0.0112]
#
#
#
#
#
#
#
#  49%|████▊     | 4861/10000 [03:20<03:24, 25.08it/s, loss=4.47e-8, rmse_test=0.0112]
#
#
#
#
#
#
#
#  49%|████▊     | 4861/10000 [03:21<03:24, 25.08it/s, loss=4.49e-8, rmse_test=0.0158]
#
#
#
#
#
#
#
#  49%|████▊     | 4861/10000 [03:21<03:24, 25.08it/s, loss=4.28e-8, rmse_test=0.00931]
#
#
#
#
#
#
#
#  49%|████▊     | 4861/10000 [03:21<03:24, 25.08it/s, loss=4.57e-8, rmse_test=0.0208]
#  49%|████▊     | 4864/10000 [03:21<03:26, 24.82it/s, loss=4.57e-8, rmse_test=0.0208]
#
#
#
#
#
#
#
#  49%|████▊     | 4864/10000 [03:21<03:26, 24.82it/s, loss=4.59e-8, rmse_test=0.0127]
#
#
#
#
#
#
#
#  49%|████▊     | 4864/10000 [03:21<03:26, 24.82it/s, loss=4.46e-8, rmse_test=0.0258]
#
#
#
#
#
#
#
#  49%|████▊     | 4864/10000 [03:21<03:26, 24.82it/s, loss=4.42e-8, rmse_test=0.0144]
#
#
#
#
#
#
#
#  49%|████▊     | 4867/10000 [03:21<03:37, 23.59it/s, loss=4.42e-8, rmse_test=0.0144]
#
#
#
#
#
#
#
#  49%|████▊     | 4867/10000 [03:21<03:37, 23.59it/s, loss=4.55e-8, rmse_test=0.0244]
#
#
#
#
#
#
#
#  49%|████▊     | 4867/10000 [03:21<03:37, 23.59it/s, loss=4.53e-8, rmse_test=0.00872]
#
#
#
#
#
#
#
#  49%|████▊     | 4867/10000 [03:21<03:37, 23.59it/s, loss=4.38e-8, rmse_test=0.00919]
#
#
#
#
#
#
#
#  49%|████▊     | 4870/10000 [03:21<03:29, 24.47it/s, loss=4.38e-8, rmse_test=0.00919]
#
#
#
#
#
#
#
#  49%|████▊     | 4870/10000 [03:21<03:29, 24.47it/s, loss=4.41e-8, rmse_test=0.0166]
#
#
#
#
#
#
#
#  49%|████▊     | 4870/10000 [03:21<03:29, 24.47it/s, loss=4.33e-8, rmse_test=0.0129]
#
#
#
#
#
#
#
#  49%|████▊     | 4870/10000 [03:21<03:29, 24.47it/s, loss=4.24e-8, rmse_test=0.011]
#
#
#
#
#
#
#
#  49%|████▊     | 4873/10000 [03:21<03:31, 24.28it/s, loss=4.24e-8, rmse_test=0.011]
#
#
#
#
#
#
#
#  49%|████▊     | 4873/10000 [03:21<03:31, 24.28it/s, loss=4.22e-8, rmse_test=0.0127]
#
#
#
#
#
#
#
#  49%|████▊     | 4873/10000 [03:32<03:31, 24.28it/s, loss=4.22e-8, rmse_test=0.0127]

# %%
run train_xstnn.py --dataset heat --outputdir output_heat --manualSeed 9690 --xp stnn_d --mode discover --patience 1000 --l1_rel 3e-6
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#   0%|          | 0/10000 [00:00<?, ?it/s, loss=0.146, rmse_test=0.149]
#
#
#
#
#
#
#
#
#   0%|          | 0/10000 [00:00<?, ?it/s, loss=0.143, rmse_test=0.157]
#
#
#
#
#
#
#
#
#   0%|          | 0/10000 [00:00<?, ?it/s, loss=0.138, rmse_test=0.163]
#
#
#
#
#
#
#
#
#   0%|          | 3/10000 [00:00<07:33, 22.06it/s, loss=0.138, rmse_test=0.163]
#
#
#
#
#
#
#
#
#   0%|          | 3/10000 [00:00<07:33, 22.06it/s, loss=0.134, rmse_test=0.167]
#
#
#
#
#
#
#
#
#   0%|          | 3/10000 [00:00<07:33, 22.06it/s, loss=0.129, rmse_test=0.169]
#
#
#
#
#
#
#
#
#   0%|          | 3/10000 [00:00<07:33, 22.06it/s, loss=0.125, rmse_test=0.171]
#
#
#
#
#
#
#
#
#   0%|          | 6/10000 [00:00<07:39, 21.75it/s, loss=0.125, rmse_test=0.171]
#
#
#
#
#
#
#
#
#   0%|          | 6/10000 [00:00<07:39, 21.75it/s, loss=0.12, rmse_test=0.173]
#
#
#
#
#
#
#
#
#   0%|          | 6/10000 [00:00<07:39, 21.75it/s, loss=0.115, rmse_test=0.174]
#
#
#
#
#
#
#
#
#   0%|          | 6/10000 [00:00<07:39, 21.75it/s, loss=0.111, rmse_test=0.175]
#
#
#
#
#
#
#
#
#   0%|          | 6/10000 [00:00<07:39, 21.75it/s, loss=0.106, rmse_test=0.176]
#
#
#
#
#
#
#
#
#   0%|          | 10/10000 [00:00<06:53, 24.13it/s, loss=0.106, rmse_test=0.176]
#
#
#
#
#
#
#
#
#   0%|          | 10/10000 [00:00<06:53, 24.13it/s, loss=0.102, rmse_test=0.176]
#
#
#
#
#
#
#
#
#   0%|          | 10/10000 [00:00<06:53, 24.13it/s, loss=0.0971, rmse_test=0.175]
#
#
#
#
#
#
#
#
#   0%|          | 10/10000 [00:00<06:53, 24.13it/s, loss=0.0926, rmse_test=0.174]
#
#
#
#
#
#
#
#
#   0%|          | 13/10000 [00:00<06:38, 25.04it/s, loss=0.0926, rmse_test=0.174]
#
#
#
#
#
#
#
#
#   0%|          | 13/10000 [00:00<06:38, 25.04it/s, loss=0.088, rmse_test=0.173]
#
#
#
#
#
#
#
#
#   0%|          | 13/10000 [00:00<06:38, 25.04it/s, loss=0.0836, rmse_test=0.171]
#
#
#
#
#
#
#
#
#   0%|          | 13/10000 [00:00<06:38, 25.04it/s, loss=0.0792, rmse_test=0.169]
#
#
#
#
#
#
#
#
#   0%|          | 16/10000 [00:00<06:42, 24.77it/s, loss=0.0792, rmse_test=0.169]
#
#
#
#
#
#
#
#
#   0%|          | 16/10000 [00:00<06:42, 24.77it/s, loss=0.0749, rmse_test=0.168]
#
#
#
#
#
#
#
#
#   0%|          | 16/10000 [00:00<06:42, 24.77it/s, loss=0.0709, rmse_test=0.165]
#
#
#
#
#
#
#
#
#   0%|          | 16/10000 [00:00<06:42, 24.77it/s, loss=0.0667, rmse_test=0.163]
#
#
#
#
#
#
#
#
#   0%|          | 19/10000 [00:00<06:50, 24.32it/s, loss=0.0667, rmse_test=0.163]
#
#
#
#
#
#
#
#
#   0%|          | 19/10000 [00:00<06:50, 24.32it/s, loss=0.0629, rmse_test=0.161]
#
#
#
#
#
#
#
#
#   0%|          | 19/10000 [00:00<06:50, 24.32it/s, loss=0.0591, rmse_test=0.158]
#
#
#
#
#
#
#
#
#   0%|          | 19/10000 [00:00<06:50, 24.32it/s, loss=0.0554, rmse_test=0.156]
#
#
#
#
#
#
#
#
#   0%|          | 19/10000 [00:00<06:50, 24.32it/s, loss=0.0518, rmse_test=0.154]
#
#
#
#
#
#
#
#
#   0%|          | 23/10000 [00:00<06:27, 25.72it/s, loss=0.0518, rmse_test=0.154]
#
#
#
#
#
#
#
#
#   0%|          | 23/10000 [00:00<06:27, 25.72it/s, loss=0.0485, rmse_test=0.152]
#
#
#
#
#
#
#
#
#   0%|          | 23/10000 [00:00<06:27, 25.72it/s, loss=0.0453, rmse_test=0.149]
#
#
#
#
#
#
#
#
#   0%|          | 23/10000 [00:01<06:27, 25.72it/s, loss=0.0423, rmse_test=0.147]
#
#
#
#
#
#
#
#
#   0%|          | 26/10000 [00:01<06:40, 24.89it/s, loss=0.0423, rmse_test=0.147]
#
#
#
#
#
#
#
#
#   0%|          | 26/10000 [00:01<06:40, 24.89it/s, loss=0.0393, rmse_test=0.145]
#
#
#
#
#
#
#
#
#   0%|          | 26/10000 [00:01<06:40, 24.89it/s, loss=0.0365, rmse_test=0.143]
#
#
#
#
#
#
#
#
#   0%|          | 26/10000 [00:01<06:40, 24.89it/s, loss=0.034, rmse_test=0.142]
#
#
#
#
#
#
#
#
#   0%|          | 29/10000 [00:01<06:37, 25.08it/s, loss=0.034, rmse_test=0.142]
#
#
#
#
#
#
#
#
#   0%|          | 29/10000 [00:01<06:37, 25.08it/s, loss=0.0315, rmse_test=0.14]
#
#
#
#
#
#
#
#
#   0%|          | 29/10000 [00:01<06:37, 25.08it/s, loss=0.0291, rmse_test=0.137]
#
#
#
#
#
#
#
#
#   0%|          | 29/10000 [00:01<06:37, 25.08it/s, loss=0.0268, rmse_test=0.135]
#
#
#
#
#
#
#
#
#   0%|          | 32/10000 [00:01<06:37, 25.10it/s, loss=0.0268, rmse_test=0.135]
#
#
#
#
#
#
#
#
#   0%|          | 32/10000 [00:01<06:37, 25.10it/s, loss=0.0248, rmse_test=0.134]
#
#
#
#
#
#
#
#
#   0%|          | 32/10000 [00:01<06:37, 25.10it/s, loss=0.023, rmse_test=0.131]
#
#
#
#
#
#
#
#
#   0%|          | 32/10000 [00:01<06:37, 25.10it/s, loss=0.0213, rmse_test=0.13]
#
#
#
#
#
#
#
#
#   0%|          | 35/10000 [00:01<06:34, 25.27it/s, loss=0.0213, rmse_test=0.13]
#
#
#
#
#
#
#
#
#   0%|          | 35/10000 [00:01<06:34, 25.27it/s, loss=0.0196, rmse_test=0.127]
#
#
#
#
#
#
#
#
#   0%|          | 35/10000 [00:01<06:34, 25.27it/s, loss=0.0182, rmse_test=0.125]
#
#
#
#
#
#
#
#
#   0%|          | 35/10000 [00:01<06:34, 25.27it/s, loss=0.0168, rmse_test=0.124]
#
#
#
#
#
#
#
#
#   0%|          | 38/10000 [00:01<06:43, 24.71it/s, loss=0.0168, rmse_test=0.124]
#
#
#
#
#
#
#
#
#   0%|          | 38/10000 [00:01<06:43, 24.71it/s, loss=0.0155, rmse_test=0.121]
#
#
#
#
#
#
#
#
#   0%|          | 38/10000 [00:01<06:43, 24.71it/s, loss=0.0143, rmse_test=0.12]
#
#
#
#
#
#
#
#
#   0%|          | 38/10000 [00:01<06:43, 24.71it/s, loss=0.0131, rmse_test=0.118]
#
#
#
#
#
#
#
#
#   0%|          | 41/10000 [00:01<06:26, 25.79it/s, loss=0.0131, rmse_test=0.118]
#
#
#
#
#
#
#
#
#   0%|          | 41/10000 [00:01<06:26, 25.79it/s, loss=0.0121, rmse_test=0.116]
#
#
#
#
#
#
#
#
#   0%|          | 41/10000 [00:01<06:26, 25.79it/s, loss=0.0112, rmse_test=0.115]
#
#
#
#
#
#
#
#
#   0%|          | 41/10000 [00:01<06:26, 25.79it/s, loss=0.0103, rmse_test=0.113]
#
#
#
#
#
#
#
#
#   0%|          | 44/10000 [00:01<06:41, 24.80it/s, loss=0.0103, rmse_test=0.113]
#
#
#
#
#
#
#
#
#   0%|          | 44/10000 [00:01<06:41, 24.80it/s, loss=0.00952, rmse_test=0.112]
#
#
#
#
#
#
#
#
#   0%|          | 44/10000 [00:01<06:41, 24.80it/s, loss=0.00877, rmse_test=0.111]
#
#
#
#
#
#
#
#
#   0%|          | 44/10000 [00:01<06:41, 24.80it/s, loss=0.00798, rmse_test=0.111]
#
#
#
#
#
#
#
#
#   0%|          | 47/10000 [00:01<06:40, 24.85it/s, loss=0.00798, rmse_test=0.111]
#
#
#
#
#
#
#
#
#   0%|          | 47/10000 [00:01<06:40, 24.85it/s, loss=0.00736, rmse_test=0.113]
#
#
#
#
#
#
#
#
#   0%|          | 47/10000 [00:01<06:40, 24.85it/s, loss=0.00682, rmse_test=0.112]
#
#
#
#
#
#
#
#
#   0%|          | 47/10000 [00:01<06:40, 24.85it/s, loss=0.00628, rmse_test=0.115]
#
#
#
#
#
#
#
#
#   0%|          | 50/10000 [00:01<06:43, 24.67it/s, loss=0.00628, rmse_test=0.115]
#
#
#
#
#
#
#
#
#   0%|          | 50/10000 [00:02<06:43, 24.67it/s, loss=0.00582, rmse_test=0.116]
#
#
#
#
#
#
#
#
#   0%|          | 50/10000 [00:02<06:43, 24.67it/s, loss=0.00537, rmse_test=0.121]
#
#
#
#
#
#
#
#
#   0%|          | 50/10000 [00:02<06:43, 24.67it/s, loss=0.00495, rmse_test=0.121]
#
#
#
#
#
#
#
#
#   1%|          | 53/10000 [00:02<06:42, 24.70it/s, loss=0.00495, rmse_test=0.121]
#   1%|          | 53/10000 [00:02<06:42, 24.70it/s, loss=0.00457, rmse_test=0.123]
#
#
#
#
#
#
#
#
#   1%|          | 53/10000 [00:02<06:42, 24.70it/s, loss=0.00422, rmse_test=0.124]
#
#
#
#
#
#
#
#
#   1%|          | 53/10000 [00:02<06:42, 24.70it/s, loss=0.00387, rmse_test=0.124]
#
#
#
#
#
#
#
#
#   1%|          | 56/10000 [00:02<06:35, 25.16it/s, loss=0.00387, rmse_test=0.124]
#
#
#
#
#
#
#
#
#   1%|          | 56/10000 [00:02<06:35, 25.16it/s, loss=0.00357, rmse_test=0.131]
#
#
#
#
#
#
#
#
#   1%|          | 56/10000 [00:02<06:35, 25.16it/s, loss=0.0033, rmse_test=0.131]
#
#
#
#
#
#
#
#
#   1%|          | 56/10000 [00:02<06:35, 25.16it/s, loss=0.00304, rmse_test=0.132]
#
#
#
#
#
#
#
#
#   1%|          | 59/10000 [00:02<06:18, 26.29it/s, loss=0.00304, rmse_test=0.132]
#
#
#
#
#
#
#
#
#   1%|          | 59/10000 [00:02<06:18, 26.29it/s, loss=0.00279, rmse_test=0.135]
#
#
#
#
#
#
#
#
#   1%|          | 59/10000 [00:02<06:18, 26.29it/s, loss=0.00257, rmse_test=0.141]
#
#
#
#
#
#
#
#
#   1%|          | 59/10000 [00:02<06:18, 26.29it/s, loss=0.00237, rmse_test=0.144]
#
#
#
#
#
#
#
#
#   1%|          | 62/10000 [00:02<06:12, 26.66it/s, loss=0.00237, rmse_test=0.144]
#
#
#
#
#
#
#
#
#   1%|          | 62/10000 [00:02<06:12, 26.66it/s, loss=0.00221, rmse_test=0.145]
#
#
#
#
#
#
#
#
#   1%|          | 62/10000 [00:02<06:12, 26.66it/s, loss=0.00204, rmse_test=0.16]
#
#
#
#
#
#
#
#
#   1%|          | 62/10000 [00:02<06:12, 26.66it/s, loss=0.00188, rmse_test=0.164]
#
#
#
#
#
#
#
#
#   1%|          | 65/10000 [00:02<06:02, 27.39it/s, loss=0.00188, rmse_test=0.164]
#
#
#
#
#
#
#
#
#   1%|          | 65/10000 [00:02<06:02, 27.39it/s, loss=0.00175, rmse_test=0.171]
#
#
#
#
#
#
#
#
#   1%|          | 65/10000 [00:02<06:02, 27.39it/s, loss=0.0016, rmse_test=0.186]
#
#
#
#
#
#
#
#
#   1%|          | 65/10000 [00:02<06:02, 27.39it/s, loss=0.00148, rmse_test=0.195]
#
#
#
#
#
#
#
#
#   1%|          | 68/10000 [00:02<06:01, 27.48it/s, loss=0.00148, rmse_test=0.195]
#
#
#
#
#
#
#
#
#   1%|          | 68/10000 [00:02<06:01, 27.48it/s, loss=0.00136, rmse_test=0.201]
#
#
#
#
#
#
#
#
#   1%|          | 68/10000 [00:02<06:01, 27.48it/s, loss=0.00125, rmse_test=0.22]
#
#
#
#
#
#
#
#
#   1%|          | 68/10000 [00:02<06:01, 27.48it/s, loss=0.00116, rmse_test=0.21]
#
#
#
#
#
#
#
#
#   1%|          | 71/10000 [00:02<05:53, 28.10it/s, loss=0.00116, rmse_test=0.21]
#
#
#
#
#
#
#
#
#   1%|          | 71/10000 [00:02<05:53, 28.10it/s, loss=0.00107, rmse_test=0.219]
#
#
#
#
#
#
#
#
#   1%|          | 71/10000 [00:02<05:53, 28.10it/s, loss=0.000984, rmse_test=0.227]
#
#
#
#
#
#
#
#
#   1%|          | 71/10000 [00:02<05:53, 28.10it/s, loss=0.000903, rmse_test=0.236]
#
#
#
#
#
#
#
#
#   1%|          | 74/10000 [00:02<05:49, 28.42it/s, loss=0.000903, rmse_test=0.236]
#
#
#
#
#
#
#
#
#   1%|          | 74/10000 [00:02<05:49, 28.42it/s, loss=0.000845, rmse_test=0.252]
#
#
#
#
#
#
#
#
#   1%|          | 74/10000 [00:02<05:49, 28.42it/s, loss=0.000801, rmse_test=0.268]
#
#
#
#
#
#
#
#
#   1%|          | 74/10000 [00:02<05:49, 28.42it/s, loss=0.000731, rmse_test=0.27]
#
#
#
#
#
#
#
#
#   1%|          | 74/10000 [00:02<05:49, 28.42it/s, loss=0.000665, rmse_test=0.273]
#
#
#
#
#
#
#
#
#   1%|          | 78/10000 [00:02<05:41, 29.02it/s, loss=0.000665, rmse_test=0.273]
#
#
#
#
#
#
#
#
#   1%|          | 78/10000 [00:03<05:41, 29.02it/s, loss=0.000608, rmse_test=0.29]
#
#
#
#
#
#
#
#
#   1%|          | 78/10000 [00:03<05:41, 29.02it/s, loss=0.000573, rmse_test=0.3]
#
#
#
#
#
#
#
#
#   1%|          | 78/10000 [00:03<05:41, 29.02it/s, loss=0.000523, rmse_test=0.318]
#
#
#
#
#
#
#
#
#   1%|          | 81/10000 [00:03<05:40, 29.10it/s, loss=0.000523, rmse_test=0.318]
#
#
#
#
#
#
#
#
#   1%|          | 81/10000 [00:03<05:40, 29.10it/s, loss=0.000484, rmse_test=0.326]
#
#
#
#
#
#
#
#
#   1%|          | 81/10000 [00:03<05:40, 29.10it/s, loss=0.000449, rmse_test=0.338]
#
#
#
#
#
#
#
#
#   1%|          | 81/10000 [00:03<05:40, 29.10it/s, loss=0.000415, rmse_test=0.354]
#
#
#
#
#
#
#
#
#   1%|          | 84/10000 [00:03<05:45, 28.69it/s, loss=0.000415, rmse_test=0.354]
#
#
#
#
#
#
#
#
#   1%|          | 84/10000 [00:03<05:45, 28.69it/s, loss=0.000376, rmse_test=0.355]
#
#
#
#
#
#
#
#
#   1%|          | 84/10000 [00:03<05:45, 28.69it/s, loss=0.000341, rmse_test=0.357]
#
#
#
#
#
#
#
#
#   1%|          | 84/10000 [00:03<05:45, 28.69it/s, loss=0.000328, rmse_test=0.371]
#
#
#
#
#
#
#
#
#   1%|          | 87/10000 [00:03<05:42, 28.97it/s, loss=0.000328, rmse_test=0.371]
#
#
#
#
#
#
#
#
#   1%|          | 87/10000 [00:03<05:42, 28.97it/s, loss=0.000304, rmse_test=0.379]
#
#
#
#
#
#
#
#
#   1%|          | 87/10000 [00:03<05:42, 28.97it/s, loss=0.000282, rmse_test=0.393]
#
#
#
#
#
#
#
#
#   1%|          | 87/10000 [00:03<05:42, 28.97it/s, loss=0.000265, rmse_test=0.406]
#
#
#
#
#
#
#
#
#   1%|          | 90/10000 [00:03<05:49, 28.33it/s, loss=0.000265, rmse_test=0.406]
#
#
#
#
#
#
#
#
#   1%|          | 90/10000 [00:03<05:49, 28.33it/s, loss=0.000241, rmse_test=0.424]
#
#
#
#
#
#
#
#
#   1%|          | 90/10000 [00:03<05:49, 28.33it/s, loss=0.000213, rmse_test=0.435]
#
#
#
#
#
#
#
#
#   1%|          | 90/10000 [00:03<05:49, 28.33it/s, loss=0.000199, rmse_test=0.479]
#
#
#
#
#
#
#
#
#   1%|          | 93/10000 [00:03<05:47, 28.49it/s, loss=0.000199, rmse_test=0.479]
#
#
#
#
#
#
#
#
#   1%|          | 93/10000 [00:03<05:47, 28.49it/s, loss=0.000181, rmse_test=0.478]
#
#
#
#
#
#
#
#
#   1%|          | 93/10000 [00:03<05:47, 28.49it/s, loss=0.000167, rmse_test=0.495]
#
#
#
#
#
#
#
#
#   1%|          | 93/10000 [00:03<05:47, 28.49it/s, loss=0.000168, rmse_test=0.506]
#
#
#
#
#
#
#
#
#   1%|          | 96/10000 [00:03<06:00, 27.46it/s, loss=0.000168, rmse_test=0.506]
#
#
#
#
#
#
#
#
#   1%|          | 96/10000 [00:03<06:00, 27.46it/s, loss=0.000146, rmse_test=0.49]
#
#
#
#
#
#
#
#
#   1%|          | 96/10000 [00:03<06:00, 27.46it/s, loss=0.000143, rmse_test=0.494]
#
#
#
#
#
#
#
#
#   1%|          | 96/10000 [00:03<06:00, 27.46it/s, loss=0.00013, rmse_test=0.505]
#
#
#
#
#
#
#
#
#   1%|          | 99/10000 [00:03<06:08, 26.90it/s, loss=0.00013, rmse_test=0.505]
#
#
#
#
#
#
#
#
#   1%|          | 99/10000 [00:03<06:08, 26.90it/s, loss=0.000124, rmse_test=0.495]
#
#
#
#
#
#
#
#
#   1%|          | 99/10000 [00:03<06:08, 26.90it/s, loss=0.000112, rmse_test=0.485]
#
#
#
#
#
#
#
#
#   1%|          | 99/10000 [00:03<06:08, 26.90it/s, loss=0.000102, rmse_test=0.481]
#
#
#
#
#
#
#
#
#   1%|          | 102/10000 [00:03<06:14, 26.40it/s, loss=0.000102, rmse_test=0.481]
#
#
#
#
#
#
#
#
#   1%|          | 102/10000 [00:03<06:14, 26.40it/s, loss=0.000103, rmse_test=0.489]
#
#
#
#
#
#
#
#
#   1%|          | 102/10000 [00:03<06:14, 26.40it/s, loss=0.000105, rmse_test=0.518]
#
#
#
#
#
#
#
#
#   1%|          | 102/10000 [00:03<06:14, 26.40it/s, loss=8.62e-5, rmse_test=0.543]
#
#
#
#
#
#
#
#
#   1%|          | 105/10000 [00:03<06:13, 26.50it/s, loss=8.62e-5, rmse_test=0.543]
#   1%|          | 105/10000 [00:04<06:13, 26.50it/s, loss=8.8e-5, rmse_test=0.6]
#
#
#
#
#
#
#
#
#   1%|          | 105/10000 [00:04<06:13, 26.50it/s, loss=8.46e-5, rmse_test=0.541]
#
#
#
#
#
#
#
#
#   1%|          | 105/10000 [00:04<06:13, 26.50it/s, loss=7.24e-5, rmse_test=0.499]
#
#
#
#
#
#
#
#
#   1%|          | 108/10000 [00:04<06:16, 26.28it/s, loss=7.24e-5, rmse_test=0.499]
#
#
#
#
#
#
#
#
#   1%|          | 108/10000 [00:04<06:16, 26.28it/s, loss=7.69e-5, rmse_test=0.53]
#
#
#
#
#
#
#
#
#   1%|          | 108/10000 [00:04<06:16, 26.28it/s, loss=8.03e-5, rmse_test=0.523]
#
#
#
#
#
#
#
#
#   1%|          | 108/10000 [00:04<06:16, 26.28it/s, loss=6.5e-5, rmse_test=0.518]
#
#
#
#
#
#
#
#
#   1%|          | 111/10000 [00:04<06:08, 26.80it/s, loss=6.5e-5, rmse_test=0.518]
#
#
#
#
#
#
#
#
#   1%|          | 111/10000 [00:04<06:08, 26.80it/s, loss=6.19e-5, rmse_test=0.511]
#
#
#
#
#
#
#
#
#   1%|          | 111/10000 [00:04<06:08, 26.80it/s, loss=6.47e-5, rmse_test=0.511]
#
#
#
#
#
#
#
#
#   1%|          | 111/10000 [00:04<06:08, 26.80it/s, loss=6.79e-5, rmse_test=0.523]
#
#
#
#
#
#
#
#
#   1%|          | 114/10000 [00:04<05:58, 27.60it/s, loss=6.79e-5, rmse_test=0.523]
#
#
#
#
#
#
#
#
#   1%|          | 114/10000 [00:04<05:58, 27.60it/s, loss=6.3e-5, rmse_test=0.54]
#
#
#
#
#
#
#
#
#   1%|          | 114/10000 [00:04<05:58, 27.60it/s, loss=6.99e-5, rmse_test=0.541]
#
#
#
#
#
#
#
#
#   1%|          | 114/10000 [00:04<05:58, 27.60it/s, loss=6.85e-5, rmse_test=0.522]
#
#
#
#
#
#
#
#
#   1%|          | 117/10000 [00:04<06:14, 26.40it/s, loss=6.85e-5, rmse_test=0.522]
#
#
#
#
#
#
#
#
#   1%|          | 117/10000 [00:04<06:14, 26.40it/s, loss=5.88e-5, rmse_test=0.509]
#
#
#
#
#
#
#
#
#   1%|          | 117/10000 [00:04<06:14, 26.40it/s, loss=6.24e-5, rmse_test=0.539]
#
#
#
#
#
#
#
#
#   1%|          | 117/10000 [00:04<06:14, 26.40it/s, loss=6.06e-5, rmse_test=0.474]
#
#
#
#
#
#
#
#
#   1%|          | 120/10000 [00:04<06:12, 26.52it/s, loss=6.06e-5, rmse_test=0.474]
#
#
#
#
#
#
#
#
#   1%|          | 120/10000 [00:04<06:12, 26.52it/s, loss=4.83e-5, rmse_test=0.459]
#
#
#
#
#
#
#
#
#   1%|          | 120/10000 [00:04<06:12, 26.52it/s, loss=6.19e-5, rmse_test=0.447]
#
#
#
#
#
#
#
#
#   1%|          | 120/10000 [00:04<06:12, 26.52it/s, loss=6.74e-5, rmse_test=0.427]
#
#
#
#
#
#
#
#
#   1%|          | 123/10000 [00:04<06:03, 27.18it/s, loss=6.74e-5, rmse_test=0.427]
#
#
#
#
#
#
#
#
#   1%|          | 123/10000 [00:04<06:03, 27.18it/s, loss=5.2e-5, rmse_test=0.417]
#
#
#
#
#
#
#
#
#   1%|          | 123/10000 [00:04<06:03, 27.18it/s, loss=4.55e-5, rmse_test=0.399]
#
#
#
#
#
#
#
#
#   1%|          | 123/10000 [00:04<06:03, 27.18it/s, loss=5.49e-5, rmse_test=0.438]
#
#
#
#
#
#
#
#
#   1%|▏         | 126/10000 [00:04<05:58, 27.54it/s, loss=5.49e-5, rmse_test=0.438]
#
#
#
#
#
#
#
#
#   1%|▏         | 126/10000 [00:04<05:58, 27.54it/s, loss=5.03e-5, rmse_test=0.407]
#
#
#
#
#
#
#
#
#   1%|▏         | 126/10000 [00:04<05:58, 27.54it/s, loss=5.84e-5, rmse_test=0.42]
#
#
#
#
#
#
#
#
#   1%|▏         | 126/10000 [00:04<05:58, 27.54it/s, loss=3.38e-5, rmse_test=0.384]
#
#
#
#
#
#
#
#
#   1%|▏         | 129/10000 [00:04<06:01, 27.30it/s, loss=3.38e-5, rmse_test=0.384]
#
#
#
#
#
#
#
#
#   1%|▏         | 129/10000 [00:04<06:01, 27.30it/s, loss=5.92e-5, rmse_test=0.378]
#
#
#
#
#
#
#
#
#   1%|▏         | 129/10000 [00:04<06:01, 27.30it/s, loss=5.74e-5, rmse_test=0.335]
#
#
#
#
#
#
#
#
#   1%|▏         | 129/10000 [00:04<06:01, 27.30it/s, loss=5.17e-5, rmse_test=0.401]
#
#
#
#
#
#
#
#
#   1%|▏         | 132/10000 [00:04<05:56, 27.65it/s, loss=5.17e-5, rmse_test=0.401]
#
#
#
#
#
#
#
#
#   1%|▏         | 132/10000 [00:05<05:56, 27.65it/s, loss=4.98e-5, rmse_test=0.374]
#
#
#
#
#
#
#
#
#   1%|▏         | 132/10000 [00:05<05:56, 27.65it/s, loss=5.54e-5, rmse_test=0.333]
#
#
#
#
#
#
#
#
#   1%|▏         | 132/10000 [00:05<05:56, 27.65it/s, loss=7.37e-5, rmse_test=0.35]
#
#
#
#
#
#
#
#
#   1%|▏         | 135/10000 [00:05<06:00, 27.36it/s, loss=7.37e-5, rmse_test=0.35]
#
#
#
#
#
#
#
#
#   1%|▏         | 135/10000 [00:05<06:00, 27.36it/s, loss=4.84e-5, rmse_test=0.428]
#
#
#
#
#
#
#
#
#   1%|▏         | 135/10000 [00:05<06:00, 27.36it/s, loss=6.69e-5, rmse_test=0.42]
#
#
#
#
#
#
#
#
#   1%|▏         | 135/10000 [00:05<06:00, 27.36it/s, loss=5.56e-5, rmse_test=0.404]
#
#
#
#
#
#
#
#
#   1%|▏         | 138/10000 [00:05<05:58, 27.54it/s, loss=5.56e-5, rmse_test=0.404]
#
#
#
#
#
#
#
#
#   1%|▏         | 138/10000 [00:05<05:58, 27.54it/s, loss=4.94e-5, rmse_test=0.399]
#
#
#
#
#
#
#
#
#   1%|▏         | 138/10000 [00:05<05:58, 27.54it/s, loss=7.3e-5, rmse_test=0.361]
#
#
#
#
#
#
#
#
#   1%|▏         | 138/10000 [00:05<05:58, 27.54it/s, loss=5.13e-5, rmse_test=0.39]
#
#
#
#
#
#
#
#
#   1%|▏         | 141/10000 [00:05<05:58, 27.51it/s, loss=5.13e-5, rmse_test=0.39]
#
#
#
#
#
#
#
#
#   1%|▏         | 141/10000 [00:05<05:58, 27.51it/s, loss=6.99e-5, rmse_test=0.402]
#
#
#
#
#
#
#
#
#   1%|▏         | 141/10000 [00:05<05:58, 27.51it/s, loss=5.29e-5, rmse_test=0.385]
#
#
#
#
#
#
#
#
#   1%|▏         | 141/10000 [00:05<05:58, 27.51it/s, loss=7.62e-5, rmse_test=0.372]
#
#
#
#
#
#
#
#
#   1%|▏         | 144/10000 [00:05<05:58, 27.50it/s, loss=7.62e-5, rmse_test=0.372]
#
#
#
#
#
#
#
#
#   1%|▏         | 144/10000 [00:05<05:58, 27.50it/s, loss=5.86e-5, rmse_test=0.396]
#
#
#
#
#
#
#
#
#   1%|▏         | 144/10000 [00:05<05:58, 27.50it/s, loss=6.27e-5, rmse_test=0.312]
#
#
#
#
#
#
#
#
#   1%|▏         | 144/10000 [00:05<05:58, 27.50it/s, loss=6.63e-5, rmse_test=0.411]
#
#
#
#
#
#
#
#
#   1%|▏         | 147/10000 [00:05<06:08, 26.76it/s, loss=6.63e-5, rmse_test=0.411]
#
#
#
#
#
#
#
#
#   1%|▏         | 147/10000 [00:05<06:08, 26.76it/s, loss=7.23e-5, rmse_test=0.373]
#
#
#
#
#
#
#
#
#   1%|▏         | 147/10000 [00:05<06:08, 26.76it/s, loss=6.51e-5, rmse_test=0.371]
#
#
#
#
#
#
#
#
#   1%|▏         | 147/10000 [00:05<06:08, 26.76it/s, loss=7.87e-5, rmse_test=0.328]
#
#
#
#
#
#
#
#
#   2%|▏         | 150/10000 [00:05<06:07, 26.78it/s, loss=7.87e-5, rmse_test=0.328]
#
#
#
#
#
#
#
#
#   2%|▏         | 150/10000 [00:05<06:07, 26.78it/s, loss=8.25e-5, rmse_test=0.368]
#
#
#
#
#
#
#
#
#   2%|▏         | 150/10000 [00:05<06:07, 26.78it/s, loss=6.9e-5, rmse_test=0.32]
#
#
#
#
#
#
#
#
#   2%|▏         | 150/10000 [00:05<06:07, 26.78it/s, loss=6.21e-5, rmse_test=0.385]
#
#
#
#
#
#
#
#
#   2%|▏         | 153/10000 [00:05<06:11, 26.52it/s, loss=6.21e-5, rmse_test=0.385]
#
#
#
#
#
#
#
#
#   2%|▏         | 153/10000 [00:05<06:11, 26.52it/s, loss=6.42e-5, rmse_test=0.342]
#
#
#
#
#
#
#
#
#   2%|▏         | 153/10000 [00:05<06:11, 26.52it/s, loss=5.46e-5, rmse_test=0.358]
#
#
#
#
#
#
#
#
#   2%|▏         | 153/10000 [00:05<06:11, 26.52it/s, loss=6.22e-5, rmse_test=0.395]
#
#
#
#
#
#
#
#
#   2%|▏         | 156/10000 [00:05<06:09, 26.66it/s, loss=6.22e-5, rmse_test=0.395]
#
#
#
#
#
#
#
#
#   2%|▏         | 156/10000 [00:05<06:09, 26.66it/s, loss=5.74e-5, rmse_test=0.399]
#   2%|▏         | 156/10000 [00:05<06:09, 26.66it/s, loss=6.98e-5, rmse_test=0.366]
#
#
#
#
#
#
#
#
#   2%|▏         | 156/10000 [00:05<06:09, 26.66it/s, loss=6.34e-5, rmse_test=0.355]
#
#
#
#
#
#
#
#
#   2%|▏         | 159/10000 [00:05<06:10, 26.57it/s, loss=6.34e-5, rmse_test=0.355]
#
#
#
#
#
#
#
#
#   2%|▏         | 159/10000 [00:06<06:10, 26.57it/s, loss=6.39e-5, rmse_test=0.406]
#
#
#
#
#
#
#
#
#   2%|▏         | 159/10000 [00:06<06:10, 26.57it/s, loss=7.67e-5, rmse_test=0.408]
#
#
#
#
#
#
#
#
#   2%|▏         | 159/10000 [00:06<06:10, 26.57it/s, loss=7.35e-5, rmse_test=0.393]
#
#
#
#
#
#
#
#
#   2%|▏         | 162/10000 [00:06<06:04, 27.01it/s, loss=7.35e-5, rmse_test=0.393]
#
#
#
#
#
#
#
#
#   2%|▏         | 162/10000 [00:06<06:04, 27.01it/s, loss=5.48e-5, rmse_test=0.413]
#
#
#
#
#
#
#
#
#   2%|▏         | 162/10000 [00:06<06:04, 27.01it/s, loss=6.58e-5, rmse_test=0.401]
#
#
#
#
#
#
#
#
#   2%|▏         | 162/10000 [00:06<06:04, 27.01it/s, loss=6.53e-5, rmse_test=0.344]
#
#
#
#
#
#
#
#
#   2%|▏         | 165/10000 [00:06<06:19, 25.93it/s, loss=6.53e-5, rmse_test=0.344]
#
#
#
#
#
#
#
#
#   2%|▏         | 165/10000 [00:06<06:19, 25.93it/s, loss=6.82e-5, rmse_test=0.368]
#
#
#
#
#
#
#
#
#   2%|▏         | 165/10000 [00:06<06:19, 25.93it/s, loss=6.56e-5, rmse_test=0.343]
#
#
#
#
#
#
#
#
#   2%|▏         | 165/10000 [00:06<06:19, 25.93it/s, loss=6.77e-5, rmse_test=0.368]
#
#
#
#
#
#
#
#
#   2%|▏         | 168/10000 [00:06<06:31, 25.11it/s, loss=6.77e-5, rmse_test=0.368]
#
#
#
#
#
#
#
#
#   2%|▏         | 168/10000 [00:06<06:31, 25.11it/s, loss=5.96e-5, rmse_test=0.345]
#
#
#
#
#
#
#
#
#   2%|▏         | 168/10000 [00:06<06:31, 25.11it/s, loss=8.69e-5, rmse_test=0.324]
#
#
#
#
#
#
#
#
#   2%|▏         | 168/10000 [00:06<06:31, 25.11it/s, loss=6.42e-5, rmse_test=0.298]
#
#
#
#
#
#
#
#
#   2%|▏         | 171/10000 [00:06<06:34, 24.94it/s, loss=6.42e-5, rmse_test=0.298]
#
#
#
#
#
#
#
#
#   2%|▏         | 171/10000 [00:06<06:34, 24.94it/s, loss=5.36e-5, rmse_test=0.245]
#
#
#
#
#
#
#
#
#   2%|▏         | 171/10000 [00:06<06:34, 24.94it/s, loss=7.55e-5, rmse_test=0.271]
#
#
#
#
#
#
#
#
#   2%|▏         | 171/10000 [00:06<06:34, 24.94it/s, loss=7.72e-5, rmse_test=0.256]
#
#
#
#
#
#
#
#
#   2%|▏         | 174/10000 [00:06<06:24, 25.55it/s, loss=7.72e-5, rmse_test=0.256]
#
#
#
#
#
#
#
#
#   2%|▏         | 174/10000 [00:06<06:24, 25.55it/s, loss=7.56e-5, rmse_test=0.305]
#
#
#
#
#
#
#
#
#   2%|▏         | 174/10000 [00:06<06:24, 25.55it/s, loss=6.15e-5, rmse_test=0.259]
#
#
#
#
#
#
#
#
#   2%|▏         | 174/10000 [00:06<06:24, 25.55it/s, loss=7.12e-5, rmse_test=0.292]
#
#
#
#
#
#
#
#
#   2%|▏         | 177/10000 [00:06<06:39, 24.59it/s, loss=7.12e-5, rmse_test=0.292]
#
#
#
#
#
#
#
#
#   2%|▏         | 177/10000 [00:06<06:39, 24.59it/s, loss=7.68e-5, rmse_test=0.317]
#
#
#
#
#
#
#
#
#   2%|▏         | 177/10000 [00:06<06:39, 24.59it/s, loss=7.02e-5, rmse_test=0.299]
#
#
#
#
#
#
#
#
#   2%|▏         | 177/10000 [00:06<06:39, 24.59it/s, loss=6.13e-5, rmse_test=0.257]
#
#
#
#
#
#
#
#
#   2%|▏         | 180/10000 [00:06<06:33, 24.93it/s, loss=6.13e-5, rmse_test=0.257]
#
#
#
#
#
#
#
#
#   2%|▏         | 180/10000 [00:06<06:33, 24.93it/s, loss=6.15e-5, rmse_test=0.278]
#
#
#
#
#
#
#
#
#   2%|▏         | 180/10000 [00:06<06:33, 24.93it/s, loss=7.25e-5, rmse_test=0.252]
#
#
#
#
#
#
#
#
#   2%|▏         | 180/10000 [00:06<06:33, 24.93it/s, loss=6.87e-5, rmse_test=0.305]
#
#
#
#
#
#
#
#
#   2%|▏         | 183/10000 [00:06<06:36, 24.75it/s, loss=6.87e-5, rmse_test=0.305]
#
#
#
#
#
#
#
#
#   2%|▏         | 183/10000 [00:06<06:36, 24.75it/s, loss=4.97e-5, rmse_test=0.249]
#
#
#
#
#
#
#
#
#   2%|▏         | 183/10000 [00:07<06:36, 24.75it/s, loss=5.54e-5, rmse_test=0.297]
#
#
#
#
#
#
#
#
#   2%|▏         | 183/10000 [00:07<06:36, 24.75it/s, loss=8.69e-5, rmse_test=0.269]
#
#
#
#
#
#
#
#
#   2%|▏         | 186/10000 [00:07<06:44, 24.26it/s, loss=8.69e-5, rmse_test=0.269]
#
#
#
#
#
#
#
#
#   2%|▏         | 186/10000 [00:07<06:44, 24.26it/s, loss=8.8e-5, rmse_test=0.311]
#
#
#
#
#
#
#
#
#   2%|▏         | 186/10000 [00:07<06:44, 24.26it/s, loss=6.83e-5, rmse_test=0.3]
#
#
#
#
#
#
#
#
#   2%|▏         | 186/10000 [00:07<06:44, 24.26it/s, loss=4.76e-5, rmse_test=0.313]
#
#
#
#
#
#
#
#
#   2%|▏         | 189/10000 [00:07<06:32, 24.98it/s, loss=4.76e-5, rmse_test=0.313]
#
#
#
#
#
#
#
#
#   2%|▏         | 189/10000 [00:07<06:32, 24.98it/s, loss=5.31e-5, rmse_test=0.276]
#
#
#
#
#
#
#
#
#   2%|▏         | 189/10000 [00:07<06:32, 24.98it/s, loss=6.87e-5, rmse_test=0.386]
#
#
#
#
#
#
#
#
#   2%|▏         | 189/10000 [00:07<06:32, 24.98it/s, loss=6.48e-5, rmse_test=0.338]
#
#
#
#
#
#
#
#
#   2%|▏         | 192/10000 [00:07<06:22, 25.64it/s, loss=6.48e-5, rmse_test=0.338]
#
#
#
#
#
#
#
#
#   2%|▏         | 192/10000 [00:07<06:22, 25.64it/s, loss=6.59e-5, rmse_test=0.339]
#
#
#
#
#
#
#
#
#   2%|▏         | 192/10000 [00:07<06:22, 25.64it/s, loss=6.6e-5, rmse_test=0.253]
#
#
#
#
#
#
#
#
#   2%|▏         | 192/10000 [00:07<06:22, 25.64it/s, loss=6.49e-5, rmse_test=0.304]
#
#
#
#
#
#
#
#
#   2%|▏         | 195/10000 [00:07<06:10, 26.45it/s, loss=6.49e-5, rmse_test=0.304]
#
#
#
#
#
#
#
#
#   2%|▏         | 195/10000 [00:07<06:10, 26.45it/s, loss=5.48e-5, rmse_test=0.215]
#
#
#
#
#
#
#
#
#   2%|▏         | 195/10000 [00:07<06:10, 26.45it/s, loss=6.29e-5, rmse_test=0.275]
#
#
#
#
#
#
#
#
#   2%|▏         | 195/10000 [00:07<06:10, 26.45it/s, loss=5.46e-5, rmse_test=0.302]
#
#
#
#
#
#
#
#
#   2%|▏         | 198/10000 [00:07<06:45, 24.19it/s, loss=5.46e-5, rmse_test=0.302]
#
#
#
#
#
#
#
#
#   2%|▏         | 198/10000 [00:07<06:45, 24.19it/s, loss=7.96e-5, rmse_test=0.563]
#
#
#
#
#
#
#
#
#   2%|▏         | 198/10000 [00:07<06:45, 24.19it/s, loss=7.8e-5, rmse_test=0.353]
#
#
#
#
#
#
#
#
#   2%|▏         | 198/10000 [00:07<06:45, 24.19it/s, loss=6.42e-5, rmse_test=0.271]
#
#
#
#
#
#
#
#
#   2%|▏         | 201/10000 [00:07<07:41, 21.23it/s, loss=6.42e-5, rmse_test=0.271]
#
#
#
#
#
#
#
#
#   2%|▏         | 201/10000 [00:07<07:41, 21.23it/s, loss=6.03e-5, rmse_test=0.153]
#
#
#
#
#
#
#
#
#   2%|▏         | 201/10000 [00:07<07:41, 21.23it/s, loss=7.54e-5, rmse_test=0.261]
#
#
#
#
#
#
#
#
#   2%|▏         | 201/10000 [00:07<07:41, 21.23it/s, loss=6.07e-5, rmse_test=0.31]
#
#
#
#
#
#
#
#
#   2%|▏         | 204/10000 [00:07<07:06, 22.98it/s, loss=6.07e-5, rmse_test=0.31]
#
#
#
#
#
#
#
#
#   2%|▏         | 204/10000 [00:07<07:06, 22.98it/s, loss=8.12e-5, rmse_test=0.306]
#
#
#
#
#
#
#
#
#   2%|▏         | 204/10000 [00:07<07:06, 22.98it/s, loss=5.8e-5, rmse_test=0.273]
#
#
#
#
#
#
#
#
#   2%|▏         | 204/10000 [00:07<07:06, 22.98it/s, loss=6.08e-5, rmse_test=0.219]
#
#
#
#
#
#
#
#
#   2%|▏         | 207/10000 [00:07<06:43, 24.26it/s, loss=6.08e-5, rmse_test=0.219]
#
#
#
#
#
#
#
#
#   2%|▏         | 207/10000 [00:07<06:43, 24.26it/s, loss=5.14e-5, rmse_test=0.225]
#
#
#
#
#
#
#
#
#   2%|▏         | 207/10000 [00:08<06:43, 24.26it/s, loss=6.12e-5, rmse_test=0.317]
#   2%|▏         | 207/10000 [00:08<06:43, 24.26it/s, loss=6.41e-5, rmse_test=0.296]
#
#
#
#
#
#
#
#
#   2%|▏         | 210/10000 [00:08<06:58, 23.38it/s, loss=6.41e-5, rmse_test=0.296]
#
#
#
#
#
#
#
#
#   2%|▏         | 210/10000 [00:08<06:58, 23.38it/s, loss=7.16e-5, rmse_test=0.295]
#
#
#
#
#
#
#
#
#   2%|▏         | 210/10000 [00:08<06:58, 23.38it/s, loss=6.1e-5, rmse_test=0.256]
#
#
#
#
#
#
#
#
#   2%|▏         | 210/10000 [00:08<06:58, 23.38it/s, loss=7e-5, rmse_test=0.167]
#
#
#
#
#
#
#
#
#   2%|▏         | 213/10000 [00:08<06:53, 23.67it/s, loss=7e-5, rmse_test=0.167]
#
#
#
#
#
#
#
#
#   2%|▏         | 213/10000 [00:08<06:53, 23.67it/s, loss=8.7e-5, rmse_test=0.278]
#
#
#
#
#
#
#
#
#   2%|▏         | 213/10000 [00:08<06:53, 23.67it/s, loss=8.64e-5, rmse_test=0.313]
#
#
#
#
#
#
#
#
#   2%|▏         | 213/10000 [00:08<06:53, 23.67it/s, loss=6.76e-5, rmse_test=0.295]
#
#
#
#
#
#
#
#
#   2%|▏         | 216/10000 [00:08<07:05, 22.99it/s, loss=6.76e-5, rmse_test=0.295]
#
#
#
#
#
#
#
#
#   2%|▏         | 216/10000 [00:08<07:05, 22.99it/s, loss=6.32e-5, rmse_test=0.272]
#
#
#
#
#
#
#
#
#   2%|▏         | 216/10000 [00:08<07:05, 22.99it/s, loss=7.2e-5, rmse_test=0.274]
#
#
#
#
#
#
#
#
#   2%|▏         | 216/10000 [00:08<07:05, 22.99it/s, loss=7.3e-5, rmse_test=0.251]
#
#
#
#
#
#
#
#
#   2%|▏         | 219/10000 [00:08<06:53, 23.66it/s, loss=7.3e-5, rmse_test=0.251]
#
#
#
#
#
#
#
#
#   2%|▏         | 219/10000 [00:08<06:53, 23.66it/s, loss=7.61e-5, rmse_test=0.27]
#
#
#
#
#
#
#
#
#   2%|▏         | 219/10000 [00:08<06:53, 23.66it/s, loss=7.9e-5, rmse_test=0.213]
#
#
#
#
#
#
#
#
#   2%|▏         | 219/10000 [00:08<06:53, 23.66it/s, loss=8.99e-5, rmse_test=0.275]
#
#
#
#
#
#
#
#
#   2%|▏         | 222/10000 [00:08<06:45, 24.13it/s, loss=8.99e-5, rmse_test=0.275]
#
#
#
#
#
#
#
#
#   2%|▏         | 222/10000 [00:08<06:45, 24.13it/s, loss=7.14e-5, rmse_test=0.263]
#
#
#
#
#
#
#
#
#   2%|▏         | 222/10000 [00:08<06:45, 24.13it/s, loss=6.8e-5, rmse_test=0.296]
#
#
#
#
#
#
#
#
#   2%|▏         | 222/10000 [00:08<06:45, 24.13it/s, loss=5.62e-5, rmse_test=0.234]
#
#
#
#
#
#
#
#
#   2%|▏         | 225/10000 [00:08<06:33, 24.87it/s, loss=5.62e-5, rmse_test=0.234]
#
#
#
#
#
#
#
#
#   2%|▏         | 225/10000 [00:08<06:33, 24.87it/s, loss=8.5e-5, rmse_test=0.264]
#
#
#
#
#
#
#
#
#   2%|▏         | 225/10000 [00:08<06:33, 24.87it/s, loss=4.54e-5, rmse_test=0.243]
#
#
#
#
#
#
#
#
#   2%|▏         | 225/10000 [00:08<06:33, 24.87it/s, loss=7.02e-5, rmse_test=0.174]
#
#
#
#
#
#
#
#
#   2%|▏         | 228/10000 [00:08<06:43, 24.21it/s, loss=7.02e-5, rmse_test=0.174]
#
#
#
#
#
#
#
#
#   2%|▏         | 228/10000 [00:08<06:43, 24.21it/s, loss=5.69e-5, rmse_test=0.272]
#
#
#
#
#
#
#
#
#   2%|▏         | 228/10000 [00:08<06:43, 24.21it/s, loss=6e-5, rmse_test=0.241]
#
#
#
#
#
#
#
#
#   2%|▏         | 228/10000 [00:08<06:43, 24.21it/s, loss=5.14e-5, rmse_test=0.234]
#
#
#
#
#
#
#
#
#   2%|▏         | 231/10000 [00:08<06:34, 24.78it/s, loss=5.14e-5, rmse_test=0.234]
#
#
#
#
#
#
#
#
#   2%|▏         | 231/10000 [00:08<06:34, 24.78it/s, loss=5.9e-5, rmse_test=0.243]
#
#
#
#
#
#
#
#
#   2%|▏         | 231/10000 [00:08<06:34, 24.78it/s, loss=7.32e-5, rmse_test=0.238]
#
#
#
#
#
#
#
#
#   2%|▏         | 231/10000 [00:09<06:34, 24.78it/s, loss=6.07e-5, rmse_test=0.217]
#
#
#
#
#
#
#
#
#   2%|▏         | 231/10000 [00:09<06:34, 24.78it/s, loss=6.08e-5, rmse_test=0.169]
#
#
#
#
#
#
#
#
#   2%|▏         | 235/10000 [00:09<06:12, 26.21it/s, loss=6.08e-5, rmse_test=0.169]
#
#
#
#
#
#
#
#
#   2%|▏         | 235/10000 [00:09<06:12, 26.21it/s, loss=6.3e-5, rmse_test=0.238]
#
#
#
#
#
#
#
#
#   2%|▏         | 235/10000 [00:09<06:12, 26.21it/s, loss=4.4e-5, rmse_test=0.314]
#
#
#
#
#
#
#
#
#   2%|▏         | 235/10000 [00:09<06:12, 26.21it/s, loss=5.05e-5, rmse_test=0.28]
#
#
#
#
#
#
#
#
#   2%|▏         | 238/10000 [00:09<06:10, 26.34it/s, loss=5.05e-5, rmse_test=0.28]
#
#
#
#
#
#
#
#
#   2%|▏         | 238/10000 [00:09<06:10, 26.34it/s, loss=6.26e-5, rmse_test=0.263]
#
#
#
#
#
#
#
#
#   2%|▏         | 238/10000 [00:09<06:10, 26.34it/s, loss=7.27e-5, rmse_test=0.275]
#
#
#
#
#
#
#
#
#   2%|▏         | 238/10000 [00:09<06:10, 26.34it/s, loss=6e-5, rmse_test=0.25]
#
#
#
#
#
#
#
#
#   2%|▏         | 241/10000 [00:09<06:11, 26.28it/s, loss=6e-5, rmse_test=0.25]
#
#
#
#
#
#
#
#
#   2%|▏         | 241/10000 [00:09<06:11, 26.28it/s, loss=6.54e-5, rmse_test=0.181]
#
#
#
#
#
#
#
#
#   2%|▏         | 241/10000 [00:09<06:11, 26.28it/s, loss=7.35e-5, rmse_test=0.204]
#
#
#
#
#
#
#
#
#   2%|▏         | 241/10000 [00:09<06:11, 26.28it/s, loss=6.99e-5, rmse_test=0.268]
#
#
#
#
#
#
#
#
#   2%|▏         | 244/10000 [00:09<06:12, 26.22it/s, loss=6.99e-5, rmse_test=0.268]
#
#
#
#
#
#
#
#
#   2%|▏         | 244/10000 [00:09<06:12, 26.22it/s, loss=6.71e-5, rmse_test=0.24]
#
#
#
#
#
#
#
#
#   2%|▏         | 244/10000 [00:09<06:12, 26.22it/s, loss=6.62e-5, rmse_test=0.157]
#
#
#
#
#
#
#
#
#   2%|▏         | 244/10000 [00:09<06:12, 26.22it/s, loss=5.54e-5, rmse_test=0.228]
#
#
#
#
#
#
#
#
#   2%|▏         | 247/10000 [00:09<06:07, 26.54it/s, loss=5.54e-5, rmse_test=0.228]
#
#
#
#
#
#
#
#
#   2%|▏         | 247/10000 [00:09<06:07, 26.54it/s, loss=5.89e-5, rmse_test=0.214]
#
#
#
#
#
#
#
#
#   2%|▏         | 247/10000 [00:09<06:07, 26.54it/s, loss=5.9e-5, rmse_test=0.255]
#
#
#
#
#
#
#
#
#   2%|▏         | 247/10000 [00:09<06:07, 26.54it/s, loss=0.000105, rmse_test=0.212]
#
#
#
#
#
#
#
#
#   2%|▎         | 250/10000 [00:09<06:18, 25.74it/s, loss=0.000105, rmse_test=0.212]
#
#
#
#
#
#
#
#
#   2%|▎         | 250/10000 [00:09<06:18, 25.74it/s, loss=5.63e-5, rmse_test=0.344]
#
#
#
#
#
#
#
#
#   2%|▎         | 250/10000 [00:09<06:18, 25.74it/s, loss=8.26e-5, rmse_test=0.318]
#
#
#
#
#
#
#
#
#   2%|▎         | 250/10000 [00:09<06:18, 25.74it/s, loss=6.13e-5, rmse_test=0.207]
#
#
#
#
#
#
#
#
#   3%|▎         | 253/10000 [00:09<06:16, 25.86it/s, loss=6.13e-5, rmse_test=0.207]
#
#
#
#
#
#
#
#
#   3%|▎         | 253/10000 [00:09<06:16, 25.86it/s, loss=7.5e-5, rmse_test=0.185]
#
#
#
#
#
#
#
#
#   3%|▎         | 253/10000 [00:09<06:16, 25.86it/s, loss=6.74e-5, rmse_test=0.246]
#
#
#
#
#
#
#
#
#   3%|▎         | 253/10000 [00:09<06:16, 25.86it/s, loss=5.79e-5, rmse_test=0.2]
#
#
#
#
#
#
#
#
#   3%|▎         | 256/10000 [00:09<06:21, 25.52it/s, loss=5.79e-5, rmse_test=0.2]
#
#
#
#
#
#
#
#
#   3%|▎         | 256/10000 [00:09<06:21, 25.52it/s, loss=6.56e-5, rmse_test=0.224]
#
#
#
#
#
#
#
#
#   3%|▎         | 256/10000 [00:09<06:21, 25.52it/s, loss=6.5e-5, rmse_test=0.21]
#
#
#
#
#
#
#
#
#   3%|▎         | 256/10000 [00:09<06:21, 25.52it/s, loss=6.97e-5, rmse_test=0.323]
#
#
#
#
#
#
#
#
#   3%|▎         | 259/10000 [00:09<06:12, 26.16it/s, loss=6.97e-5, rmse_test=0.323]
#
#
#
#
#
#
#
#
#   3%|▎         | 259/10000 [00:10<06:12, 26.16it/s, loss=6.39e-5, rmse_test=0.294]
#
#
#
#
#
#
#
#
#   3%|▎         | 259/10000 [00:10<06:12, 26.16it/s, loss=8.3e-5, rmse_test=0.167]
#   3%|▎         | 259/10000 [00:10<06:12, 26.16it/s, loss=8.33e-5, rmse_test=0.159]
#
#
#
#
#
#
#
#
#   3%|▎         | 262/10000 [00:10<06:23, 25.39it/s, loss=8.33e-5, rmse_test=0.159]
#
#
#
#
#
#
#
#
#   3%|▎         | 262/10000 [00:10<06:23, 25.39it/s, loss=8.68e-5, rmse_test=0.157]
#
#
#
#
#
#
#
#
#   3%|▎         | 262/10000 [00:10<06:23, 25.39it/s, loss=0.000103, rmse_test=0.23]
#
#
#
#
#
#
#
#
#   3%|▎         | 262/10000 [00:10<06:23, 25.39it/s, loss=8.7e-5, rmse_test=0.234]
#
#
#
#
#
#
#
#
#   3%|▎         | 265/10000 [00:10<06:11, 26.21it/s, loss=8.7e-5, rmse_test=0.234]
#
#
#
#
#
#
#
#
#   3%|▎         | 265/10000 [00:10<06:11, 26.21it/s, loss=6.55e-5, rmse_test=0.267]
#
#
#
#
#
#
#
#
#   3%|▎         | 265/10000 [00:10<06:11, 26.21it/s, loss=6.96e-5, rmse_test=0.236]
#
#
#
#
#
#
#
#
#   3%|▎         | 265/10000 [00:10<06:11, 26.21it/s, loss=8.9e-5, rmse_test=0.242]
#
#
#
#
#
#
#
#
#   3%|▎         | 268/10000 [00:10<06:06, 26.56it/s, loss=8.9e-5, rmse_test=0.242]
#
#
#
#
#
#
#
#
#   3%|▎         | 268/10000 [00:10<06:06, 26.56it/s, loss=7.84e-5, rmse_test=0.235]
#
#
#
#
#
#
#
#
#   3%|▎         | 268/10000 [00:10<06:06, 26.56it/s, loss=6.5e-5, rmse_test=0.187]
#
#
#
#
#
#
#
#
#   3%|▎         | 268/10000 [00:10<06:06, 26.56it/s, loss=6.79e-5, rmse_test=0.215]
#
#
#
#
#
#
#
#
#   3%|▎         | 271/10000 [00:10<05:56, 27.26it/s, loss=6.79e-5, rmse_test=0.215]
#
#
#
#
#
#
#
#
#   3%|▎         | 271/10000 [00:10<05:56, 27.26it/s, loss=7.92e-5, rmse_test=0.204]
#
#
#
#
#
#
#
#
#   3%|▎         | 271/10000 [00:10<05:56, 27.26it/s, loss=6.94e-5, rmse_test=0.146]
#
#
#
#
#
#
#
#
#   3%|▎         | 271/10000 [00:10<05:56, 27.26it/s, loss=6.55e-5, rmse_test=0.111]
#
#
#
#
#
#
#
#
#   3%|▎         | 274/10000 [00:10<05:54, 27.40it/s, loss=6.55e-5, rmse_test=0.111]
#
#
#
#
#
#
#
#
#   3%|▎         | 274/10000 [00:10<05:54, 27.40it/s, loss=6.67e-5, rmse_test=0.302]
#
#
#
#
#
#
#
#
#   3%|▎         | 274/10000 [00:10<05:54, 27.40it/s, loss=7.89e-5, rmse_test=0.232]
#
#
#
#
#
#
#
#
#   3%|▎         | 274/10000 [00:10<05:54, 27.40it/s, loss=5.03e-5, rmse_test=0.171]
#
#
#
#
#
#
#
#
#   3%|▎         | 274/10000 [00:10<05:54, 27.40it/s, loss=6.57e-5, rmse_test=0.284]
#
#
#
#
#
#
#
#
#   3%|▎         | 278/10000 [00:10<05:44, 28.19it/s, loss=6.57e-5, rmse_test=0.284]
#
#
#
#
#
#
#
#
#   3%|▎         | 278/10000 [00:10<05:44, 28.19it/s, loss=6.91e-5, rmse_test=0.167]
#
#
#
#
#
#
#
#
#   3%|▎         | 278/10000 [00:10<05:44, 28.19it/s, loss=6.94e-5, rmse_test=0.18]
#
#
#
#
#
#
#
#
#   3%|▎         | 278/10000 [00:10<05:44, 28.19it/s, loss=6.8e-5, rmse_test=0.165]
#
#
#
#
#
#
#
#
#   3%|▎         | 281/10000 [00:10<05:45, 28.15it/s, loss=6.8e-5, rmse_test=0.165]
#
#
#
#
#
#
#
#
#   3%|▎         | 281/10000 [00:10<05:45, 28.15it/s, loss=7.22e-5, rmse_test=0.294]
#
#
#
#
#
#
#
#
#   3%|▎         | 281/10000 [00:10<05:45, 28.15it/s, loss=7.11e-5, rmse_test=0.225]
#
#
#
#
#
#
#
#
#   3%|▎         | 281/10000 [00:10<05:45, 28.15it/s, loss=6.18e-5, rmse_test=0.295]
#
#
#
#
#
#
#
#
#   3%|▎         | 284/10000 [00:10<05:46, 28.05it/s, loss=6.18e-5, rmse_test=0.295]
#
#
#
#
#
#
#
#
#   3%|▎         | 284/10000 [00:10<05:46, 28.05it/s, loss=8.76e-5, rmse_test=0.223]
#
#
#
#
#
#
#
#
#   3%|▎         | 284/10000 [00:10<05:46, 28.05it/s, loss=5.68e-5, rmse_test=0.235]
#
#
#
#
#
#
#
#
#   3%|▎         | 284/10000 [00:11<05:46, 28.05it/s, loss=7.34e-5, rmse_test=0.197]
#
#
#
#
#
#
#
#
#   3%|▎         | 287/10000 [00:11<05:52, 27.55it/s, loss=7.34e-5, rmse_test=0.197]
#
#
#
#
#
#
#
#
#   3%|▎         | 287/10000 [00:11<05:52, 27.55it/s, loss=6.06e-5, rmse_test=0.142]
#
#
#
#
#
#
#
#
#   3%|▎         | 287/10000 [00:11<05:52, 27.55it/s, loss=7.75e-5, rmse_test=0.237]
#
#
#
#
#
#
#
#
#   3%|▎         | 287/10000 [00:11<05:52, 27.55it/s, loss=7.38e-5, rmse_test=0.203]
#
#
#
#
#
#
#
#
#   3%|▎         | 290/10000 [00:11<05:48, 27.83it/s, loss=7.38e-5, rmse_test=0.203]
#
#
#
#
#
#
#
#
#   3%|▎         | 290/10000 [00:11<05:48, 27.83it/s, loss=6.91e-5, rmse_test=0.173]
#
#
#
#
#
#
#
#
#   3%|▎         | 290/10000 [00:11<05:48, 27.83it/s, loss=5.29e-5, rmse_test=0.188]
#
#
#
#
#
#
#
#
#   3%|▎         | 290/10000 [00:11<05:48, 27.83it/s, loss=5.55e-5, rmse_test=0.253]
#
#
#
#
#
#
#
#
#   3%|▎         | 290/10000 [00:11<05:48, 27.83it/s, loss=7.64e-5, rmse_test=0.34]
#
#
#
#
#
#
#
#
#   3%|▎         | 294/10000 [00:11<05:24, 29.92it/s, loss=7.64e-5, rmse_test=0.34]
#
#
#
#
#
#
#
#
#   3%|▎         | 294/10000 [00:11<05:24, 29.92it/s, loss=7.02e-5, rmse_test=0.171]
#
#
#
#
#
#
#
#
#   3%|▎         | 294/10000 [00:11<05:24, 29.92it/s, loss=7.05e-5, rmse_test=0.187]
#
#
#
#
#
#
#
#
#   3%|▎         | 294/10000 [00:11<05:24, 29.92it/s, loss=6.26e-5, rmse_test=0.193]
#
#
#
#
#
#
#
#
#   3%|▎         | 294/10000 [00:11<05:24, 29.92it/s, loss=5.67e-5, rmse_test=0.153]
#
#
#
#
#
#
#
#
#   3%|▎         | 298/10000 [00:11<05:33, 29.08it/s, loss=5.67e-5, rmse_test=0.153]
#
#
#
#
#
#
#
#
#   3%|▎         | 298/10000 [00:11<05:33, 29.08it/s, loss=4.13e-5, rmse_test=0.278]
#
#
#
#
#
#
#
#
#   3%|▎         | 298/10000 [00:11<05:33, 29.08it/s, loss=6.42e-5, rmse_test=0.205]
#
#
#
#
#
#
#
#
#   3%|▎         | 298/10000 [00:11<05:33, 29.08it/s, loss=6.34e-5, rmse_test=0.175]
#
#
#
#
#
#
#
#
#   3%|▎         | 301/10000 [00:11<06:41, 24.13it/s, loss=6.34e-5, rmse_test=0.175]
#
#
#
#
#
#
#
#
#   3%|▎         | 301/10000 [00:11<06:41, 24.13it/s, loss=7.24e-5, rmse_test=0.171]
#
#
#
#
#
#
#
#
#   3%|▎         | 301/10000 [00:11<06:41, 24.13it/s, loss=7.38e-5, rmse_test=0.174]
#
#
#
#
#
#
#
#
#   3%|▎         | 301/10000 [00:11<06:41, 24.13it/s, loss=5.66e-5, rmse_test=0.168]
#
#
#
#
#
#
#
#
#   3%|▎         | 304/10000 [00:11<06:32, 24.68it/s, loss=5.66e-5, rmse_test=0.168]
#
#
#
#
#
#
#
#
#   3%|▎         | 304/10000 [00:11<06:32, 24.68it/s, loss=5.95e-5, rmse_test=0.141]
#
#
#
#
#
#
#
#
#   3%|▎         | 304/10000 [00:11<06:32, 24.68it/s, loss=4.99e-5, rmse_test=0.155]
#
#
#
#
#
#
#
#
#   3%|▎         | 304/10000 [00:11<06:32, 24.68it/s, loss=6.06e-5, rmse_test=0.18]
#
#
#
#
#
#
#
#
#   3%|▎         | 307/10000 [00:11<06:15, 25.79it/s, loss=6.06e-5, rmse_test=0.18]
#
#
#
#
#
#
#
#
#   3%|▎         | 307/10000 [00:11<06:15, 25.79it/s, loss=7.46e-5, rmse_test=0.133]
#
#
#
#
#
#
#
#
#   3%|▎         | 307/10000 [00:11<06:15, 25.79it/s, loss=6.59e-5, rmse_test=0.104]
#
#
#
#
#
#
#
#
#   3%|▎         | 307/10000 [00:11<06:15, 25.79it/s, loss=0.000105, rmse_test=0.206]
#
#
#
#
#
#
#
#
#   3%|▎         | 310/10000 [00:11<06:05, 26.52it/s, loss=0.000105, rmse_test=0.206]
#
#
#
#
#
#
#
#
#   3%|▎         | 310/10000 [00:11<06:05, 26.52it/s, loss=7.12e-5, rmse_test=0.161]
#
#
#
#
#
#
#
#
#   3%|▎         | 310/10000 [00:11<06:05, 26.52it/s, loss=8.27e-5, rmse_test=0.112]
#
#
#
#
#
#
#
#
#   3%|▎         | 310/10000 [00:11<06:05, 26.52it/s, loss=7.65e-5, rmse_test=0.149]
#
#
#
#
#
#
#
#
#   3%|▎         | 310/10000 [00:11<06:05, 26.52it/s, loss=8.24e-5, rmse_test=0.157]
#   3%|▎         | 314/10000 [00:11<05:47, 27.90it/s, loss=8.24e-5, rmse_test=0.157]
#
#
#
#
#
#
#
#
#   3%|▎         | 314/10000 [00:12<05:47, 27.90it/s, loss=6.4e-5, rmse_test=0.128]
#
#
#
#
#
#
#
#
#   3%|▎         | 314/10000 [00:12<05:47, 27.90it/s, loss=4.63e-5, rmse_test=0.162]
#
#
#
#
#
#
#
#
#   3%|▎         | 314/10000 [00:12<05:47, 27.90it/s, loss=4.09e-5, rmse_test=0.151]
#
#
#
#
#
#
#
#
#   3%|▎         | 314/10000 [00:12<05:47, 27.90it/s, loss=7.57e-5, rmse_test=0.22]
#
#
#
#
#
#
#
#
#   3%|▎         | 318/10000 [00:12<05:32, 29.08it/s, loss=7.57e-5, rmse_test=0.22]
#
#
#
#
#
#
#
#
#   3%|▎         | 318/10000 [00:12<05:32, 29.08it/s, loss=7.36e-5, rmse_test=0.201]
#
#
#
#
#
#
#
#
#   3%|▎         | 318/10000 [00:12<05:32, 29.08it/s, loss=6.5e-5, rmse_test=0.136]
#
#
#
#
#
#
#
#
#   3%|▎         | 318/10000 [00:12<05:32, 29.08it/s, loss=6e-5, rmse_test=0.215]
#
#
#
#
#
#
#
#
#   3%|▎         | 318/10000 [00:12<05:32, 29.08it/s, loss=7.44e-5, rmse_test=0.187]
#
#
#
#
#
#
#
#
#   3%|▎         | 322/10000 [00:12<05:26, 29.66it/s, loss=7.44e-5, rmse_test=0.187]
#
#
#
#
#
#
#
#
#   3%|▎         | 322/10000 [00:12<05:26, 29.66it/s, loss=8.07e-5, rmse_test=0.156]
#
#
#
#
#
#
#
#
#   3%|▎         | 322/10000 [00:12<05:26, 29.66it/s, loss=5.89e-5, rmse_test=0.186]
#
#
#
#
#
#
#
#
#   3%|▎         | 322/10000 [00:12<05:26, 29.66it/s, loss=5.82e-5, rmse_test=0.092]
#
#
#
#
#
#
#
#
#   3%|▎         | 322/10000 [00:12<05:26, 29.66it/s, loss=7.82e-5, rmse_test=0.252]
#
#
#
#
#
#
#
#
#   3%|▎         | 326/10000 [00:12<05:31, 29.16it/s, loss=7.82e-5, rmse_test=0.252]
#
#
#
#
#
#
#
#
#   3%|▎         | 326/10000 [00:12<05:31, 29.16it/s, loss=4.63e-5, rmse_test=0.141]
#
#
#
#
#
#
#
#
#   3%|▎         | 326/10000 [00:12<05:31, 29.16it/s, loss=6.01e-5, rmse_test=0.146]
#
#
#
#
#
#
#
#
#   3%|▎         | 326/10000 [00:12<05:31, 29.16it/s, loss=7.81e-5, rmse_test=0.188]
#
#
#
#
#
#
#
#
#   3%|▎         | 329/10000 [00:12<05:34, 28.89it/s, loss=7.81e-5, rmse_test=0.188]
#
#
#
#
#
#
#
#
#   3%|▎         | 329/10000 [00:12<05:34, 28.89it/s, loss=6.83e-5, rmse_test=0.185]
#
#
#
#
#
#
#
#
#   3%|▎         | 329/10000 [00:12<05:34, 28.89it/s, loss=4.71e-5, rmse_test=0.132]
#
#
#
#
#
#
#
#
#   3%|▎         | 329/10000 [00:12<05:34, 28.89it/s, loss=7.86e-5, rmse_test=0.208]
#
#
#
#
#
#
#
#
#   3%|▎         | 332/10000 [00:12<05:41, 28.33it/s, loss=7.86e-5, rmse_test=0.208]
#
#
#
#
#
#
#
#
#   3%|▎         | 332/10000 [00:12<05:41, 28.33it/s, loss=6.55e-5, rmse_test=0.229]
#
#
#
#
#
#
#
#
#   3%|▎         | 332/10000 [00:12<05:41, 28.33it/s, loss=8.16e-5, rmse_test=0.256]
#
#
#
#
#
#
#
#
#   3%|▎         | 332/10000 [00:12<05:41, 28.33it/s, loss=7.52e-5, rmse_test=0.176]
#
#
#
#
#
#
#
#
#   3%|▎         | 332/10000 [00:12<05:41, 28.33it/s, loss=6.74e-5, rmse_test=0.0912]
#
#
#
#
#
#
#
#
#   3%|▎         | 336/10000 [00:12<05:33, 28.95it/s, loss=6.74e-5, rmse_test=0.0912]
#
#
#
#
#
#
#
#
#   3%|▎         | 336/10000 [00:12<05:33, 28.95it/s, loss=8.37e-5, rmse_test=0.0818]
#
#
#
#
#
#
#
#
#   3%|▎         | 336/10000 [00:12<05:33, 28.95it/s, loss=6.94e-5, rmse_test=0.186]
#
#
#
#
#
#
#
#
#   3%|▎         | 336/10000 [00:12<05:33, 28.95it/s, loss=6.27e-5, rmse_test=0.154]
#
#
#
#
#
#
#
#
#   3%|▎         | 336/10000 [00:12<05:33, 28.95it/s, loss=7e-5, rmse_test=0.147]
#
#
#
#
#
#
#
#
#   3%|▎         | 340/10000 [00:12<05:26, 29.61it/s, loss=7e-5, rmse_test=0.147]
#
#
#
#
#
#
#
#
#   3%|▎         | 340/10000 [00:12<05:26, 29.61it/s, loss=6.9e-5, rmse_test=0.174]
#
#
#
#
#
#
#
#
#   3%|▎         | 340/10000 [00:12<05:26, 29.61it/s, loss=7.7e-5, rmse_test=0.307]
#
#
#
#
#
#
#
#
#   3%|▎         | 340/10000 [00:12<05:26, 29.61it/s, loss=8.82e-5, rmse_test=0.151]
#
#
#
#
#
#
#
#
#   3%|▎         | 343/10000 [00:12<05:31, 29.10it/s, loss=8.82e-5, rmse_test=0.151]
#
#
#
#
#
#
#
#
#   3%|▎         | 343/10000 [00:13<05:31, 29.10it/s, loss=8.31e-5, rmse_test=0.109]
#
#
#
#
#
#
#
#
#   3%|▎         | 343/10000 [00:13<05:31, 29.10it/s, loss=8.73e-5, rmse_test=0.234]
#
#
#
#
#
#
#
#
#   3%|▎         | 343/10000 [00:13<05:31, 29.10it/s, loss=7.75e-5, rmse_test=0.108]
#
#
#
#
#
#
#
#
#   3%|▎         | 346/10000 [00:13<05:38, 28.56it/s, loss=7.75e-5, rmse_test=0.108]
#
#
#
#
#
#
#
#
#   3%|▎         | 346/10000 [00:13<05:38, 28.56it/s, loss=9.89e-5, rmse_test=0.145]
#
#
#
#
#
#
#
#
#   3%|▎         | 346/10000 [00:13<05:38, 28.56it/s, loss=7.66e-5, rmse_test=0.111]
#
#
#
#
#
#
#
#
#   3%|▎         | 346/10000 [00:13<05:38, 28.56it/s, loss=7.49e-5, rmse_test=0.0843]
#
#
#
#
#
#
#
#
#   3%|▎         | 349/10000 [00:13<05:40, 28.32it/s, loss=7.49e-5, rmse_test=0.0843]
#
#
#
#
#
#
#
#
#   3%|▎         | 349/10000 [00:13<05:40, 28.32it/s, loss=5.21e-5, rmse_test=0.139]
#
#
#
#
#
#
#
#
#   3%|▎         | 349/10000 [00:13<05:40, 28.32it/s, loss=8.76e-5, rmse_test=0.105]
#
#
#
#
#
#
#
#
#   3%|▎         | 349/10000 [00:13<05:40, 28.32it/s, loss=8.05e-5, rmse_test=0.13]
#
#
#
#
#
#
#
#
#   4%|▎         | 352/10000 [00:13<05:50, 27.55it/s, loss=8.05e-5, rmse_test=0.13]
#
#
#
#
#
#
#
#
#   4%|▎         | 352/10000 [00:13<05:50, 27.55it/s, loss=7.62e-5, rmse_test=0.0719]
#
#
#
#
#
#
#
#
#   4%|▎         | 352/10000 [00:13<05:50, 27.55it/s, loss=7.85e-5, rmse_test=0.136]
#
#
#
#
#
#
#
#
#   4%|▎         | 352/10000 [00:13<05:50, 27.55it/s, loss=8.63e-5, rmse_test=0.131]
#
#
#
#
#
#
#
#
#   4%|▎         | 355/10000 [00:13<06:04, 26.46it/s, loss=8.63e-5, rmse_test=0.131]
#
#
#
#
#
#
#
#
#   4%|▎         | 355/10000 [00:13<06:04, 26.46it/s, loss=6.56e-5, rmse_test=0.0636]
#
#
#
#
#
#
#
#
#   4%|▎         | 355/10000 [00:13<06:04, 26.46it/s, loss=7.36e-5, rmse_test=0.238]
#
#
#
#
#
#
#
#
#   4%|▎         | 355/10000 [00:13<06:04, 26.46it/s, loss=6.25e-5, rmse_test=0.129]
#
#
#
#
#
#
#
#
#   4%|▎         | 358/10000 [00:13<05:56, 27.08it/s, loss=6.25e-5, rmse_test=0.129]
#
#
#
#
#
#
#
#
#   4%|▎         | 358/10000 [00:13<05:56, 27.08it/s, loss=7.12e-5, rmse_test=0.099]
#
#
#
#
#
#
#
#
#   4%|▎         | 358/10000 [00:13<05:56, 27.08it/s, loss=5.49e-5, rmse_test=0.0998]
#
#
#
#
#
#
#
#
#   4%|▎         | 358/10000 [00:13<05:56, 27.08it/s, loss=7.27e-5, rmse_test=0.119]
#
#
#
#
#
#
#
#
#   4%|▎         | 361/10000 [00:13<05:51, 27.45it/s, loss=7.27e-5, rmse_test=0.119]
#
#
#
#
#
#
#
#
#   4%|▎         | 361/10000 [00:13<05:51, 27.45it/s, loss=7.02e-5, rmse_test=0.251]
#
#
#
#
#
#
#
#
#   4%|▎         | 361/10000 [00:13<05:51, 27.45it/s, loss=7.41e-5, rmse_test=0.194]
#
#
#
#
#
#
#
#
#   4%|▎         | 361/10000 [00:13<05:51, 27.45it/s, loss=7.15e-5, rmse_test=0.0971]
#
#
#
#
#
#
#
#
#   4%|▎         | 364/10000 [00:13<05:58, 26.91it/s, loss=7.15e-5, rmse_test=0.0971]
#
#
#
#
#
#
#
#
#   4%|▎         | 364/10000 [00:13<05:58, 26.91it/s, loss=7.17e-5, rmse_test=0.134]
#
#
#
#
#
#
#
#
#   4%|▎         | 364/10000 [00:13<05:58, 26.91it/s, loss=6.51e-5, rmse_test=0.108]
#
#
#
#
#
#
#
#
#   4%|▎         | 364/10000 [00:13<05:58, 26.91it/s, loss=7.65e-5, rmse_test=0.184]
#   4%|▎         | 367/10000 [00:13<05:54, 27.17it/s, loss=7.65e-5, rmse_test=0.184]
#
#
#
#
#
#
#
#
#   4%|▎         | 367/10000 [00:13<05:54, 27.17it/s, loss=7.43e-5, rmse_test=0.0897]
#
#
#
#
#
#
#
#
#   4%|▎         | 367/10000 [00:13<05:54, 27.17it/s, loss=5.89e-5, rmse_test=0.169]
#
#
#
#
#
#
#
#
#   4%|▎         | 367/10000 [00:13<05:54, 27.17it/s, loss=5.38e-5, rmse_test=0.0883]
#
#
#
#
#
#
#
#
#   4%|▎         | 370/10000 [00:13<05:52, 27.31it/s, loss=5.38e-5, rmse_test=0.0883]
#
#
#
#
#
#
#
#
#   4%|▎         | 370/10000 [00:14<05:52, 27.31it/s, loss=6.65e-5, rmse_test=0.153]
#
#
#
#
#
#
#
#
#   4%|▎         | 370/10000 [00:14<05:52, 27.31it/s, loss=7.17e-5, rmse_test=0.0817]
#
#
#
#
#
#
#
#
#   4%|▎         | 370/10000 [00:14<05:52, 27.31it/s, loss=8.16e-5, rmse_test=0.158]
#
#
#
#
#
#
#
#
#   4%|▎         | 373/10000 [00:14<05:53, 27.24it/s, loss=8.16e-5, rmse_test=0.158]
#
#
#
#
#
#
#
#
#   4%|▎         | 373/10000 [00:14<05:53, 27.24it/s, loss=0.000107, rmse_test=0.234]
#
#
#
#
#
#
#
#
#   4%|▎         | 373/10000 [00:14<05:53, 27.24it/s, loss=9.5e-5, rmse_test=0.214]
#
#
#
#
#
#
#
#
#   4%|▎         | 373/10000 [00:14<05:53, 27.24it/s, loss=8.43e-5, rmse_test=0.106]
#
#
#
#
#
#
#
#
#   4%|▍         | 376/10000 [00:14<05:47, 27.69it/s, loss=8.43e-5, rmse_test=0.106]
#
#
#
#
#
#
#
#
#   4%|▍         | 376/10000 [00:14<05:47, 27.69it/s, loss=8.59e-5, rmse_test=0.0532]
#
#
#
#
#
#
#
#
#   4%|▍         | 376/10000 [00:14<05:47, 27.69it/s, loss=6.28e-5, rmse_test=0.111]
#
#
#
#
#
#
#
#
#   4%|▍         | 376/10000 [00:14<05:47, 27.69it/s, loss=9.17e-5, rmse_test=0.116]
#
#
#
#
#
#
#
#
#   4%|▍         | 379/10000 [00:14<05:40, 28.23it/s, loss=9.17e-5, rmse_test=0.116]
#
#
#
#
#
#
#
#
#   4%|▍         | 379/10000 [00:14<05:40, 28.23it/s, loss=8.35e-5, rmse_test=0.218]
#
#
#
#
#
#
#
#
#   4%|▍         | 379/10000 [00:14<05:40, 28.23it/s, loss=8.26e-5, rmse_test=0.121]
#
#
#
#
#
#
#
#
#   4%|▍         | 379/10000 [00:14<05:40, 28.23it/s, loss=8.56e-5, rmse_test=0.0943]
#
#
#
#
#
#
#
#
#   4%|▍         | 379/10000 [00:14<05:40, 28.23it/s, loss=6.34e-5, rmse_test=0.103]
#
#
#
#
#
#
#
#
#   4%|▍         | 383/10000 [00:14<05:34, 28.74it/s, loss=6.34e-5, rmse_test=0.103]
#
#
#
#
#
#
#
#
#   4%|▍         | 383/10000 [00:14<05:34, 28.74it/s, loss=7.29e-5, rmse_test=0.0641]
#
#
#
#
#
#
#
#
#   4%|▍         | 383/10000 [00:14<05:34, 28.74it/s, loss=8.75e-5, rmse_test=0.0694]
#
#
#
#
#
#
#
#
#   4%|▍         | 383/10000 [00:14<05:34, 28.74it/s, loss=5.63e-5, rmse_test=0.0909]
#
#
#
#
#
#
#
#
#   4%|▍         | 386/10000 [00:14<05:35, 28.66it/s, loss=5.63e-5, rmse_test=0.0909]
#
#
#
#
#
#
#
#
#   4%|▍         | 386/10000 [00:14<05:35, 28.66it/s, loss=5.42e-5, rmse_test=0.0917]
#
#
#
#
#
#
#
#
#   4%|▍         | 386/10000 [00:14<05:35, 28.66it/s, loss=9.36e-5, rmse_test=0.0995]
#
#
#
#
#
#
#
#
#   4%|▍         | 386/10000 [00:14<05:35, 28.66it/s, loss=7.65e-5, rmse_test=0.0533]
#
#
#
#
#
#
#
#
#   4%|▍         | 389/10000 [00:14<05:32, 28.95it/s, loss=7.65e-5, rmse_test=0.0533]
#
#
#
#
#
#
#
#
#   4%|▍         | 389/10000 [00:14<05:32, 28.95it/s, loss=6.1e-5, rmse_test=0.0956]
#
#
#
#
#
#
#
#
#   4%|▍         | 389/10000 [00:14<05:32, 28.95it/s, loss=6.05e-5, rmse_test=0.12]
#
#
#
#
#
#
#
#
#   4%|▍         | 389/10000 [00:14<05:32, 28.95it/s, loss=6.32e-5, rmse_test=0.203]
#
#
#
#
#
#
#
#
#   4%|▍         | 389/10000 [00:14<05:32, 28.95it/s, loss=6.68e-5, rmse_test=0.147]
#
#
#
#
#
#
#
#
#   4%|▍         | 393/10000 [00:14<05:22, 29.80it/s, loss=6.68e-5, rmse_test=0.147]
#
#
#
#
#
#
#
#
#   4%|▍         | 393/10000 [00:14<05:22, 29.80it/s, loss=7.61e-5, rmse_test=0.0686]
#
#
#
#
#
#
#
#
#   4%|▍         | 393/10000 [00:14<05:22, 29.80it/s, loss=9.76e-5, rmse_test=0.0914]
#
#
#
#
#
#
#
#
#   4%|▍         | 393/10000 [00:14<05:22, 29.80it/s, loss=9.49e-5, rmse_test=0.152]
#
#
#
#
#
#
#
#
#   4%|▍         | 396/10000 [00:14<05:35, 28.63it/s, loss=9.49e-5, rmse_test=0.152]
#
#
#
#
#
#
#
#
#   4%|▍         | 396/10000 [00:14<05:35, 28.63it/s, loss=9.91e-5, rmse_test=0.114]
#
#
#
#
#
#
#
#
#   4%|▍         | 396/10000 [00:14<05:35, 28.63it/s, loss=6.28e-5, rmse_test=0.069]
#
#
#
#
#
#
#
#
#   4%|▍         | 396/10000 [00:14<05:35, 28.63it/s, loss=6.75e-5, rmse_test=0.0766]
#
#
#
#
#
#
#
#
#   4%|▍         | 399/10000 [00:14<05:31, 28.99it/s, loss=6.75e-5, rmse_test=0.0766]
#
#
#
#
#
#
#
#
#   4%|▍         | 399/10000 [00:15<05:31, 28.99it/s, loss=5.96e-5, rmse_test=0.0774]
#
#
#
#
#
#
#
#
#   4%|▍         | 399/10000 [00:15<05:31, 28.99it/s, loss=7.81e-5, rmse_test=0.0996]
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
#  41%|████      | 4083/10000 [02:49<03:50, 25.72it/s, loss=7.31e-7, rmse_test=0.0306]
#
#
#
#
#
#
#
#
#  41%|████      | 4083/10000 [02:49<03:50, 25.72it/s, loss=7.29e-7, rmse_test=0.029]
#
#
#
#
#
#
#
#
#  41%|████      | 4083/10000 [02:49<03:50, 25.72it/s, loss=7.32e-7, rmse_test=0.03]
#
#
#
#
#
#
#
#
#  41%|████      | 4086/10000 [02:49<03:48, 25.84it/s, loss=7.32e-7, rmse_test=0.03]
#
#
#
#
#
#
#
#
#  41%|████      | 4086/10000 [02:49<03:48, 25.84it/s, loss=7.31e-7, rmse_test=0.0294]
#
#
#
#
#
#
#
#
#  41%|████      | 4086/10000 [02:49<03:48, 25.84it/s, loss=7.33e-7, rmse_test=0.0301]
#
#
#
#
#
#
#
#
#  41%|████      | 4086/10000 [02:49<03:48, 25.84it/s, loss=7.31e-7, rmse_test=0.0302]
#
#
#
#
#
#
#
#
#  41%|████      | 4089/10000 [02:49<03:47, 25.97it/s, loss=7.31e-7, rmse_test=0.0302]
#
#
#
#
#
#
#
#
#  41%|████      | 4089/10000 [02:49<03:47, 25.97it/s, loss=7.31e-7, rmse_test=0.0293]
#
#
#
#
#
#
#
#
#  41%|████      | 4089/10000 [02:49<03:47, 25.97it/s, loss=7.3e-7, rmse_test=0.0305]
#
#
#
#
#
#
#
#
#  41%|████      | 4089/10000 [02:49<03:47, 25.97it/s, loss=7.31e-7, rmse_test=0.03]
#
#
#
#
#
#
#
#
#  41%|████      | 4092/10000 [02:49<03:39, 26.89it/s, loss=7.31e-7, rmse_test=0.03]
#
#
#
#
#
#
#
#
#  41%|████      | 4092/10000 [02:49<03:39, 26.89it/s, loss=7.29e-7, rmse_test=0.0304]
#
#
#
#
#
#
#
#
#  41%|████      | 4092/10000 [02:49<03:39, 26.89it/s, loss=7.3e-7, rmse_test=0.031]
#
#
#
#
#
#
#
#
#  41%|████      | 4092/10000 [02:49<03:39, 26.89it/s, loss=7.29e-7, rmse_test=0.0306]
#
#
#
#
#
#
#
#
#  41%|████      | 4095/10000 [02:49<03:44, 26.29it/s, loss=7.29e-7, rmse_test=0.0306]
#
#
#
#
#
#
#
#
#  41%|████      | 4095/10000 [02:49<03:44, 26.29it/s, loss=7.29e-7, rmse_test=0.0293]
#
#
#
#
#
#
#
#
#  41%|████      | 4095/10000 [02:49<03:44, 26.29it/s, loss=7.31e-7, rmse_test=0.0296]
#
#
#
#
#
#
#
#
#  41%|████      | 4095/10000 [02:49<03:44, 26.29it/s, loss=7.29e-7, rmse_test=0.0317]
#
#
#
#
#
#
#
#
#  41%|████      | 4098/10000 [02:49<03:39, 26.85it/s, loss=7.29e-7, rmse_test=0.0317]
#
#
#
#
#
#
#
#
#  41%|████      | 4098/10000 [02:49<03:39, 26.85it/s, loss=7.3e-7, rmse_test=0.0314]
#
#
#
#
#
#
#
#
#  41%|████      | 4098/10000 [02:49<03:39, 26.85it/s, loss=7.31e-7, rmse_test=0.0305]
#
#
#
#
#
#
#
#
#  41%|████      | 4098/10000 [02:50<03:39, 26.85it/s, loss=7.3e-7, rmse_test=0.0311]
#
#
#
#
#
#
#
#
#  41%|████      | 4101/10000 [02:50<10:10,  9.66it/s, loss=7.3e-7, rmse_test=0.0311]
#
#
#
#
#
#
#
#
#  41%|████      | 4101/10000 [02:50<10:10,  9.66it/s, loss=7.3e-7, rmse_test=0.0317]
#
#
#
#
#
#
#
#
#  41%|████      | 4101/10000 [02:50<10:10,  9.66it/s, loss=7.29e-7, rmse_test=0.031]
#
#
#
#
#
#
#
#
#  41%|████      | 4101/10000 [02:50<10:10,  9.66it/s, loss=7.28e-7, rmse_test=0.0296]
#
#
#
#
#
#
#
#
#  41%|████      | 4104/10000 [02:50<08:13, 11.96it/s, loss=7.28e-7, rmse_test=0.0296]
#
#
#
#
#
#
#
#
#  41%|████      | 4104/10000 [02:50<08:13, 11.96it/s, loss=7.28e-7, rmse_test=0.0302]
#
#
#
#
#
#
#
#
#  41%|████      | 4104/10000 [02:50<08:13, 11.96it/s, loss=7.28e-7, rmse_test=0.029]
#
#
#
#
#
#
#
#
#  41%|████      | 4104/10000 [02:50<08:13, 11.96it/s, loss=7.27e-7, rmse_test=0.0297]
#
#
#
#
#
#
#
#
#  41%|████      | 4107/10000 [02:50<06:45, 14.53it/s, loss=7.27e-7, rmse_test=0.0297]
#
#
#
#
#
#
#
#
#  41%|████      | 4107/10000 [02:50<06:45, 14.53it/s, loss=7.27e-7, rmse_test=0.0297]
#
#
#
#
#
#
#
#
#  41%|████      | 4107/10000 [02:50<06:45, 14.53it/s, loss=7.28e-7, rmse_test=0.0288]
#
#
#
#
#
#
#
#
#  41%|████      | 4107/10000 [02:50<06:45, 14.53it/s, loss=7.29e-7, rmse_test=0.0296]
#
#
#
#
#
#
#
#
#  41%|████      | 4110/10000 [02:50<05:50, 16.81it/s, loss=7.29e-7, rmse_test=0.0296]
#
#
#
#
#
#
#
#
#  41%|████      | 4110/10000 [02:50<05:50, 16.81it/s, loss=7.28e-7, rmse_test=0.0295]
#
#
#
#
#
#
#
#
#  41%|████      | 4110/10000 [02:50<05:50, 16.81it/s, loss=7.29e-7, rmse_test=0.0297]
#
#
#
#
#
#
#
#
#  41%|████      | 4110/10000 [02:50<05:50, 16.81it/s, loss=7.29e-7, rmse_test=0.0334]
#
#
#
#
#
#
#
#
#  41%|████      | 4113/10000 [02:50<05:13, 18.80it/s, loss=7.29e-7, rmse_test=0.0334]
#
#
#
#
#
#
#
#
#  41%|████      | 4113/10000 [02:50<05:13, 18.80it/s, loss=7.3e-7, rmse_test=0.0312]
#
#
#
#
#
#
#
#
#  41%|████      | 4113/10000 [02:50<05:13, 18.80it/s, loss=7.28e-7, rmse_test=0.0321]
#
#
#
#
#
#
#
#
#  41%|████      | 4113/10000 [02:51<05:13, 18.80it/s, loss=7.29e-7, rmse_test=0.0328]
#
#
#
#
#
#
#
#
#  41%|████      | 4116/10000 [02:51<04:54, 19.96it/s, loss=7.29e-7, rmse_test=0.0328]
#
#
#
#
#
#
#
#
#  41%|████      | 4116/10000 [02:51<04:54, 19.96it/s, loss=7.29e-7, rmse_test=0.0312]
#
#
#
#
#
#
#
#
#  41%|████      | 4116/10000 [02:51<04:54, 19.96it/s, loss=7.29e-7, rmse_test=0.0313]
#
#
#
#
#
#
#
#
#  41%|████      | 4116/10000 [02:51<04:54, 19.96it/s, loss=7.29e-7, rmse_test=0.0303]
#  41%|████      | 4119/10000 [02:51<04:31, 21.68it/s, loss=7.29e-7, rmse_test=0.0303]
#
#
#
#
#
#
#
#
#  41%|████      | 4119/10000 [02:51<04:31, 21.68it/s, loss=7.3e-7, rmse_test=0.0328]
#
#
#
#
#
#
#
#
#  41%|████      | 4119/10000 [02:51<04:31, 21.68it/s, loss=7.3e-7, rmse_test=0.0302]
#
#
#
#
#
#
#
#
#  41%|████      | 4119/10000 [02:51<04:31, 21.68it/s, loss=7.29e-7, rmse_test=0.0304]
#
#
#
#
#
#
#
#
#  41%|████      | 4122/10000 [02:51<04:15, 23.04it/s, loss=7.29e-7, rmse_test=0.0304]
#
#
#
#
#
#
#
#
#  41%|████      | 4122/10000 [02:51<04:15, 23.04it/s, loss=7.29e-7, rmse_test=0.0358]
#
#
#
#
#
#
#
#
#  41%|████      | 4122/10000 [02:51<04:15, 23.04it/s, loss=7.32e-7, rmse_test=0.033]
#
#
#
#
#
#
#
#
#  41%|████      | 4122/10000 [02:51<04:15, 23.04it/s, loss=7.29e-7, rmse_test=0.0313]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4125/10000 [02:51<04:02, 24.22it/s, loss=7.29e-7, rmse_test=0.0313]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4125/10000 [02:51<04:02, 24.22it/s, loss=7.29e-7, rmse_test=0.0326]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4125/10000 [02:51<04:02, 24.22it/s, loss=7.3e-7, rmse_test=0.0312]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4125/10000 [02:51<04:02, 24.22it/s, loss=7.29e-7, rmse_test=0.0341]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4128/10000 [02:51<03:57, 24.75it/s, loss=7.29e-7, rmse_test=0.0341]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4128/10000 [02:51<03:57, 24.75it/s, loss=7.31e-7, rmse_test=0.032]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4128/10000 [02:51<03:57, 24.75it/s, loss=7.27e-7, rmse_test=0.0312]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4128/10000 [02:51<03:57, 24.75it/s, loss=7.27e-7, rmse_test=0.0305]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4131/10000 [02:51<03:56, 24.80it/s, loss=7.27e-7, rmse_test=0.0305]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4131/10000 [02:51<03:56, 24.80it/s, loss=7.26e-7, rmse_test=0.031]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4131/10000 [02:51<03:56, 24.80it/s, loss=7.26e-7, rmse_test=0.0319]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4131/10000 [02:51<03:56, 24.80it/s, loss=7.28e-7, rmse_test=0.0307]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4134/10000 [02:51<03:48, 25.64it/s, loss=7.28e-7, rmse_test=0.0307]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4134/10000 [02:51<03:48, 25.64it/s, loss=7.27e-7, rmse_test=0.0304]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4134/10000 [02:51<03:48, 25.64it/s, loss=7.32e-7, rmse_test=0.0305]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4134/10000 [02:51<03:48, 25.64it/s, loss=7.29e-7, rmse_test=0.0347]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4137/10000 [02:51<03:49, 25.51it/s, loss=7.29e-7, rmse_test=0.0347]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4137/10000 [02:51<03:49, 25.51it/s, loss=7.32e-7, rmse_test=0.034]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4137/10000 [02:51<03:49, 25.51it/s, loss=7.31e-7, rmse_test=0.0308]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4137/10000 [02:51<03:49, 25.51it/s, loss=7.29e-7, rmse_test=0.0322]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4140/10000 [02:51<03:49, 25.56it/s, loss=7.29e-7, rmse_test=0.0322]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4140/10000 [02:51<03:49, 25.56it/s, loss=7.28e-7, rmse_test=0.0316]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4140/10000 [02:52<03:49, 25.56it/s, loss=7.29e-7, rmse_test=0.0311]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4140/10000 [02:52<03:49, 25.56it/s, loss=7.27e-7, rmse_test=0.0327]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4143/10000 [02:52<03:48, 25.68it/s, loss=7.27e-7, rmse_test=0.0327]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4143/10000 [02:52<03:48, 25.68it/s, loss=7.28e-7, rmse_test=0.0314]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4143/10000 [02:52<03:48, 25.68it/s, loss=7.28e-7, rmse_test=0.0315]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4143/10000 [02:52<03:48, 25.68it/s, loss=7.26e-7, rmse_test=0.031]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4146/10000 [02:52<03:51, 25.28it/s, loss=7.26e-7, rmse_test=0.031]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4146/10000 [02:52<03:51, 25.28it/s, loss=7.27e-7, rmse_test=0.0314]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4146/10000 [02:52<03:51, 25.28it/s, loss=7.27e-7, rmse_test=0.0312]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4146/10000 [02:52<03:51, 25.28it/s, loss=7.26e-7, rmse_test=0.0303]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4149/10000 [02:52<03:45, 25.99it/s, loss=7.26e-7, rmse_test=0.0303]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4149/10000 [02:52<03:45, 25.99it/s, loss=7.25e-7, rmse_test=0.0306]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4149/10000 [02:52<03:45, 25.99it/s, loss=7.23e-7, rmse_test=0.0309]
#
#
#
#
#
#
#
#
#  41%|████▏     | 4149/10000 [02:52<03:45, 25.99it/s, loss=7.24e-7, rmse_test=0.0307]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4152/10000 [02:52<03:45, 25.94it/s, loss=7.24e-7, rmse_test=0.0307]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4152/10000 [02:52<03:45, 25.94it/s, loss=7.22e-7, rmse_test=0.0299]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4152/10000 [02:52<03:45, 25.94it/s, loss=7.25e-7, rmse_test=0.0295]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4152/10000 [02:52<03:45, 25.94it/s, loss=7.25e-7, rmse_test=0.0294]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4155/10000 [02:52<03:41, 26.44it/s, loss=7.25e-7, rmse_test=0.0294]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4155/10000 [02:52<03:41, 26.44it/s, loss=7.27e-7, rmse_test=0.0295]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4155/10000 [02:52<03:41, 26.44it/s, loss=7.25e-7, rmse_test=0.03]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4155/10000 [02:52<03:41, 26.44it/s, loss=7.24e-7, rmse_test=0.0303]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4158/10000 [02:52<03:42, 26.26it/s, loss=7.24e-7, rmse_test=0.0303]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4158/10000 [02:52<03:42, 26.26it/s, loss=7.25e-7, rmse_test=0.0301]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4158/10000 [02:52<03:42, 26.26it/s, loss=7.24e-7, rmse_test=0.0295]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4158/10000 [02:52<03:42, 26.26it/s, loss=7.24e-7, rmse_test=0.0321]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4161/10000 [02:52<03:47, 25.70it/s, loss=7.24e-7, rmse_test=0.0321]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4161/10000 [02:52<03:47, 25.70it/s, loss=7.25e-7, rmse_test=0.0305]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4161/10000 [02:52<03:47, 25.70it/s, loss=7.25e-7, rmse_test=0.0298]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4161/10000 [02:52<03:47, 25.70it/s, loss=7.24e-7, rmse_test=0.0301]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4164/10000 [02:52<03:44, 25.98it/s, loss=7.24e-7, rmse_test=0.0301]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4164/10000 [02:52<03:44, 25.98it/s, loss=7.23e-7, rmse_test=0.0301]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4164/10000 [02:52<03:44, 25.98it/s, loss=7.24e-7, rmse_test=0.0306]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4164/10000 [02:52<03:44, 25.98it/s, loss=7.24e-7, rmse_test=0.0295]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4167/10000 [02:52<03:39, 26.54it/s, loss=7.24e-7, rmse_test=0.0295]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4167/10000 [02:53<03:39, 26.54it/s, loss=7.23e-7, rmse_test=0.031]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4167/10000 [02:53<03:39, 26.54it/s, loss=7.22e-7, rmse_test=0.0326]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4167/10000 [02:53<03:39, 26.54it/s, loss=7.24e-7, rmse_test=0.0356]
#  42%|████▏     | 4170/10000 [02:53<03:38, 26.73it/s, loss=7.24e-7, rmse_test=0.0356]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4170/10000 [02:53<03:38, 26.73it/s, loss=7.28e-7, rmse_test=0.0319]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4170/10000 [02:53<03:38, 26.73it/s, loss=7.24e-7, rmse_test=0.0333]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4170/10000 [02:53<03:38, 26.73it/s, loss=7.26e-7, rmse_test=0.033]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4173/10000 [02:53<03:35, 27.06it/s, loss=7.26e-7, rmse_test=0.033]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4173/10000 [02:53<03:35, 27.06it/s, loss=7.26e-7, rmse_test=0.0318]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4173/10000 [02:53<03:35, 27.06it/s, loss=7.23e-7, rmse_test=0.0317]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4173/10000 [02:53<03:35, 27.06it/s, loss=7.23e-7, rmse_test=0.0322]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4176/10000 [02:53<03:36, 26.90it/s, loss=7.23e-7, rmse_test=0.0322]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4176/10000 [02:53<03:36, 26.90it/s, loss=7.23e-7, rmse_test=0.0327]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4176/10000 [02:53<03:36, 26.90it/s, loss=7.24e-7, rmse_test=0.0319]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4176/10000 [02:53<03:36, 26.90it/s, loss=7.22e-7, rmse_test=0.0342]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4179/10000 [02:53<03:34, 27.09it/s, loss=7.22e-7, rmse_test=0.0342]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4179/10000 [02:53<03:34, 27.09it/s, loss=7.25e-7, rmse_test=0.0326]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4179/10000 [02:53<03:34, 27.09it/s, loss=7.23e-7, rmse_test=0.0342]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4179/10000 [02:53<03:34, 27.09it/s, loss=7.26e-7, rmse_test=0.0326]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4182/10000 [02:53<03:45, 25.82it/s, loss=7.26e-7, rmse_test=0.0326]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4182/10000 [02:53<03:45, 25.82it/s, loss=7.24e-7, rmse_test=0.032]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4182/10000 [02:53<03:45, 25.82it/s, loss=7.24e-7, rmse_test=0.0315]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4182/10000 [02:53<03:45, 25.82it/s, loss=7.23e-7, rmse_test=0.0312]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4185/10000 [02:53<03:41, 26.20it/s, loss=7.23e-7, rmse_test=0.0312]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4185/10000 [02:53<03:41, 26.20it/s, loss=7.23e-7, rmse_test=0.0313]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4185/10000 [02:53<03:41, 26.20it/s, loss=7.22e-7, rmse_test=0.0307]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4185/10000 [02:53<03:41, 26.20it/s, loss=7.24e-7, rmse_test=0.0304]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4188/10000 [02:53<03:44, 25.85it/s, loss=7.24e-7, rmse_test=0.0304]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4188/10000 [02:53<03:44, 25.85it/s, loss=7.22e-7, rmse_test=0.0307]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4188/10000 [02:53<03:44, 25.85it/s, loss=7.23e-7, rmse_test=0.0302]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4188/10000 [02:53<03:44, 25.85it/s, loss=7.23e-7, rmse_test=0.0306]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4191/10000 [02:53<03:40, 26.37it/s, loss=7.23e-7, rmse_test=0.0306]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4191/10000 [02:53<03:40, 26.37it/s, loss=7.21e-7, rmse_test=0.0302]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4191/10000 [02:53<03:40, 26.37it/s, loss=7.22e-7, rmse_test=0.0314]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4191/10000 [02:53<03:40, 26.37it/s, loss=7.23e-7, rmse_test=0.0302]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4194/10000 [02:53<03:45, 25.79it/s, loss=7.23e-7, rmse_test=0.0302]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4194/10000 [02:54<03:45, 25.79it/s, loss=7.24e-7, rmse_test=0.0297]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4194/10000 [02:54<03:45, 25.79it/s, loss=7.22e-7, rmse_test=0.03]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4194/10000 [02:54<03:45, 25.79it/s, loss=7.22e-7, rmse_test=0.0307]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4197/10000 [02:54<03:43, 25.93it/s, loss=7.22e-7, rmse_test=0.0307]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4197/10000 [02:54<03:43, 25.93it/s, loss=7.22e-7, rmse_test=0.0313]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4197/10000 [02:54<03:43, 25.93it/s, loss=7.22e-7, rmse_test=0.0336]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4197/10000 [02:54<03:43, 25.93it/s, loss=7.25e-7, rmse_test=0.0305]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4200/10000 [02:54<10:54,  8.86it/s, loss=7.25e-7, rmse_test=0.0305]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4200/10000 [02:55<10:54,  8.86it/s, loss=7.23e-7, rmse_test=0.0304]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4200/10000 [02:55<10:54,  8.86it/s, loss=7.23e-7, rmse_test=0.0304]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4200/10000 [02:55<10:54,  8.86it/s, loss=7.24e-7, rmse_test=0.0303]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4203/10000 [02:55<08:50, 10.93it/s, loss=7.24e-7, rmse_test=0.0303]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4203/10000 [02:55<08:50, 10.93it/s, loss=7.23e-7, rmse_test=0.0314]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4203/10000 [02:55<08:50, 10.93it/s, loss=7.22e-7, rmse_test=0.0317]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4203/10000 [02:55<08:50, 10.93it/s, loss=7.22e-7, rmse_test=0.0298]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4206/10000 [02:55<07:15, 13.29it/s, loss=7.22e-7, rmse_test=0.0298]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4206/10000 [02:55<07:15, 13.29it/s, loss=7.23e-7, rmse_test=0.0304]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4206/10000 [02:55<07:15, 13.29it/s, loss=7.23e-7, rmse_test=0.031]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4206/10000 [02:55<07:15, 13.29it/s, loss=7.22e-7, rmse_test=0.0303]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4209/10000 [02:55<06:14, 15.47it/s, loss=7.22e-7, rmse_test=0.0303]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4209/10000 [02:55<06:14, 15.47it/s, loss=7.21e-7, rmse_test=0.0326]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4209/10000 [02:55<06:14, 15.47it/s, loss=7.22e-7, rmse_test=0.0329]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4209/10000 [02:55<06:14, 15.47it/s, loss=7.23e-7, rmse_test=0.0308]
#
#
#
#
#
#
#
#
#  42%|████▏     | 4209/10000 [03:07<06:14, 15.47it/s, loss=7.23e-7, rmse_test=0.0308]

# %% [markdown]
# ## Model

# %%
outputdir = 'output_heat'
exps = ['stnn', 'stnn_r', 'stnn_d']
models = {}
for exp in exps:
    with open(os.path.join(outputdir, exp, 'config.json'), 'r') as f:
        config = json.load(f)
    setup, (train_data, test_data), relations, (exogenous_train, exogenous_test) = dataset_factory(datadir, dataset, config['khop'])

    model = SaptioTemporalNN(relations, exogenous_train, 41, 100, 0, 1, config['nz'], config['mode'], config['nhid'],
                             config['nlayers'], config['dropout_f'], config['dropout_d'],
                             config['activation'], config['periode'])
    state_dict = torch.load(os.path.join(outputdir, exp, 'model.pt'), map_location=lambda storage, loc: storage)
    model.load_state_dict(state_dict)
    models[exp] = model

# %% [markdown]
# ## Results

# %%
predictions = {}
for exp in exps:
    model = models[exp]
    model.eval()
    with torch.no_grad():
        prediction, _ = model.generate(100, exogenous_test)
        predictions[exp] = prediction
        mse =  rmse(prediction, test_data)
    print('RMSE {}:\t'.format(exp), mse)
# Out:
# RMSE stnn:	 0.006673112977296114
# RMSE stnn_r:	 0.012743831612169743
# RMSE stnn_d:	 0.03084404766559601

# %%
plt.figure('Test plots', figsize=(17, 4), dpi=90)
for exp in exps:
    with open(os.path.join(outputdir, exp, 'logs.json'), 'r') as f:
        logs = json.load(f)

    plt.plot([logs['test_epoch.ts.{}.rmse'.format(ts)][-1] for ts in range(100)], label=exp, alpha=0.8)

plt.grid()
plt.title('Prediction RMSE')
plt.xlabel('timestep')
plt.legend()

# %%
plt.figure('Results', figsize=(17, 12), dpi=70)

plt.subplot(3, 3, 1)
plt.imshow(test_data.squeeze().numpy().T, aspect='auto', cmap='jet')
plt.colorbar()
plt.title('ground truth')

for i, exp in enumerate(exps):
    plt.subplot(3, 3, i * 3 + 2 + i // 3)
    plt.imshow(predictions[exp].squeeze().numpy().T, aspect='auto', cmap='jet')
    plt.colorbar()
    plt.title('{} prediction'.format(exp))

    plt.subplot(3, 3, i * 3 + 3 + i // 3)
    plt.imshow(test_data.sub(predictions[exp]).abs().squeeze().numpy().T, aspect='auto')
    plt.colorbar()
    plt.title('{} absolute error'.format(exp))

# %%
plt.figure('Relations', figsize=(17, 4), dpi=70)

plt.subplot(1, 2, 1)
m = models['stnn_r']
plt.imshow(m.get_relations()[:, 1].detach().numpy(), aspect='equal')
plt.title('stnn_r')
plt.colorbar()

plt.subplot(1, 2, 2)
m = models['stnn_d']
plt.imshow(m.get_relations()[:, 1].detach().numpy(), aspect='equal')
plt.title('stnn_d')
plt.colorbar()
